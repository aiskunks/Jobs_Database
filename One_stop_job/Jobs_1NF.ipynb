# %%
#import statements
import pandas as pd
from datetime import datetime, timedelta

# %%
#reading the uncleaned csv
df = pd.read_csv("Jobs_1NF_Final.csv")
df.head()
# Out:
#                                           Job_Titile  \
# 0                   Board Certified Behavior Analyst
# 1  Economic Analyst – Remote ***Guaranteed minimu...
# 2                                 Recruiting Analyst
# 3              Legal Compliance Analyst - Hybrid job
# 4  Board Certified Behavior Analyst (BCBA) - Cape...
#
#                                              Job_URL  \
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1  https://www.indeed.com/company/Augusta/jobs/Ec...
# 2  https://www.indeed.com/rc/clk?jk=fc9e8f57f0724...
# 3  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
#
#                                          Company_URL  \
# 0  https://www.indeed.com/cmp/North-Oakland-Autis...
# 1               https://www.indeed.com/cmp/Augusta-7
# 2                 https://www.indeed.com/cmp/Discord
# 3                https://www.indeed.com/cmp/Odoo-Inc
# 4                                                NaN
#
#                        Company  Rating                     Salary  \
# 0  North Oakland Autism Center     3.9   $50,000 - $90,000 a year
# 1      Augusta Precious Metals     3.8       From $100,000 a year
# 2                      Discord     4.3            $133,000 a year
# 3                     Odoo Inc     4.5  $75,000 - $110,000 a year
# 4                          NaN     NaN   $70,000 - $85,000 a year
#
#         Job_Tyoe                                    Job_description  \
# 0  Full-time\n+1  Our ideal candidate will competently manage a ...
# 1  Full-time\n+1  We will provide in-house systems and complianc...
# 2            NaN  Colorado residents only: Minimum salary of $10...
# 3      Full-time  Odoo ERP system is enterprise resource plannin...
# 4  Full-time\n+1  Full-time salaried positions: Monday-Friday (w...
#
#                      Post_Date           City State ZipCode
# 0  Posted\nPosted 30+ days ago     Lake Orion    MI   48362
# 1    Posted\nPosted 5 days ago  San Francisco    CA  94134
# 2  Posted\nPosted 30+ days ago        Hyannis    MA     NaN
# 3  Employer\nActive 5 days ago    South Paris    ME    4281
# 4  Posted\nPosted 30+ days ago    Hyattsville    MD     NaN

# %%
df['Salary']
# Out:
# 0        $50,000 - $90,000 a year
# 1            From $100,000 a year
# 2                 $133,000 a year
# 3       $75,000 - $110,000 a year
# 4        $70,000 - $85,000 a year
#                   ...
# 3777                    Full-time
# 3778                    Full-time
# 3779                    Full-time
# 3780               $68,640 a year
# 3781                    Full-time
# Name: Salary, Length: 3782, dtype: object

# %%
#replace all the characters 
df['Salary'] = df['Salary'].str.replace('Estimated ','').str.replace(' a year','').str.replace('From','').str.replace('-','').str.replace('a month','').str.replace('an hour','')
df['Salary'] = df['Salary'].str.replace('Fulltime','').str.replace('\n+1','').str.replace('Parttime','').str.replace('Up to','').str.replace('a year','').str.replace('$','')
# Out:
# /var/folders/v2/18cz5grj6_l18_cp77bmkj6r0000gn/T/ipykernel_72833/728174517.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Salary'] = df['Salary'].str.replace('Fulltime','').str.replace('\n+1','').str.replace('Parttime','').str.replace('Up to','').str.replace('a year','').str.replace('$','')
# /var/folders/v2/18cz5grj6_l18_cp77bmkj6r0000gn/T/ipykernel_72833/728174517.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Salary'] = df['Salary'].str.replace('Fulltime','').str.replace('\n+1','').str.replace('Parttime','').str.replace('Up to','').str.replace('a year','').str.replace('$','')

# %%
df['Salary']
# Out:
# 0        50,000  90,000
# 1               100,000
# 2               133,000
# 3       75,000  110,000
# 4        70,000  85,000
#              ...
# 3777
# 3778
# 3779
# 3780             68,640
# 3781
# Name: Salary, Length: 3782, dtype: object

# %%
df1 = df['Salary'].str.split(n=1, expand=True)
df1.columns = ['Salary{}'.format(x+1) for x in df1.columns]

df = df.join(df1)
df
# Out:
#                                              Job_Titile  \
# 0                      Board Certified Behavior Analyst
# 1     Economic Analyst – Remote ***Guaranteed minimu...
# 2                                    Recruiting Analyst
# 3                 Legal Compliance Analyst - Hybrid job
# 4     Board Certified Behavior Analyst (BCBA) - Cape...
# ...                                                 ...
# 3777                Software Engineer (Remote USA Only)
# 3778                         Graduate Software Engineer
# 3779  2023 University Graduate - Software Developmen...
# 3780            Software Engineer (Remote Work Options)
# 3781                                Software Engineer 1
#
#                                                 Job_URL  \
# 0     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1     https://www.indeed.com/company/Augusta/jobs/Ec...
# 2     https://www.indeed.com/rc/clk?jk=fc9e8f57f0724...
# 3     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# ...                                                 ...
# 3777  https://www.indeed.com/rc/clk?jk=2d1bcaf75519d...
# 3778  https://www.indeed.com/rc/clk?jk=ab60705252c60...
# 3779  https://www.indeed.com/rc/clk?jk=5d518aade2b7c...
# 3780  https://www.indeed.com/rc/clk?jk=fdfd4880ee0af...
# 3781  https://www.indeed.com/rc/clk?jk=c321400a3836d...
#
#                                             Company_URL  \
# 0     https://www.indeed.com/cmp/North-Oakland-Autis...
# 1                  https://www.indeed.com/cmp/Augusta-7
# 2                    https://www.indeed.com/cmp/Discord
# 3                   https://www.indeed.com/cmp/Odoo-Inc
# 4                                                   NaN
# ...                                                 ...
# 3777                https://www.indeed.com/cmp/Experian
# 3778                  https://www.indeed.com/cmp/Wise-6
# 3779                   https://www.indeed.com/cmp/Adobe
# 3780       https://www.indeed.com/cmp/Shelter-Insurance
# 3781  https://www.indeed.com/cmp/Pacific-Northwest-N...
#
#                                     Company  Rating           Salary  \
# 0               North Oakland Autism Center     3.9   50,000  90,000
# 1                   Augusta Precious Metals     3.8          100,000
# 2                                   Discord     4.3          133,000
# 3                                  Odoo Inc     4.5  75,000  110,000
# 4                                       NaN     NaN   70,000  85,000
# ...                                     ...     ...              ...
# 3777                               Experian     3.6
# 3778                                   Wise     4.1
# 3779                                  Adobe     4.3
# 3780                      Shelter Insurance     3.7           68,640
# 3781  Pacific Northwest National Laboratory     4.0
#
#            Job_Tyoe                                    Job_description  \
# 0     Full-time\n+1  Our ideal candidate will competently manage a ...
# 1     Full-time\n+1  We will provide in-house systems and complianc...
# 2               NaN  Colorado residents only: Minimum salary of $10...
# 3         Full-time  Odoo ERP system is enterprise resource plannin...
# 4     Full-time\n+1  Full-time salaried positions: Monday-Friday (w...
# ...             ...                                                ...
# 3777      Full-time  In addition to a competitive base salary and v...
# 3778      Full-time  At Wise you'll work on challenging technical p...
# 3779      Full-time  Adobe is seeking talented and passionate Softw...
# 3780  Full-time\n+1  Develop, test, maintain and document software ...
# 3781      Full-time  The candidate will be required to communicate ...
#
#                         Post_Date            City State ZipCode  Salary1  \
# 0     Posted\nPosted 30+ days ago      Lake Orion    MI   48362   50,000
# 1       Posted\nPosted 5 days ago   San Francisco    CA  94134   100,000
# 2     Posted\nPosted 30+ days ago         Hyannis    MA     NaN  133,000
# 3     Employer\nActive 5 days ago     South Paris    ME    4281   75,000
# 4     Posted\nPosted 30+ days ago     Hyattsville    MD     NaN   70,000
# ...                           ...             ...   ...     ...      ...
# 3777    Posted\nPosted 2 days ago    Grand Island    NE   68801     None
# 3778    Posted\nPosted 4 days ago   San Francisco    CA     NaN     None
# 3779   Posted\nPosted 26 days ago  West Greenwich    RI    2817     None
# 3780    Posted\nPosted 2 days ago          Boston    MA     NaN   68,640
# 3781    Posted\nPosted 6 days ago        New York    NY     NaN     None
#
#       Salary2
# 0      90,000
# 1        None
# 2        None
# 3     110,000
# 4      85,000
# ...       ...
# 3777     None
# 3778     None
# 3779     None
# 3780     None
# 3781     None
#
# [3782 rows x 14 columns]

# %%
#replace all the characters 
df['Salary1'] = df['Salary1'].str.replace(',','').str.replace('Up','').str.replace(' ','').str.replace('Contract','').str.replace('Internship','').str.replace('None','')
df['Salary1'] = df['Salary1'].str.replace('.','').str.replace('K','00').str.replace('Temporary','')
# Out:
# /var/folders/v2/18cz5grj6_l18_cp77bmkj6r0000gn/T/ipykernel_72833/1410569658.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Salary1'] = df['Salary1'].str.replace('.','').str.replace('K','00').str.replace('Temporary','')

# %%
df['Salary1']
# Out:
# 0        50000
# 1       100000
# 2       133000
# 3        75000
# 4        70000
#          ...
# 3777      None
# 3778      None
# 3779      None
# 3780     68640
# 3781      None
# Name: Salary1, Length: 3782, dtype: object

# %%
#get rid of '' error
salaries = []
for sal in df['Salary1']:
    if(sal != '' and sal is not None and sal == sal):
        sal = int(sal)
    elif(sal == ''):
        sal = '0'
    else:
        sal = sal
    salaries.append(sal)

# %%
df['Salary1'] = salaries

# %%
#convert the salary1 data type from object to float
df['Salary1'] = df['Salary1'].astype('float64')

# %%
df['Salary1']
# Out:
# 0        50000.0
# 1       100000.0
# 2       133000.0
# 3        75000.0
# 4        70000.0
#           ...
# 3777         NaN
# 3778         NaN
# 3779         NaN
# 3780     68640.0
# 3781         NaN
# Name: Salary1, Length: 3782, dtype: float64

# %%
df['Salary2']
# Out:
# 0        90,000
# 1          None
# 2          None
# 3       110,000
# 4        85,000
#          ...
# 3777       None
# 3778       None
# 3779       None
# 3780       None
# 3781       None
# Name: Salary2, Length: 3782, dtype: object

# %%
#replace all the characters 
df['Salary2'] = df['Salary2'].str.replace(',','').str.replace('Up','').str.replace(' ','').str.replace('Contract','').str.replace('Internship','').str.replace('None','')
df['Salary2'] = df['Salary2'].str.replace('.','').str.replace('K','00').str.replace('Temporary','')
# Out:
# /var/folders/v2/18cz5grj6_l18_cp77bmkj6r0000gn/T/ipykernel_72833/427629457.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Salary2'] = df['Salary2'].str.replace('.','').str.replace('K','00').str.replace('Temporary','')

# %%
df['Salary2']
# Out:
# 0        90000
# 1         None
# 2         None
# 3       110000
# 4        85000
#          ...
# 3777      None
# 3778      None
# 3779      None
# 3780      None
# 3781      None
# Name: Salary2, Length: 3782, dtype: object

# %%
#get rid of '' error
salaries1 = []
for sal in df['Salary2']:
    if(sal != '' and sal is not None and sal == sal):
        sal = int(sal)
    elif(sal == ''):
        sal = '0'
    else:
        sal = sal
    salaries1.append(sal)

# %%
#update the salary1
df['Salary2'] = salaries1

# %%
#convert the salary1 data type from object to float
df['Salary2'] = df['Salary2'].astype('float64')

# %%
df['Salary2']
# Out:
# 0        90000.0
# 1            NaN
# 2            NaN
# 3       110000.0
# 4        85000.0
#           ...
# 3777         NaN
# 3778         NaN
# 3779         NaN
# 3780         NaN
# 3781         NaN
# Name: Salary2, Length: 3782, dtype: float64

# %%
df
# Out:
#                                              Job_Titile  \
# 0                      Board Certified Behavior Analyst
# 1     Economic Analyst – Remote ***Guaranteed minimu...
# 2                                    Recruiting Analyst
# 3                 Legal Compliance Analyst - Hybrid job
# 4     Board Certified Behavior Analyst (BCBA) - Cape...
# ...                                                 ...
# 3777                Software Engineer (Remote USA Only)
# 3778                         Graduate Software Engineer
# 3779  2023 University Graduate - Software Developmen...
# 3780            Software Engineer (Remote Work Options)
# 3781                                Software Engineer 1
#
#                                                 Job_URL  \
# 0     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1     https://www.indeed.com/company/Augusta/jobs/Ec...
# 2     https://www.indeed.com/rc/clk?jk=fc9e8f57f0724...
# 3     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# ...                                                 ...
# 3777  https://www.indeed.com/rc/clk?jk=2d1bcaf75519d...
# 3778  https://www.indeed.com/rc/clk?jk=ab60705252c60...
# 3779  https://www.indeed.com/rc/clk?jk=5d518aade2b7c...
# 3780  https://www.indeed.com/rc/clk?jk=fdfd4880ee0af...
# 3781  https://www.indeed.com/rc/clk?jk=c321400a3836d...
#
#                                             Company_URL  \
# 0     https://www.indeed.com/cmp/North-Oakland-Autis...
# 1                  https://www.indeed.com/cmp/Augusta-7
# 2                    https://www.indeed.com/cmp/Discord
# 3                   https://www.indeed.com/cmp/Odoo-Inc
# 4                                                   NaN
# ...                                                 ...
# 3777                https://www.indeed.com/cmp/Experian
# 3778                  https://www.indeed.com/cmp/Wise-6
# 3779                   https://www.indeed.com/cmp/Adobe
# 3780       https://www.indeed.com/cmp/Shelter-Insurance
# 3781  https://www.indeed.com/cmp/Pacific-Northwest-N...
#
#                                     Company  Rating           Salary  \
# 0               North Oakland Autism Center     3.9   50,000  90,000
# 1                   Augusta Precious Metals     3.8          100,000
# 2                                   Discord     4.3          133,000
# 3                                  Odoo Inc     4.5  75,000  110,000
# 4                                       NaN     NaN   70,000  85,000
# ...                                     ...     ...              ...
# 3777                               Experian     3.6
# 3778                                   Wise     4.1
# 3779                                  Adobe     4.3
# 3780                      Shelter Insurance     3.7           68,640
# 3781  Pacific Northwest National Laboratory     4.0
#
#            Job_Tyoe                                    Job_description  \
# 0     Full-time\n+1  Our ideal candidate will competently manage a ...
# 1     Full-time\n+1  We will provide in-house systems and complianc...
# 2               NaN  Colorado residents only: Minimum salary of $10...
# 3         Full-time  Odoo ERP system is enterprise resource plannin...
# 4     Full-time\n+1  Full-time salaried positions: Monday-Friday (w...
# ...             ...                                                ...
# 3777      Full-time  In addition to a competitive base salary and v...
# 3778      Full-time  At Wise you'll work on challenging technical p...
# 3779      Full-time  Adobe is seeking talented and passionate Softw...
# 3780  Full-time\n+1  Develop, test, maintain and document software ...
# 3781      Full-time  The candidate will be required to communicate ...
#
#                         Post_Date            City State ZipCode   Salary1  \
# 0     Posted\nPosted 30+ days ago      Lake Orion    MI   48362   50000.0
# 1       Posted\nPosted 5 days ago   San Francisco    CA  94134   100000.0
# 2     Posted\nPosted 30+ days ago         Hyannis    MA     NaN  133000.0
# 3     Employer\nActive 5 days ago     South Paris    ME    4281   75000.0
# 4     Posted\nPosted 30+ days ago     Hyattsville    MD     NaN   70000.0
# ...                           ...             ...   ...     ...       ...
# 3777    Posted\nPosted 2 days ago    Grand Island    NE   68801       NaN
# 3778    Posted\nPosted 4 days ago   San Francisco    CA     NaN       NaN
# 3779   Posted\nPosted 26 days ago  West Greenwich    RI    2817       NaN
# 3780    Posted\nPosted 2 days ago          Boston    MA     NaN   68640.0
# 3781    Posted\nPosted 6 days ago        New York    NY     NaN       NaN
#
#        Salary2
# 0      90000.0
# 1          NaN
# 2          NaN
# 3     110000.0
# 4      85000.0
# ...        ...
# 3777       NaN
# 3778       NaN
# 3779       NaN
# 3780       NaN
# 3781       NaN
#
# [3782 rows x 14 columns]

# %%
#delete salary and salary2 column as we are considering only one part of the salary
df.drop(['Salary'], axis=1, inplace=True)

# %%
df
# Out:
#                                              Job_Titile  \
# 0                      Board Certified Behavior Analyst
# 1     Economic Analyst – Remote ***Guaranteed minimu...
# 2                                    Recruiting Analyst
# 3                 Legal Compliance Analyst - Hybrid job
# 4     Board Certified Behavior Analyst (BCBA) - Cape...
# ...                                                 ...
# 3777                Software Engineer (Remote USA Only)
# 3778                         Graduate Software Engineer
# 3779  2023 University Graduate - Software Developmen...
# 3780            Software Engineer (Remote Work Options)
# 3781                                Software Engineer 1
#
#                                                 Job_URL  \
# 0     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1     https://www.indeed.com/company/Augusta/jobs/Ec...
# 2     https://www.indeed.com/rc/clk?jk=fc9e8f57f0724...
# 3     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# ...                                                 ...
# 3777  https://www.indeed.com/rc/clk?jk=2d1bcaf75519d...
# 3778  https://www.indeed.com/rc/clk?jk=ab60705252c60...
# 3779  https://www.indeed.com/rc/clk?jk=5d518aade2b7c...
# 3780  https://www.indeed.com/rc/clk?jk=fdfd4880ee0af...
# 3781  https://www.indeed.com/rc/clk?jk=c321400a3836d...
#
#                                             Company_URL  \
# 0     https://www.indeed.com/cmp/North-Oakland-Autis...
# 1                  https://www.indeed.com/cmp/Augusta-7
# 2                    https://www.indeed.com/cmp/Discord
# 3                   https://www.indeed.com/cmp/Odoo-Inc
# 4                                                   NaN
# ...                                                 ...
# 3777                https://www.indeed.com/cmp/Experian
# 3778                  https://www.indeed.com/cmp/Wise-6
# 3779                   https://www.indeed.com/cmp/Adobe
# 3780       https://www.indeed.com/cmp/Shelter-Insurance
# 3781  https://www.indeed.com/cmp/Pacific-Northwest-N...
#
#                                     Company  Rating       Job_Tyoe  \
# 0               North Oakland Autism Center     3.9  Full-time\n+1
# 1                   Augusta Precious Metals     3.8  Full-time\n+1
# 2                                   Discord     4.3            NaN
# 3                                  Odoo Inc     4.5      Full-time
# 4                                       NaN     NaN  Full-time\n+1
# ...                                     ...     ...            ...
# 3777                               Experian     3.6      Full-time
# 3778                                   Wise     4.1      Full-time
# 3779                                  Adobe     4.3      Full-time
# 3780                      Shelter Insurance     3.7  Full-time\n+1
# 3781  Pacific Northwest National Laboratory     4.0      Full-time
#
#                                         Job_description  \
# 0     Our ideal candidate will competently manage a ...
# 1     We will provide in-house systems and complianc...
# 2     Colorado residents only: Minimum salary of $10...
# 3     Odoo ERP system is enterprise resource plannin...
# 4     Full-time salaried positions: Monday-Friday (w...
# ...                                                 ...
# 3777  In addition to a competitive base salary and v...
# 3778  At Wise you'll work on challenging technical p...
# 3779  Adobe is seeking talented and passionate Softw...
# 3780  Develop, test, maintain and document software ...
# 3781  The candidate will be required to communicate ...
#
#                         Post_Date            City State ZipCode   Salary1  \
# 0     Posted\nPosted 30+ days ago      Lake Orion    MI   48362   50000.0
# 1       Posted\nPosted 5 days ago   San Francisco    CA  94134   100000.0
# 2     Posted\nPosted 30+ days ago         Hyannis    MA     NaN  133000.0
# 3     Employer\nActive 5 days ago     South Paris    ME    4281   75000.0
# 4     Posted\nPosted 30+ days ago     Hyattsville    MD     NaN   70000.0
# ...                           ...             ...   ...     ...       ...
# 3777    Posted\nPosted 2 days ago    Grand Island    NE   68801       NaN
# 3778    Posted\nPosted 4 days ago   San Francisco    CA     NaN       NaN
# 3779   Posted\nPosted 26 days ago  West Greenwich    RI    2817       NaN
# 3780    Posted\nPosted 2 days ago          Boston    MA     NaN   68640.0
# 3781    Posted\nPosted 6 days ago        New York    NY     NaN       NaN
#
#        Salary2
# 0      90000.0
# 1          NaN
# 2          NaN
# 3     110000.0
# 4      85000.0
# ...        ...
# 3777       NaN
# 3778       NaN
# 3779       NaN
# 3780       NaN
# 3781       NaN
#
# [3782 rows x 13 columns]

# %%
#replace the column name Salary1 with Salary
df = df.rename({'Salary1': 'Min_salary'}, axis=1)

# %%
#replace the column name Salary1 with Salary
df = df.rename({'Salary2': 'Max_salary'}, axis=1)

# %%
df
# Out:
#                                              Job_Titile  \
# 0                      Board Certified Behavior Analyst
# 1     Economic Analyst – Remote ***Guaranteed minimu...
# 2                                    Recruiting Analyst
# 3                 Legal Compliance Analyst - Hybrid job
# 4     Board Certified Behavior Analyst (BCBA) - Cape...
# ...                                                 ...
# 3777                Software Engineer (Remote USA Only)
# 3778                         Graduate Software Engineer
# 3779  2023 University Graduate - Software Developmen...
# 3780            Software Engineer (Remote Work Options)
# 3781                                Software Engineer 1
#
#                                                 Job_URL  \
# 0     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1     https://www.indeed.com/company/Augusta/jobs/Ec...
# 2     https://www.indeed.com/rc/clk?jk=fc9e8f57f0724...
# 3     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# ...                                                 ...
# 3777  https://www.indeed.com/rc/clk?jk=2d1bcaf75519d...
# 3778  https://www.indeed.com/rc/clk?jk=ab60705252c60...
# 3779  https://www.indeed.com/rc/clk?jk=5d518aade2b7c...
# 3780  https://www.indeed.com/rc/clk?jk=fdfd4880ee0af...
# 3781  https://www.indeed.com/rc/clk?jk=c321400a3836d...
#
#                                             Company_URL  \
# 0     https://www.indeed.com/cmp/North-Oakland-Autis...
# 1                  https://www.indeed.com/cmp/Augusta-7
# 2                    https://www.indeed.com/cmp/Discord
# 3                   https://www.indeed.com/cmp/Odoo-Inc
# 4                                                   NaN
# ...                                                 ...
# 3777                https://www.indeed.com/cmp/Experian
# 3778                  https://www.indeed.com/cmp/Wise-6
# 3779                   https://www.indeed.com/cmp/Adobe
# 3780       https://www.indeed.com/cmp/Shelter-Insurance
# 3781  https://www.indeed.com/cmp/Pacific-Northwest-N...
#
#                                     Company  Rating       Job_Tyoe  \
# 0               North Oakland Autism Center     3.9  Full-time\n+1
# 1                   Augusta Precious Metals     3.8  Full-time\n+1
# 2                                   Discord     4.3            NaN
# 3                                  Odoo Inc     4.5      Full-time
# 4                                       NaN     NaN  Full-time\n+1
# ...                                     ...     ...            ...
# 3777                               Experian     3.6      Full-time
# 3778                                   Wise     4.1      Full-time
# 3779                                  Adobe     4.3      Full-time
# 3780                      Shelter Insurance     3.7  Full-time\n+1
# 3781  Pacific Northwest National Laboratory     4.0      Full-time
#
#                                         Job_description  \
# 0     Our ideal candidate will competently manage a ...
# 1     We will provide in-house systems and complianc...
# 2     Colorado residents only: Minimum salary of $10...
# 3     Odoo ERP system is enterprise resource plannin...
# 4     Full-time salaried positions: Monday-Friday (w...
# ...                                                 ...
# 3777  In addition to a competitive base salary and v...
# 3778  At Wise you'll work on challenging technical p...
# 3779  Adobe is seeking talented and passionate Softw...
# 3780  Develop, test, maintain and document software ...
# 3781  The candidate will be required to communicate ...
#
#                         Post_Date            City State ZipCode  Min_salary  \
# 0     Posted\nPosted 30+ days ago      Lake Orion    MI   48362     50000.0
# 1       Posted\nPosted 5 days ago   San Francisco    CA  94134     100000.0
# 2     Posted\nPosted 30+ days ago         Hyannis    MA     NaN    133000.0
# 3     Employer\nActive 5 days ago     South Paris    ME    4281     75000.0
# 4     Posted\nPosted 30+ days ago     Hyattsville    MD     NaN     70000.0
# ...                           ...             ...   ...     ...         ...
# 3777    Posted\nPosted 2 days ago    Grand Island    NE   68801         NaN
# 3778    Posted\nPosted 4 days ago   San Francisco    CA     NaN         NaN
# 3779   Posted\nPosted 26 days ago  West Greenwich    RI    2817         NaN
# 3780    Posted\nPosted 2 days ago          Boston    MA     NaN     68640.0
# 3781    Posted\nPosted 6 days ago        New York    NY     NaN         NaN
#
#       Max_salary
# 0        90000.0
# 1            NaN
# 2            NaN
# 3       110000.0
# 4        85000.0
# ...          ...
# 3777         NaN
# 3778         NaN
# 3779         NaN
# 3780         NaN
# 3781         NaN
#
# [3782 rows x 13 columns]

# %%
df.describe()
# Out:
#             Rating     Min_salary     Max_salary
# count  3093.000000    2452.000000    1934.000000
# mean      3.861461   68641.781811   99835.174767
# std       0.435425   42310.458293   69767.867624
# min       2.500000       0.000000       1.000000
# 25%       3.600000   46400.000000   64870.000000
# 50%       3.900000   72500.000000   93500.000000
# 75%       4.100000  100000.000000  134458.250000
# max       5.000000  170000.000000  400000.000000

# %%
#fill the null values of Salary column with the mean salary
df.fillna({"Min_salary":df['Min_salary'].mean(),},inplace=True)

# %%
#fill the null values of Salary column with the mean salary
df.fillna({"Max_salary":df['Max_salary'].mean(),},inplace=True)

# %%
#Replace all the string values
df ['Post_Date'] = df['Post_Date'].str.replace('Posted\nPosted','').str.replace(' days ago','').str.replace('+','').str.replace(' day ago','')
df['Post_Date'] = df['Post_Date'].str.replace('Posted\nToday','').str.replace('Employer\nActive 5','').str.replace('Employer\nActive ','').str.replace('Hiring ongoing','').str.replace('Posted\nJust posted','0')
# Out:
# /var/folders/v2/18cz5grj6_l18_cp77bmkj6r0000gn/T/ipykernel_72833/4082833382.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df ['Post_Date'] = df['Post_Date'].str.replace('Posted\nPosted','').str.replace(' days ago','').str.replace('+','').str.replace(' day ago','')

# %%
#lets initialize the datetime
today = datetime.today()
yesterday = today - timedelta(days=1)
one_week_ago = today - timedelta(days=7)
thirty_days_ago = today - timedelta(days=30)
print(today.strftime("%m/%d/%y"))
# Out:
# 12/13/22

# %%
#get rid of '' error
dates = []
for date in df['Post_Date']:
    if(date != '' and date is not None and date == date):
        date = (today - timedelta(days=int(date))).strftime("%m/%d/%y")
    dates.append(date)

# %%
#update the Post_Date
df['Post_Date'] = dates

# %%
#display the dataframe after the changes
df
# Out:
#                                              Job_Titile  \
# 0                      Board Certified Behavior Analyst
# 1     Economic Analyst – Remote ***Guaranteed minimu...
# 2                                    Recruiting Analyst
# 3                 Legal Compliance Analyst - Hybrid job
# 4     Board Certified Behavior Analyst (BCBA) - Cape...
# ...                                                 ...
# 3777                Software Engineer (Remote USA Only)
# 3778                         Graduate Software Engineer
# 3779  2023 University Graduate - Software Developmen...
# 3780            Software Engineer (Remote Work Options)
# 3781                                Software Engineer 1
#
#                                                 Job_URL  \
# 0     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1     https://www.indeed.com/company/Augusta/jobs/Ec...
# 2     https://www.indeed.com/rc/clk?jk=fc9e8f57f0724...
# 3     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# ...                                                 ...
# 3777  https://www.indeed.com/rc/clk?jk=2d1bcaf75519d...
# 3778  https://www.indeed.com/rc/clk?jk=ab60705252c60...
# 3779  https://www.indeed.com/rc/clk?jk=5d518aade2b7c...
# 3780  https://www.indeed.com/rc/clk?jk=fdfd4880ee0af...
# 3781  https://www.indeed.com/rc/clk?jk=c321400a3836d...
#
#                                             Company_URL  \
# 0     https://www.indeed.com/cmp/North-Oakland-Autis...
# 1                  https://www.indeed.com/cmp/Augusta-7
# 2                    https://www.indeed.com/cmp/Discord
# 3                   https://www.indeed.com/cmp/Odoo-Inc
# 4                                                   NaN
# ...                                                 ...
# 3777                https://www.indeed.com/cmp/Experian
# 3778                  https://www.indeed.com/cmp/Wise-6
# 3779                   https://www.indeed.com/cmp/Adobe
# 3780       https://www.indeed.com/cmp/Shelter-Insurance
# 3781  https://www.indeed.com/cmp/Pacific-Northwest-N...
#
#                                     Company  Rating       Job_Tyoe  \
# 0               North Oakland Autism Center     3.9  Full-time\n+1
# 1                   Augusta Precious Metals     3.8  Full-time\n+1
# 2                                   Discord     4.3            NaN
# 3                                  Odoo Inc     4.5      Full-time
# 4                                       NaN     NaN  Full-time\n+1
# ...                                     ...     ...            ...
# 3777                               Experian     3.6      Full-time
# 3778                                   Wise     4.1      Full-time
# 3779                                  Adobe     4.3      Full-time
# 3780                      Shelter Insurance     3.7  Full-time\n+1
# 3781  Pacific Northwest National Laboratory     4.0      Full-time
#
#                                         Job_description Post_Date  \
# 0     Our ideal candidate will competently manage a ...  11/13/22
# 1     We will provide in-house systems and complianc...  12/08/22
# 2     Colorado residents only: Minimum salary of $10...  11/13/22
# 3     Odoo ERP system is enterprise resource plannin...
# 4     Full-time salaried positions: Monday-Friday (w...  11/13/22
# ...                                                 ...       ...
# 3777  In addition to a competitive base salary and v...  12/11/22
# 3778  At Wise you'll work on challenging technical p...  12/09/22
# 3779  Adobe is seeking talented and passionate Softw...  11/17/22
# 3780  Develop, test, maintain and document software ...  12/11/22
# 3781  The candidate will be required to communicate ...  12/07/22
#
#                 City State ZipCode     Min_salary     Max_salary
# 0         Lake Orion    MI   48362   50000.000000   90000.000000
# 1      San Francisco    CA  94134   100000.000000   99835.174767
# 2            Hyannis    MA     NaN  133000.000000   99835.174767
# 3        South Paris    ME    4281   75000.000000  110000.000000
# 4        Hyattsville    MD     NaN   70000.000000   85000.000000
# ...              ...   ...     ...            ...            ...
# 3777    Grand Island    NE   68801   68641.781811   99835.174767
# 3778   San Francisco    CA     NaN   68641.781811   99835.174767
# 3779  West Greenwich    RI    2817   68641.781811   99835.174767
# 3780          Boston    MA     NaN   68640.000000   99835.174767
# 3781        New York    NY     NaN   68641.781811   99835.174767
#
# [3782 rows x 13 columns]

# %%
#fill the null values of Rating column with the mean Rating
df.fillna({"Rating":df['Rating'].mean(),},inplace=True)

# %%
df
# Out:
#                                              Job_Titile  \
# 0                      Board Certified Behavior Analyst
# 1     Economic Analyst – Remote ***Guaranteed minimu...
# 2                                    Recruiting Analyst
# 3                 Legal Compliance Analyst - Hybrid job
# 4     Board Certified Behavior Analyst (BCBA) - Cape...
# ...                                                 ...
# 3777                Software Engineer (Remote USA Only)
# 3778                         Graduate Software Engineer
# 3779  2023 University Graduate - Software Developmen...
# 3780            Software Engineer (Remote Work Options)
# 3781                                Software Engineer 1
#
#                                                 Job_URL  \
# 0     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1     https://www.indeed.com/company/Augusta/jobs/Ec...
# 2     https://www.indeed.com/rc/clk?jk=fc9e8f57f0724...
# 3     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# ...                                                 ...
# 3777  https://www.indeed.com/rc/clk?jk=2d1bcaf75519d...
# 3778  https://www.indeed.com/rc/clk?jk=ab60705252c60...
# 3779  https://www.indeed.com/rc/clk?jk=5d518aade2b7c...
# 3780  https://www.indeed.com/rc/clk?jk=fdfd4880ee0af...
# 3781  https://www.indeed.com/rc/clk?jk=c321400a3836d...
#
#                                             Company_URL  \
# 0     https://www.indeed.com/cmp/North-Oakland-Autis...
# 1                  https://www.indeed.com/cmp/Augusta-7
# 2                    https://www.indeed.com/cmp/Discord
# 3                   https://www.indeed.com/cmp/Odoo-Inc
# 4                                                   NaN
# ...                                                 ...
# 3777                https://www.indeed.com/cmp/Experian
# 3778                  https://www.indeed.com/cmp/Wise-6
# 3779                   https://www.indeed.com/cmp/Adobe
# 3780       https://www.indeed.com/cmp/Shelter-Insurance
# 3781  https://www.indeed.com/cmp/Pacific-Northwest-N...
#
#                                     Company    Rating       Job_Tyoe  \
# 0               North Oakland Autism Center  3.900000  Full-time\n+1
# 1                   Augusta Precious Metals  3.800000  Full-time\n+1
# 2                                   Discord  4.300000            NaN
# 3                                  Odoo Inc  4.500000      Full-time
# 4                                       NaN  3.861461  Full-time\n+1
# ...                                     ...       ...            ...
# 3777                               Experian  3.600000      Full-time
# 3778                                   Wise  4.100000      Full-time
# 3779                                  Adobe  4.300000      Full-time
# 3780                      Shelter Insurance  3.700000  Full-time\n+1
# 3781  Pacific Northwest National Laboratory  4.000000      Full-time
#
#                                         Job_description Post_Date  \
# 0     Our ideal candidate will competently manage a ...  11/13/22
# 1     We will provide in-house systems and complianc...  12/08/22
# 2     Colorado residents only: Minimum salary of $10...  11/13/22
# 3     Odoo ERP system is enterprise resource plannin...
# 4     Full-time salaried positions: Monday-Friday (w...  11/13/22
# ...                                                 ...       ...
# 3777  In addition to a competitive base salary and v...  12/11/22
# 3778  At Wise you'll work on challenging technical p...  12/09/22
# 3779  Adobe is seeking talented and passionate Softw...  11/17/22
# 3780  Develop, test, maintain and document software ...  12/11/22
# 3781  The candidate will be required to communicate ...  12/07/22
#
#                 City State ZipCode     Min_salary     Max_salary
# 0         Lake Orion    MI   48362   50000.000000   90000.000000
# 1      San Francisco    CA  94134   100000.000000   99835.174767
# 2            Hyannis    MA     NaN  133000.000000   99835.174767
# 3        South Paris    ME    4281   75000.000000  110000.000000
# 4        Hyattsville    MD     NaN   70000.000000   85000.000000
# ...              ...   ...     ...            ...            ...
# 3777    Grand Island    NE   68801   68641.781811   99835.174767
# 3778   San Francisco    CA     NaN   68641.781811   99835.174767
# 3779  West Greenwich    RI    2817   68641.781811   99835.174767
# 3780          Boston    MA     NaN   68640.000000   99835.174767
# 3781        New York    NY     NaN   68641.781811   99835.174767
#
# [3782 rows x 13 columns]

# %%
#check for the columns(Salary and Rating) that have updated with null values
df.isna().sum()
# Out:
# Job_Titile            0
# Job_URL               0
# Company_URL         689
# Company             186
# Rating                0
# Job_Tyoe            784
# Job_description      81
# Post_Date           145
# City                  0
# State                 0
# ZipCode            1595
# Min_salary            0
# Max_salary            0
# dtype: int64

# %%
#duplicate values
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3777    False
# 3778     True
# 3779     True
# 3780     True
# 3781    False
# Length: 3782, dtype: bool

# %%
#initialize the values of duplicated
duplicate = df[df.duplicated()]

# %%
#display all the duplicate values
duplicate
# Out:
#                                              Job_Titile  \
# 33                                   Recruiting Analyst
# 36                      Crocs: Global Inventory Analyst
# 66                      Crocs: Global Inventory Analyst
# 69                                Health Policy Analyst
# 74                       Provider Data Analyst - Remote
# ...                                                 ...
# 3774                      Software Development Engineer
# 3775                     JR Software Developer (Remote)
# 3778                         Graduate Software Engineer
# 3779  2023 University Graduate - Software Developmen...
# 3780            Software Engineer (Remote Work Options)
#
#                                                 Job_URL  \
# 33    https://www.indeed.com/rc/clk?jk=fc9e8f57f0724...
# 36    https://www.indeed.com/rc/clk?jk=bd2959ee6cdca...
# 66    https://www.indeed.com/rc/clk?jk=bd2959ee6cdca...
# 69    https://www.indeed.com/rc/clk?jk=e310b2feb1791...
# 74    https://www.indeed.com/rc/clk?jk=597c85460fde5...
# ...                                                 ...
# 3774  https://www.indeed.com/rc/clk?jk=f434f985bb539...
# 3775  https://www.indeed.com/rc/clk?jk=e6f8c3066a981...
# 3778  https://www.indeed.com/rc/clk?jk=ab60705252c60...
# 3779  https://www.indeed.com/rc/clk?jk=5d518aade2b7c...
# 3780  https://www.indeed.com/rc/clk?jk=fdfd4880ee0af...
#
#                                             Company_URL  \
# 33                   https://www.indeed.com/cmp/Discord
# 36                     https://www.indeed.com/cmp/Crocs
# 66                     https://www.indeed.com/cmp/Crocs
# 69    https://www.indeed.com/cmp/Centers-For-Disease...
# 74        https://www.indeed.com/cmp/UnitedHealth-Group
# ...                                                 ...
# 3774              https://www.indeed.com/cmp/CVS-Health
# 3775                 https://www.indeed.com/cmp/Jaggaer
# 3778                  https://www.indeed.com/cmp/Wise-6
# 3779                   https://www.indeed.com/cmp/Adobe
# 3780       https://www.indeed.com/cmp/Shelter-Insurance
#
#                                          Company  Rating       Job_Tyoe  \
# 33                                       Discord     4.3            NaN
# 36                                         Crocs     3.6            NaN
# 66                                         Crocs     3.6            NaN
# 69    Centers for Disease Control and Prevention     4.2  Full-time\n+1
# 74                            UnitedHealth Group     3.6      Full-time
# ...                                          ...     ...            ...
# 3774                                  CVS Health     3.3            NaN
# 3775                                     Jaggaer     2.7      Full-time
# 3778                                        Wise     4.1      Full-time
# 3779                                       Adobe     4.3      Full-time
# 3780                           Shelter Insurance     3.7  Full-time\n+1
#
#                                         Job_description Post_Date  \
# 33    Colorado residents only: Minimum salary of $10...  11/13/22
# 36    1-3 years previous experience in Inventory or ...  12/02/22
# 66    1-3 years previous experience in Inventory or ...  12/02/22
# 69    Public Trust/Moderate Background Investigation...  12/11/22
# 74    E2E Solution Team Data analysts will be respon...  12/11/22
# ...                                                 ...       ...
# 3774    0-3 years of experience as a Software engineer.       NaN
# 3775  You will start building production ready softw...  12/07/22
# 3778  At Wise you'll work on challenging technical p...  12/09/22
# 3779  Adobe is seeking talented and passionate Softw...  11/17/22
# 3780  Develop, test, maintain and document software ...  12/11/22
#
#                 City State ZipCode     Min_salary     Max_salary
# 33           Hyannis    MA     NaN  133000.000000   99835.174767
# 36            Boston    MA  02109    73000.000000   88000.000000
# 66            Boston    MA  02109    73000.000000   88000.000000
# 69            Denver    CO  80207    89834.000000  138868.000000
# 74          New York    NY     NaN    2168.000000    3856.000000
# ...              ...   ...     ...            ...            ...
# 3774      Somerville    MA     NaN   46400.000000   97400.000000
# 3775          Denver    CO  80207    68641.781811   99835.174767
# 3778   San Francisco    CA     NaN   68641.781811   99835.174767
# 3779  West Greenwich    RI    2817   68641.781811   99835.174767
# 3780          Boston    MA     NaN   68640.000000   99835.174767
#
# [798 rows x 13 columns]

# %%
#Drop all the duplicate vlaues
df = df.drop_duplicates(keep='first')

# %%
df
# Out:
#                                              Job_Titile  \
# 0                      Board Certified Behavior Analyst
# 1     Economic Analyst – Remote ***Guaranteed minimu...
# 2                                    Recruiting Analyst
# 3                 Legal Compliance Analyst - Hybrid job
# 4     Board Certified Behavior Analyst (BCBA) - Cape...
# ...                                                 ...
# 3765                              IT Software Developer
# 3771               Associate Software Engineer - Remote
# 3776                      Software Engineer (Front End)
# 3777                Software Engineer (Remote USA Only)
# 3781                                Software Engineer 1
#
#                                                 Job_URL  \
# 0     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1     https://www.indeed.com/company/Augusta/jobs/Ec...
# 2     https://www.indeed.com/rc/clk?jk=fc9e8f57f0724...
# 3     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# ...                                                 ...
# 3765  https://www.indeed.com/rc/clk?jk=0c6201a24f1d0...
# 3771  https://www.indeed.com/rc/clk?jk=bc1094c931645...
# 3776  https://www.indeed.com/rc/clk?jk=bcbfa1fa1f670...
# 3777  https://www.indeed.com/rc/clk?jk=2d1bcaf75519d...
# 3781  https://www.indeed.com/rc/clk?jk=c321400a3836d...
#
#                                             Company_URL  \
# 0     https://www.indeed.com/cmp/North-Oakland-Autis...
# 1                  https://www.indeed.com/cmp/Augusta-7
# 2                    https://www.indeed.com/cmp/Discord
# 3                   https://www.indeed.com/cmp/Odoo-Inc
# 4                                                   NaN
# ...                                                 ...
# 3765       https://www.indeed.com/cmp/Miami-Dade-County
# 3771      https://www.indeed.com/cmp/UnitedHealth-Group
# 3776  https://www.indeed.com/cmp/Amplify-Education,-...
# 3777                https://www.indeed.com/cmp/Experian
# 3781  https://www.indeed.com/cmp/Pacific-Northwest-N...
#
#                                     Company    Rating       Job_Tyoe  \
# 0               North Oakland Autism Center  3.900000  Full-time\n+1
# 1                   Augusta Precious Metals  3.800000  Full-time\n+1
# 2                                   Discord  4.300000            NaN
# 3                                  Odoo Inc  4.500000      Full-time
# 4                                       NaN  3.861461  Full-time\n+1
# ...                                     ...       ...            ...
# 3765                      Miami-Dade County  4.200000      Full-time
# 3771                     UnitedHealth Group  3.600000      Full-time
# 3776                Amplify Education, Inc.  4.000000      Full-time
# 3777                               Experian  3.600000      Full-time
# 3781  Pacific Northwest National Laboratory  4.000000      Full-time
#
#                                         Job_description Post_Date  \
# 0     Our ideal candidate will competently manage a ...  11/13/22
# 1     We will provide in-house systems and complianc...  12/08/22
# 2     Colorado residents only: Minimum salary of $10...  11/13/22
# 3     Odoo ERP system is enterprise resource plannin...
# 4     Full-time salaried positions: Monday-Friday (w...  11/13/22
# ...                                                 ...       ...
# 3765  Two years of experience in software developmen...  11/13/22
# 3771  At Optum Insight Technology, you’ll help us wo...       NaN
# 3776  Salary is only one component of the Amplify To...  12/02/22
# 3777  In addition to a competitive base salary and v...  12/11/22
# 3781  The candidate will be required to communicate ...  12/07/22
#
#                City State ZipCode     Min_salary     Max_salary
# 0        Lake Orion    MI   48362   50000.000000   90000.000000
# 1     San Francisco    CA  94134   100000.000000   99835.174767
# 2           Hyannis    MA     NaN  133000.000000   99835.174767
# 3       South Paris    ME    4281   75000.000000  110000.000000
# 4       Hyattsville    MD     NaN   70000.000000   85000.000000
# ...             ...   ...     ...            ...            ...
# 3765         Boston    MA  02116    73674.000000   99835.174767
# 3771    South Paris    ME    4281   54400.000000   97000.000000
# 3776       Hartford    CT  06105   101000.000000  131000.000000
# 3777   Grand Island    NE   68801   68641.781811   99835.174767
# 3781       New York    NY     NaN   68641.781811   99835.174767
#
# [2984 rows x 13 columns]

# %%
#drop all the null values
df = df.dropna()

# %%
df
# Out:
#                                              Job_Titile  \
# 0                      Board Certified Behavior Analyst
# 1     Economic Analyst – Remote ***Guaranteed minimu...
# 3                 Legal Compliance Analyst - Hybrid job
# 9                                 Health Policy Analyst
# 12                                 Service Desk Analyst
# ...                                                 ...
# 3752               Software Engineer I (Remote Option*)
# 3758   Software Engineer Co-Op (Spring 2023 - Yarmouth)
# 3765                              IT Software Developer
# 3776                      Software Engineer (Front End)
# 3777                Software Engineer (Remote USA Only)
#
#                                                 Job_URL  \
# 0     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1     https://www.indeed.com/company/Augusta/jobs/Ec...
# 3     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 9     https://www.indeed.com/rc/clk?jk=e310b2feb1791...
# 12    https://www.indeed.com/company/Spruce/jobs/Ser...
# ...                                                 ...
# 3752  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 3758  https://www.indeed.com/rc/clk?jk=5a748f5c432c9...
# 3765  https://www.indeed.com/rc/clk?jk=0c6201a24f1d0...
# 3776  https://www.indeed.com/rc/clk?jk=bcbfa1fa1f670...
# 3777  https://www.indeed.com/rc/clk?jk=2d1bcaf75519d...
#
#                                             Company_URL  \
# 0     https://www.indeed.com/cmp/North-Oakland-Autis...
# 1                  https://www.indeed.com/cmp/Augusta-7
# 3                   https://www.indeed.com/cmp/Odoo-Inc
# 9     https://www.indeed.com/cmp/Centers-For-Disease...
# 12                    https://www.indeed.com/cmp/Spruce
# ...                                                 ...
# 3752                    https://www.indeed.com/cmp/Nike
# 3758                  https://www.indeed.com/cmp/Garmin
# 3765       https://www.indeed.com/cmp/Miami-Dade-County
# 3776  https://www.indeed.com/cmp/Amplify-Education,-...
# 3777                https://www.indeed.com/cmp/Experian
#
#                                          Company  Rating       Job_Tyoe  \
# 0                    North Oakland Autism Center     3.9  Full-time\n+1
# 1                        Augusta Precious Metals     3.8  Full-time\n+1
# 3                                       Odoo Inc     4.5      Full-time
# 9     Centers for Disease Control and Prevention     4.2  Full-time\n+1
# 12                                        Spruce     3.4       Contract
# ...                                          ...     ...            ...
# 3752                                        Nike     4.1      Full-time
# 3758                  Garmin International, Inc.     3.7  Full-time\n+1
# 3765                           Miami-Dade County     4.2      Full-time
# 3776                     Amplify Education, Inc.     4.0      Full-time
# 3777                                    Experian     3.6      Full-time
#
#                                         Job_description Post_Date  \
# 0     Our ideal candidate will competently manage a ...  11/13/22
# 1     We will provide in-house systems and complianc...  12/08/22
# 3     Odoo ERP system is enterprise resource plannin...
# 9     Public Trust/Moderate Background Investigation...  12/11/22
# 12    Monitor and answer the Service Desk phone, e-m...  11/24/22
# ...                                                 ...       ...
# 3752  Experience with Version control tools such as ...  11/13/22
# 3758  Learn to perform software releases and softwar...  11/13/22
# 3765  Two years of experience in software developmen...  11/13/22
# 3776  Salary is only one component of the Amplify To...  12/02/22
# 3777  In addition to a competitive base salary and v...  12/11/22
#
#                City State ZipCode     Min_salary     Max_salary
# 0        Lake Orion    MI   48362   50000.000000   90000.000000
# 1     San Francisco    CA  94134   100000.000000   99835.174767
# 3       South Paris    ME    4281   75000.000000  110000.000000
# 9            Denver    CO  80207    89834.000000  138868.000000
# 12     Grand Island    NE   68801      40.000000      60.000000
# ...             ...   ...     ...            ...            ...
# 3752         Boston    MA  02109   107500.000000  161500.000000
# 3758       Hartford    CT  06105        1.000000   99835.174767
# 3765         Boston    MA  02116    73674.000000   99835.174767
# 3776       Hartford    CT  06105   101000.000000  131000.000000
# 3777   Grand Island    NE   68801   68641.781811   99835.174767
#
# [1065 rows x 13 columns]

# %%
#check if there are any null values
df.isna().sum()
# Out:
# Job_Titile         0
# Job_URL            0
# Company_URL        0
# Company            0
# Rating             0
# Job_Tyoe           0
# Job_description    0
# Post_Date          0
# City               0
# State              0
# ZipCode            0
# Min_salary         0
# Max_salary         0
# dtype: int64

# %%
df
# Out:
#                                              Job_Titile  \
# 0                      Board Certified Behavior Analyst
# 1     Economic Analyst – Remote ***Guaranteed minimu...
# 3                 Legal Compliance Analyst - Hybrid job
# 9                                 Health Policy Analyst
# 12                                 Service Desk Analyst
# ...                                                 ...
# 3752               Software Engineer I (Remote Option*)
# 3758   Software Engineer Co-Op (Spring 2023 - Yarmouth)
# 3765                              IT Software Developer
# 3776                      Software Engineer (Front End)
# 3777                Software Engineer (Remote USA Only)
#
#                                                 Job_URL  \
# 0     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1     https://www.indeed.com/company/Augusta/jobs/Ec...
# 3     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 9     https://www.indeed.com/rc/clk?jk=e310b2feb1791...
# 12    https://www.indeed.com/company/Spruce/jobs/Ser...
# ...                                                 ...
# 3752  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 3758  https://www.indeed.com/rc/clk?jk=5a748f5c432c9...
# 3765  https://www.indeed.com/rc/clk?jk=0c6201a24f1d0...
# 3776  https://www.indeed.com/rc/clk?jk=bcbfa1fa1f670...
# 3777  https://www.indeed.com/rc/clk?jk=2d1bcaf75519d...
#
#                                             Company_URL  \
# 0     https://www.indeed.com/cmp/North-Oakland-Autis...
# 1                  https://www.indeed.com/cmp/Augusta-7
# 3                   https://www.indeed.com/cmp/Odoo-Inc
# 9     https://www.indeed.com/cmp/Centers-For-Disease...
# 12                    https://www.indeed.com/cmp/Spruce
# ...                                                 ...
# 3752                    https://www.indeed.com/cmp/Nike
# 3758                  https://www.indeed.com/cmp/Garmin
# 3765       https://www.indeed.com/cmp/Miami-Dade-County
# 3776  https://www.indeed.com/cmp/Amplify-Education,-...
# 3777                https://www.indeed.com/cmp/Experian
#
#                                          Company  Rating       Job_Tyoe  \
# 0                    North Oakland Autism Center     3.9  Full-time\n+1
# 1                        Augusta Precious Metals     3.8  Full-time\n+1
# 3                                       Odoo Inc     4.5      Full-time
# 9     Centers for Disease Control and Prevention     4.2  Full-time\n+1
# 12                                        Spruce     3.4       Contract
# ...                                          ...     ...            ...
# 3752                                        Nike     4.1      Full-time
# 3758                  Garmin International, Inc.     3.7  Full-time\n+1
# 3765                           Miami-Dade County     4.2      Full-time
# 3776                     Amplify Education, Inc.     4.0      Full-time
# 3777                                    Experian     3.6      Full-time
#
#                                         Job_description Post_Date  \
# 0     Our ideal candidate will competently manage a ...  11/13/22
# 1     We will provide in-house systems and complianc...  12/08/22
# 3     Odoo ERP system is enterprise resource plannin...
# 9     Public Trust/Moderate Background Investigation...  12/11/22
# 12    Monitor and answer the Service Desk phone, e-m...  11/24/22
# ...                                                 ...       ...
# 3752  Experience with Version control tools such as ...  11/13/22
# 3758  Learn to perform software releases and softwar...  11/13/22
# 3765  Two years of experience in software developmen...  11/13/22
# 3776  Salary is only one component of the Amplify To...  12/02/22
# 3777  In addition to a competitive base salary and v...  12/11/22
#
#                City State ZipCode     Min_salary     Max_salary
# 0        Lake Orion    MI   48362   50000.000000   90000.000000
# 1     San Francisco    CA  94134   100000.000000   99835.174767
# 3       South Paris    ME    4281   75000.000000  110000.000000
# 9            Denver    CO  80207    89834.000000  138868.000000
# 12     Grand Island    NE   68801      40.000000      60.000000
# ...             ...   ...     ...            ...            ...
# 3752         Boston    MA  02109   107500.000000  161500.000000
# 3758       Hartford    CT  06105        1.000000   99835.174767
# 3765         Boston    MA  02116    73674.000000   99835.174767
# 3776       Hartford    CT  06105   101000.000000  131000.000000
# 3777   Grand Island    NE   68801   68641.781811   99835.174767
#
# [1065 rows x 13 columns]

# %%
#export the cleaned data into a csv file
df.to_csv("JobsFinalDatabase.csv")

# %%
#import statements
import sqlite3
import plotly.express as px

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
print("Opened database successfully");
conn.execute('''DROP TABLE IF EXISTS job_details;''')
conn.execute('''CREATE TABLE IF NOT EXISTS job_details
         (
          job_id INTEGER PRIMARY KEY,
          job_title TEXT,
          company_name TEXT,
          job_type TEXT,
          job_post_date datetime,
          job_rating Float,
          job_link TEXT,
          job_desc TEXT,
          company_website TEXT
         );''')

print("job_details Table created successfully");

conn.close()
# Out:
# Opened database successfully
# job_details Table created successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
print("Opened database successfully");
conn.execute('''DROP TABLE IF EXISTS salary_details;''')
conn.execute('''CREATE TABLE IF NOT EXISTS salary_details
         (
          job_id INTEGER PRIMARY KEY ,
          min_salary Float,
          max_salary Float,
          FOREIGN KEY (job_id) REFERENCES job_details(job_id)
         );''')

print("salary_details Table created successfully");

conn.close()
# Out:
# Opened database successfully
# salary_details Table created successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
print("Opened database successfully");
conn.execute('''DROP TABLE IF EXISTS job_location_details;''')
conn.execute('''CREATE TABLE IF NOT EXISTS job_location_details
         (
          job_id INTEGER PRIMARY KEY ,
          city TEXT,
          state TEXT,
          zipcode INTEGER,
          FOREIGN KEY (job_id) REFERENCES job_details(job_id)
         );''')

print("job_location_details Table created successfully");

conn.close()
# Out:
# Opened database successfully
# job_location_details Table created successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
print("Opened database successfully");
conn.execute('''DROP TABLE IF EXISTS user_login_details;''')
conn.execute('''CREATE TABLE IF NOT EXISTS user_login_details
         (
          user_platform_name TEXT PRIMARY KEY ,
          user_password TEXT,
          user_role TEXT
         );''')

print("user_login_details Table created successfully");

conn.close()
# Out:
# Opened database successfully
# user_login_details Table created successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
print("Opened database successfully");
conn.execute('''DROP TABLE IF EXISTS user_details;''')
conn.execute('''CREATE TABLE IF NOT EXISTS user_details
         (
          user_platform_name TEXT PRIMARY KEY ,
          user_first_name TEXT,
          user_last_name TEXT,
          dob datetime,
          mobile_number TEXT,
          email_id TEXT,
          portfolio_link TEXT,
          FOREIGN KEY (user_platform_name) REFERENCES user_login_details(user_platform_name)
         );''')

print("user_details Table created successfully");

conn.close()
# Out:
# Opened database successfully
# user_details Table created successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
print("Opened database successfully");
conn.execute('''DROP TABLE IF EXISTS user_skillset_details;''')
conn.execute('''CREATE TABLE IF NOT EXISTS user_skillset_details
         (
          user_platform_name TEXT PRIMARY KEY ,
          skillset TEXT,
        FOREIGN KEY (user_platform_name) REFERENCES user_details(user_platform_name)
         );''')

print("user_skillset_details Table created successfully");

conn.close()
# Out:
# Opened database successfully
# user_skillset_details Table created successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
print("Opened database successfully");
conn.execute('''DROP TABLE IF EXISTS user_certifications;''')
conn.execute('''CREATE TABLE IF NOT EXISTS user_certifications
         (
          user_platform_name TEXT PRIMARY KEY ,
     certification TEXT,
        FOREIGN KEY (user_platform_name) REFERENCES user_details(user_platform_name)
         );''')

print("user_certifications Table created successfully");

conn.close()
# Out:
# Opened database successfully
# user_certifications Table created successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
print("Opened database successfully");
conn.execute('''DROP TABLE IF EXISTS user_saved_jobs;''')
conn.execute('''CREATE TABLE IF NOT EXISTS user_saved_jobs
         (
          user_platform_name TEXT PRIMARY KEY ,
        saved_application_id INTEGER,
        FOREIGN KEY (user_platform_name) REFERENCES user_details(user_platform_name)
         );''')

print("user_saved_jobs Table created successfully");

conn.close()
# Out:
# Opened database successfully
# user_saved_jobs Table created successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
print("Opened database successfully");
conn.execute('''DROP TABLE IF EXISTS user_location_details;''')
conn.execute('''CREATE TABLE IF NOT EXISTS user_location_details
         (
          user_platform_name TEXT PRIMARY KEY ,
          city TEXT,
          state TEXT,
          zipcode INTEGER,
        FOREIGN KEY (user_platform_name) REFERENCES user_details(user_platform_name)
         );''')

print("user_location_details Table created successfully");

conn.close()
# Out:
# Opened database successfully
# user_location_details Table created successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
i = 0
for row in df.itertuples():
    i += 1
    conn.execute('INSERT or IGNORE INTO job_details(job_id, job_title, company_name, job_type, job_post_date, job_rating, job_link, job_desc, company_website) VALUES (?,?,?,?,?,?,?,?,?)',(
                i,
                row.Job_Titile, 
                row.Company,
                row.Job_Tyoe,
                row.Post_Date,
                row.Rating,
                row.Job_URL,
                row.Job_description,
                row.Company_URL
                )
                )
    conn.commit()
print("job_details Table values inserted successfully");
conn.close()
# Out:
# job_details Table values inserted successfully

# %%
con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''SELECT * from job_details;''')

r1 = pd.read_sql(q1, con)
r1.head(1)
#print(r1)
r1
# Out:
#       job_id                                          job_title  \
# 0          1                   Board Certified Behavior Analyst
# 1          2  Economic Analyst – Remote ***Guaranteed minimu...
# 2          3              Legal Compliance Analyst - Hybrid job
# 3          4                              Health Policy Analyst
# 4          5                               Service Desk Analyst
# ...      ...                                                ...
# 1060    1061               Software Engineer I (Remote Option*)
# 1061    1062   Software Engineer Co-Op (Spring 2023 - Yarmouth)
# 1062    1063                              IT Software Developer
# 1063    1064                      Software Engineer (Front End)
# 1064    1065                Software Engineer (Remote USA Only)
#
#                                     company_name       job_type job_post_date  \
# 0                    North Oakland Autism Center  Full-time\n+1      11/13/22
# 1                        Augusta Precious Metals  Full-time\n+1      12/08/22
# 2                                       Odoo Inc      Full-time
# 3     Centers for Disease Control and Prevention  Full-time\n+1      12/11/22
# 4                                         Spruce       Contract      11/24/22
# ...                                          ...            ...           ...
# 1060                                        Nike      Full-time      11/13/22
# 1061                  Garmin International, Inc.  Full-time\n+1      11/13/22
# 1062                           Miami-Dade County      Full-time      11/13/22
# 1063                     Amplify Education, Inc.      Full-time      12/02/22
# 1064                                    Experian      Full-time      12/11/22
#
#       job_rating                                           job_link  \
# 0            3.9  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1            3.8  https://www.indeed.com/company/Augusta/jobs/Ec...
# 2            4.5  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3            4.2  https://www.indeed.com/rc/clk?jk=e310b2feb1791...
# 4            3.4  https://www.indeed.com/company/Spruce/jobs/Ser...
# ...          ...                                                ...
# 1060         4.1  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 1061         3.7  https://www.indeed.com/rc/clk?jk=5a748f5c432c9...
# 1062         4.2  https://www.indeed.com/rc/clk?jk=0c6201a24f1d0...
# 1063         4.0  https://www.indeed.com/rc/clk?jk=bcbfa1fa1f670...
# 1064         3.6  https://www.indeed.com/rc/clk?jk=2d1bcaf75519d...
#
#                                                job_desc  \
# 0     Our ideal candidate will competently manage a ...
# 1     We will provide in-house systems and complianc...
# 2     Odoo ERP system is enterprise resource plannin...
# 3     Public Trust/Moderate Background Investigation...
# 4     Monitor and answer the Service Desk phone, e-m...
# ...                                                 ...
# 1060  Experience with Version control tools such as ...
# 1061  Learn to perform software releases and softwar...
# 1062  Two years of experience in software developmen...
# 1063  Salary is only one component of the Amplify To...
# 1064  In addition to a competitive base salary and v...
#
#                                         company_website
# 0     https://www.indeed.com/cmp/North-Oakland-Autis...
# 1                  https://www.indeed.com/cmp/Augusta-7
# 2                   https://www.indeed.com/cmp/Odoo-Inc
# 3     https://www.indeed.com/cmp/Centers-For-Disease...
# 4                     https://www.indeed.com/cmp/Spruce
# ...                                                 ...
# 1060                    https://www.indeed.com/cmp/Nike
# 1061                  https://www.indeed.com/cmp/Garmin
# 1062       https://www.indeed.com/cmp/Miami-Dade-County
# 1063  https://www.indeed.com/cmp/Amplify-Education,-...
# 1064                https://www.indeed.com/cmp/Experian
#
# [1065 rows x 9 columns]

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
i = 0
for row in df.itertuples():
    i += 1
    conn.execute('INSERT or IGNORE INTO salary_details(job_id, min_salary, max_salary) VALUES (?,?,?)',(
                i,
                row.Min_salary, 
                row.Max_salary
                )
                )
    conn.commit()
print("salary_details Table values inserted successfully");
conn.close()
# Out:
# salary_details Table values inserted successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
i = 0
for row in df.itertuples():
    i+=1
    conn.execute('INSERT or IGNORE INTO job_location_details(job_id, city, state, zipcode) VALUES (?,?,?,?)',(
                i,
                row.City, 
                row.State,
                row.ZipCode
                )
                )
    conn.commit()
print("job_location_details Table values inserted successfully");
conn.close()
# Out:
# job_location_details Table values inserted successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
i = 0
for row in df.itertuples():
    i+=1
    conn.execute('INSERT or IGNORE INTO company_details(company_name, company_website) VALUES (?,?)',(
                row.Company, 
                row.Company_URL
                )
                )
    conn.commit()
print("company_details Table values inserted successfully");
conn.close()
# Out:
# company_details Table values inserted successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
conn.execute('INSERT or IGNORE INTO user_login_details(user_platform_name, user_password, user_role) VALUES (?,?,?)',(
                "@Hilton", 
                "Hilton@123",
                "seeker"
                )
                )
conn.commit()
print("user_login_details Table values inserted successfully");
conn.close()
# Out:
# user_login_details Table values inserted successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
conn.execute('INSERT or IGNORE INTO user_details(user_platform_name, user_first_name, user_last_name, dob, mobile_number, email_id, portfolio_link) VALUES (?,?,?,?,?,?,?)',(
                "@Hilton", 
                "Hilton",
                "Benson",
                "1998-04-02",
                "7658904321",
                "hilton.savage@gmail.com",
                "www.hilton.com"
                )
                )
conn.commit()
print("user_details Table values inserted successfully");
conn.close()
# Out:
# user_details Table values inserted successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
conn.execute('INSERT or IGNORE INTO user_skillset_details(user_platform_name, skillset) VALUES (?,?)',(
                "@Hilton", 
                "Java",
                )
                )
conn.execute('INSERT or IGNORE INTO user_skillset_details(user_platform_name, skillset) VALUES (?,?)',(
                "@Hilton", 
                "Software",
                )
                )
conn.commit()
print("user_skillset_details Table values inserted successfully");
conn.close()
# Out:
# user_skillset_details Table values inserted successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
conn.execute('INSERT or IGNORE INTO user_certifications(user_platform_name, certification) VALUES (?,?)',(
                "@Hilton", 
                "AWS CCP",
                )
                )
conn.execute('INSERT or IGNORE INTO user_certifications(user_platform_name, certification) VALUES (?,?)',(
                "@Hilton", 
                "CFA",
                )
                )
conn.commit()
print("user_certifications Table values inserted successfully");
conn.close()
# Out:
# user_certifications Table values inserted successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
conn.execute('INSERT or IGNORE INTO user_saved_jobs(user_platform_name, saved_application_id) VALUES (?,?)',(
                "@Hilton", 
                1,
                )
                )
conn.execute('INSERT or IGNORE INTO user_saved_jobs(user_platform_name, saved_application_id) VALUES (?,?)',(
                "@Hilton", 
                200,
                )
                )
conn.commit()
print("user_saved_jobs Table values inserted successfully");
conn.close()
# Out:
# user_saved_jobs Table values inserted successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
conn.execute('INSERT or IGNORE INTO user_location_details(user_platform_name, city, state, zipcode) VALUES (?,?,?,?)',(
                "@Hilton", 
                "Boston",
                "MA",
                "01234"
                )
                )
conn.commit()
print("user_location_details Table values inserted successfully");
conn.close()
# Out:
# user_location_details Table values inserted successfully

# %%
#3NF
conn = sqlite3.connect('JobsFinalDatabase.db')
print("Opened database successfully");
conn.execute('''DROP TABLE IF EXISTS company_details;''')
conn.execute('''CREATE TABLE IF NOT EXISTS company_details
         (
          company_name TEXT PRIMARY KEY ,
          company_website TEXT
         );''')

print("company_details Table created successfully");

conn.close()
# Out:
# Opened database successfully
# company_details Table created successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
i = 0
for row in df.itertuples():
    i+=1
    conn.execute('INSERT or IGNORE INTO company_details(company_name, company_website) VALUES (?,?)',(
                row.Company, 
                row.Company_URL
                )
                )
    conn.commit()
print("company_details Table values inserted successfully");
conn.close()
# Out:
# company_details Table values inserted successfully

# %%
con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''SELECT * from company_details;''')

r1 = pd.read_sql(q1, con)
r1.head(1)
#print(r1)
r1
# Out:
#                                   company_name  \
# 0                  North Oakland Autism Center
# 1                      Augusta Precious Metals
# 2                                     Odoo Inc
# 3   Centers for Disease Control and Prevention
# 4                                       Spruce
# ..                                         ...
# 90                        National Instruments
# 91                  Garmin International, Inc.
# 92                                      PayPal
# 93                      Insurance Technologies
# 94                     Amplify Education, Inc.
#
#                                       company_website
# 0   https://www.indeed.com/cmp/North-Oakland-Autis...
# 1                https://www.indeed.com/cmp/Augusta-7
# 2                 https://www.indeed.com/cmp/Odoo-Inc
# 3   https://www.indeed.com/cmp/Centers-For-Disease...
# 4                   https://www.indeed.com/cmp/Spruce
# ..                                                ...
# 90  https://www.indeed.com/cmp/National-Instruments-1
# 91                  https://www.indeed.com/cmp/Garmin
# 92                  https://www.indeed.com/cmp/Paypal
# 93                https://www.indeed.com/cmp/Hexure-1
# 94  https://www.indeed.com/cmp/Amplify-Education,-...
#
# [95 rows x 2 columns]

# %%
## Query 2
con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''select c.company_name, avg(j.job_rating) from company_details c inner join job_details j on c.company_name = j.company_name group by c.company_name having avg(j.job_rating) > 2.0 and avg(j.job_rating) < 4.0;''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
r3
# Out:
#                                          company_name  avg(j.job_rating)
# 0                                                  3M                3.9
# 1                        Amazon Dev Center U.S., Inc.                3.5
# 2                             Amazon.com Services LLC                3.5
# 3                             Augusta Precious Metals                3.8
# 4                                         BAE Systems                3.8
# 5                                     Bank of America                3.8
# 6                                         Capital One                3.9
# 7                           Carrier Klimatechnik GmbH                3.8
# 8                                 Children's Mercy KC                3.8
# 9                                               Cigna                3.7
# 10                                             Circle                3.7
# 11                                        CyberCoders                3.7
# 12                                   D&W Diesel, Inc.                3.3
# 13                                           Deloitte                3.9
# 14                                            Dropbox                3.9
# 15                           Elbit Systems of America                3.6
# 16                                    Electronic Arts                3.8
# 17                                           Experian                3.6
# 18                                              Fetch                3.6
# 19                                           Formlabs                3.7
# 20                         Garmin International, Inc.                3.7
# 21                                           GenSpark                2.8
# 22                                           Genspark                2.8
# 23                         Hewlett Packard Enterprise                3.8
# 24                                                IBM                3.9
# 25                         Idaho Central Credit Union                3.9
# 26                          JPMorgan Chase Bank, N.A.                3.8
# 27                                            Jaggaer                2.7
# 28                                         MSA Safety                3.7
# 29                     Maine Machine Products (MMPCo)                3.8
# 30                                           NETSCOUT                3.7
# 31  National Association of County and City Health...                3.3
# 32                               National Instruments                3.0
# 33                                             Nelnet                3.5
# 34                                            Netflix                3.9
# 35                        North Oakland Autism Center                3.9
# 36                                        Ocean Spray                3.5
# 37                                           PTC Inc.                3.7
# 38                                            Parsons                3.9
# 39                                             PayPal                3.9
# 40                                        Pegasystems                3.6
# 41                                         Proofpoint                3.6
# 42                                               Roku                3.1
# 43                                  Shelter Insurance                3.7
# 44                                             Spruce                3.4
# 45     State of Connecticut - Department of Social...                3.9
# 46                                              Tesla                3.4
# 47                                    The Judge Group                3.7
# 48                                  The Pulse Network                3.0
# 49                                        TriMark USA                3.0
# 50                                               Uber                3.6
# 51                                 UnitedHealth Group                3.6
# 52                                        VSolvit LLC                3.5
# 53                                        Veeder Root                3.0
# 54                                            Wayfair                3.0
# 55                                      WinnCompanies                3.1
# 56                                           foodguys                3.2

# %%
##Query 1
con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select j.job_title, j.job_link, l.city || ', ' ||  l.state || ', ' ||  l.zipcode as location, s.min_salary as salary, j.job_post_date, j.job_desc, j.job_rating, j.job_type from job_details j inner join salary_details s on j.job_id = s.job_id inner join job_location_details l on j.job_id = l.job_id where j.job_title LIKE "%Analyst%";''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
r3
# Out:
#                                              job_title  \
# 0                     Board Certified Behavior Analyst
# 1    Economic Analyst – Remote ***Guaranteed minimu...
# 2                Legal Compliance Analyst - Hybrid job
# 3                                Health Policy Analyst
# 4                                 Service Desk Analyst
# ..                                                 ...
# 328                           Trade Operations Analyst
# 329                   Board Certified Behavior Analyst
# 330              Program Analyst Workforce Development
# 331                                 Programmer Analyst
# 332                                 Programmer Analyst
#
#                                               job_link  \
# 0    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1    https://www.indeed.com/company/Augusta/jobs/Ec...
# 2    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3    https://www.indeed.com/rc/clk?jk=e310b2feb1791...
# 4    https://www.indeed.com/company/Spruce/jobs/Ser...
# ..                                                 ...
# 328  https://www.indeed.com/rc/clk?jk=81c5a77fff82d...
# 329  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 330  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 331  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 332  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
#
#                       location         salary job_post_date  \
# 0        Lake Orion, MI, 48362   50000.000000      11/13/22
# 1    San Francisco, CA, 94134   100000.000000      12/08/22
# 2        South Paris, ME, 4281   75000.000000
# 3           Denver, CO, 80207    89834.000000      12/11/22
# 4      Grand Island, NE, 68801      40.000000      11/24/22
# ..                         ...            ...           ...
# 328       Hartford, CT, 06105    68641.781811      12/02/22
# 329     Providence, RI, 02903    50000.000000      11/13/22
# 330        Chubbuck, ID, 83202   61040.000000      12/09/22
# 331         Boston, MA, 02116    68641.781811      11/13/22
# 332         Boston, MA, 02109    68641.781811      11/13/22
#
#                                               job_desc  job_rating  \
# 0    Our ideal candidate will competently manage a ...         3.9
# 1    We will provide in-house systems and complianc...         3.8
# 2    Odoo ERP system is enterprise resource plannin...         4.5
# 3    Public Trust/Moderate Background Investigation...         4.2
# 4    Monitor and answer the Service Desk phone, e-m...         3.4
# ..                                                 ...         ...
# 328  Perform key operational responsibilities relat...         4.0
# 329  Our ideal candidate will competently manage a ...         3.9
# 330  Bachelor's degree in relevant professional fie...         3.3
# 331  Develop APIs and other software integrations t...         3.3
# 332  Develop APIs and other software integrations t...         3.3
#
#           job_type
# 0    Full-time\n+1
# 1    Full-time\n+1
# 2        Full-time
# 3    Full-time\n+1
# 4         Contract
# ..             ...
# 328      Full-time
# 329  Full-time\n+1
# 330      Full-time
# 331      Full-time
# 332      Full-time
#
# [333 rows x 8 columns]

# %%
## Query 3
con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''select c.company_name, c.company_website, l.city || ', ' || l.state || ', ' || l.zipcode as location from company_details c inner join job_details j on c.company_name = j.company_name inner join job_location_details l on j.job_id = l.job_id where l.state LIKE "%MA%";''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
r3
# Out:
#                      company_name  \
# 0                              3M
# 1              UnitedHealth Group
# 2                     TriMark USA
# 3     North Oakland Autism Center
# 4           Stride Autism Centers
# ..                            ...
# 300  Arkansas Children's Hospital
# 301                   VSolvit LLC
# 302        Insurance Technologies
# 303                          Nike
# 304             Miami-Dade County
#
#                                        company_website            location
# 0                        https://www.indeed.com/cmp/3M  Boston, MA, 02109
# 1        https://www.indeed.com/cmp/UnitedHealth-Group  Boston, MA, 02116
# 2               https://www.indeed.com/cmp/Trimark-USA  Boston, MA, 02109
# 3    https://www.indeed.com/cmp/North-Oakland-Autis...  Boston, MA, 02116
# 4     https://www.indeed.com/cmp/Stride-Autism-Centers  Boston, MA, 02116
# ..                                                 ...                 ...
# 300  https://www.indeed.com/cmp/Arkansas-Children's...  Boston, MA, 02110
# 301             https://www.indeed.com/cmp/Vsolvit-LLC  Boston, MA, 02110
# 302                https://www.indeed.com/cmp/Hexure-1  Boston, MA, 02110
# 303                    https://www.indeed.com/cmp/Nike  Boston, MA, 02109
# 304       https://www.indeed.com/cmp/Miami-Dade-County  Boston, MA, 02116
#
# [305 rows x 3 columns]

# %%
## Query 4

con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''select j.job_title, j.job_link, l.city || ', ' || l.state || ', ' || l.zipcode as location, s.min_salary as salary, j.job_rating, j.job_type from job_details j inner join salary_details s on j.job_id = s.job_id inner join job_location_details l on j.job_id = l.job_id where j.job_desc LIKE "%Software%" ORDER BY j.job_rating desc limit 5;''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
r3
# Out:
#                                job_title  \
# 0                          Web Developer
# 1                          Web Developer
# 2                          Web Developer
# 3                          Web Developer
# 4  Legal Compliance Analyst - Hybrid job
#
#                                             job_link  \
# 0  https://www.indeed.com/company/Emonics/jobs/We...
# 1  https://www.indeed.com/company/Emonics/jobs/We...
# 2  https://www.indeed.com/company/Emonics/jobs/We...
# 3  https://www.indeed.com/company/Emonics/jobs/We...
# 4  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
#
#                     location   salary  job_rating   job_type
# 0  San Francisco, CA, 94134   70000.0         4.6  Full-time
# 1      South Paris, ME, 4281  70000.0         4.6  Full-time
# 2       Hartford, CT, 06105   70000.0         4.6  Full-time
# 3     Providence, RI, 02903   70000.0         4.6  Full-time
# 4      South Paris, ME, 4281  75000.0         4.5  Full-time

# %%
## Query 5

con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select j.job_title, j.job_link, j.job_type, s.min_salary as salary from job_details j inner join salary_details s on j.job_id = s.job_id where j.job_type LIKE "%Full-time%" and j.job_title LIKE "%Intern%";''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
r3
# Out:
#                                              job_title  \
# 0                     2023 Intern - Software Developer
# 1                                      software intern
# 2    Frontend React/JS Internship, Vehicle Software...
# 3            Software Engineering Intern (Summer 2023)
# 4               Software Engineer Intern (Summer 2023)
# ..                                                 ...
# 97                    2023 Intern - Software Developer
# 98                    2023 Intern - Software Developer
# 99   UI Software Development Intern (Winter/Spring ...
# 100          Software Engineering Intern (Summer 2023)
# 101  Frontend React/JS Internship, Vehicle Software...
#
#                                               job_link       job_type  \
# 0    https://www.indeed.com/rc/clk?jk=9b239bcadff12...  Full-time\n+1
# 1    https://www.indeed.com/rc/clk?jk=983a87b9fd73d...  Full-time\n+1
# 2    https://www.indeed.com/rc/clk?jk=ba32cb615094f...  Full-time\n+3
# 3    https://www.indeed.com/rc/clk?jk=3faf42dbd2873...  Full-time\n+1
# 4    https://www.indeed.com/rc/clk?jk=d1d32b55c9e5a...  Full-time\n+2
# ..                                                 ...            ...
# 97   https://www.indeed.com/rc/clk?jk=9b239bcadff12...  Full-time\n+1
# 98   https://www.indeed.com/rc/clk?jk=9b239bcadff12...  Full-time\n+1
# 99   https://www.indeed.com/rc/clk?jk=ef00e02de4e3c...  Full-time\n+1
# 100  https://www.indeed.com/rc/clk?jk=3faf42dbd2873...  Full-time\n+1
# 101  https://www.indeed.com/rc/clk?jk=ba32cb615094f...  Full-time\n+3
#
#            salary
# 0    79800.000000
# 1    68641.781811
# 2    72500.000000
# 3    68641.781811
# 4    44700.000000
# ..            ...
# 97   79800.000000
# 98   79800.000000
# 99   68641.781811
# 100  68641.781811
# 101  72500.000000
#
# [102 rows x 4 columns]

# %%
## Query 6

con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select c.company_name from company_details c inner join job_details j on c.company_name = j.company_name where j.job_title LIKE "%Full Stack%" group by c.company_name having max(j.job_rating) > 4;''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
r3
# Out:
#               company_name
# 0  #twiceasnice Recruiting
# 1           AllSTEM - Jobs
# 2       Buchanan & Edwards
# 3                   Engtal
# 4               Neteffects
# 5                   VMware

# %%
## Query 7

con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select j.job_title, c.company_name, j.job_link, l.city || ', ' || l.state || ', ' ||  l.zipcode as location, s.min_salary as salary from job_details j left join company_details c on c.company_name = j.company_name inner join salary_details s on j.job_id = s.job_id inner join job_location_details l on j.job_id = l.job_id where j.job_title LIKE "%Remote%" and s.min_salary >= 70000;''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
r3
# Out:
#                                             job_title  \
# 0   Economic Analyst – Remote ***Guaranteed minimu...
# 1   Economic Analyst – Remote ***Guaranteed minimu...
# 2   Economic Analyst – Remote ***Guaranteed minimu...
# 3   Economic Analyst – Remote ***Guaranteed minimu...
# 4   Economic Analyst – Remote ***Guaranteed minimu...
# 5   Economic Analyst – Remote ***Guaranteed minimu...
# 6   Economic Analyst – Remote ***Guaranteed minimu...
# 7   Economic Analyst – Remote ***Guaranteed minimu...
# 8   Economic Analyst – Remote ***Guaranteed minimu...
# 9   Economic Analyst – Remote ***Guaranteed minimu...
# 10  Economic Analyst – Remote ***Guaranteed minimu...
# 11  Economic Analyst – Remote ***Guaranteed minimu...
# 12  Economic Analyst – Remote ***Guaranteed minimu...
# 13  Economic Analyst – Remote ***Guaranteed minimu...
# 14  Economic Analyst – Remote ***Guaranteed minimu...
# 15                        Remote Full-Stack Developer
# 16                        Remote Full-Stack Developer
# 17                        Remote Full-Stack Developer
# 18                        Remote Full-Stack Developer
# 19                        Remote Full-Stack Developer
# 20                        Remote Full-Stack Developer
# 21                        Remote Full-Stack Developer
# 22                        Remote Full-Stack Developer
# 23                        Remote Full-Stack Developer
# 24                        Remote Full-Stack Developer
# 25               Software Engineer I (Remote Option*)
# 26               Software Engineer I (Remote Option*)
# 27               Software Engineer I (Remote Option*)
# 28               Software Engineer I (Remote Option*)
# 29              Software Engineer II (Remote Option*)
# 30              Software Engineer II (Remote Option*)
# 31               Software Engineer I (Remote Option*)
# 32               Software Engineer I (Remote Option*)
# 33               Software Engineer I (Remote Option*)
# 34              Software Engineer II (Remote Option*)
# 35               Software Engineer I (Remote Option*)
# 36               Software Engineer I (Remote Option*)
# 37               Software Engineer I (Remote Option*)
# 38               Software Engineer I (Remote Option*)
# 39               Software Engineer I (Remote Option*)
# 40               Software Engineer I (Remote Option*)
# 41               Software Engineer I (Remote Option*)
#
#                company_name  \
# 0   Augusta Precious Metals
# 1   Augusta Precious Metals
# 2   Augusta Precious Metals
# 3   Augusta Precious Metals
# 4   Augusta Precious Metals
# 5   Augusta Precious Metals
# 6   Augusta Precious Metals
# 7   Augusta Precious Metals
# 8   Augusta Precious Metals
# 9   Augusta Precious Metals
# 10  Augusta Precious Metals
# 11  Augusta Precious Metals
# 12  Augusta Precious Metals
# 13  Augusta Precious Metals
# 14  Augusta Precious Metals
# 15              CyberCoders
# 16              CyberCoders
# 17              CyberCoders
# 18              CyberCoders
# 19              CyberCoders
# 20              CyberCoders
# 21              CyberCoders
# 22              CyberCoders
# 23              CyberCoders
# 24              CyberCoders
# 25                     Nike
# 26                     Nike
# 27                     Nike
# 28                     Nike
# 29                     Nike
# 30                     Nike
# 31                     Nike
# 32                     Nike
# 33                     Nike
# 34                     Nike
# 35                     Nike
# 36                     Nike
# 37                     Nike
# 38                     Nike
# 39                     Nike
# 40                     Nike
# 41                     Nike
#
#                                              job_link  \
# 0   https://www.indeed.com/company/Augusta/jobs/Ec...
# 1   https://www.indeed.com/company/Augusta/jobs/Ec...
# 2   https://www.indeed.com/company/Augusta/jobs/Ec...
# 3   https://www.indeed.com/company/Augusta/jobs/Ec...
# 4   https://www.indeed.com/company/Augusta/jobs/Ec...
# 5   https://www.indeed.com/company/Augusta/jobs/Ec...
# 6   https://www.indeed.com/company/Augusta/jobs/Ec...
# 7   https://www.indeed.com/company/Augusta/jobs/Ec...
# 8   https://www.indeed.com/company/Augusta/jobs/Ec...
# 9   https://www.indeed.com/company/Augusta/jobs/Ec...
# 10  https://www.indeed.com/company/Augusta/jobs/Ec...
# 11  https://www.indeed.com/company/Augusta/jobs/Ec...
# 12  https://www.indeed.com/company/Augusta/jobs/Ec...
# 13  https://www.indeed.com/company/Augusta/jobs/Ec...
# 14  https://www.indeed.com/company/Augusta/jobs/Ec...
# 15  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 16  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 17  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 18  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 19  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 20  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 21  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 22  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 23  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 24  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 25  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 26  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 27  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 28  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 29  https://www.indeed.com/rc/clk?jk=be578c7beba1e...
# 30  https://www.indeed.com/rc/clk?jk=be578c7beba1e...
# 31  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 32  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 33  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 34  https://www.indeed.com/rc/clk?jk=be578c7beba1e...
# 35  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 36  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 37  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 38  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 39  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 40  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 41  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
#
#                       location    salary
# 0    San Francisco, CA, 94134   100000.0
# 1        South Paris, ME, 4281  100000.0
# 2        Lake Orion, MI, 48362  100000.0
# 3           Boston, MA, 02116   100000.0
# 4      Grand Island, NE, 68801  100000.0
# 5           Boston, MA, 02109   100000.0
# 6           Boston, MA, 02110   100000.0
# 7           Boston, MA, 02116   100000.0
# 8           Denver, CO, 80207   100000.0
# 9     West Greenwich, RI, 2817  100000.0
# 10      Providence, RI, 02903   100000.0
# 11         Merrimack, NH, 3054  100000.0
# 12         Lakeville, MA, 2347  100000.0
# 13  Remote in Boston, MA, 2108  100000.0
# 14         Chubbuck, ID, 83202  100000.0
# 15     Grand Island, NE, 68801   90000.0
# 16   San Francisco, CA, 94134    90000.0
# 17      Providence, RI, 02903    90000.0
# 18       Lake Orion, MI, 48362   90000.0
# 19          Boston, MA, 02110    90000.0
# 20  Remote in Boston, MA, 2108   90000.0
# 21           Beverly, MA, 1915   90000.0
# 22         Merrimack, NH, 3054   90000.0
# 23       Cambridge, MA, 02139    90000.0
# 24   San Francisco, CA, 94134    90000.0
# 25     Grand Island, NE, 68801  107500.0
# 26       Lake Orion, MI, 48362  107500.0
# 27      Providence, RI, 02903   107500.0
# 28          Boston, MA, 02110   107500.0
# 29          Boston, MA, 02109   121000.0
# 30       South Paris, ME, 4281  121000.0
# 31          Boston, MA, 02110   107500.0
# 32          Denver, CO, 80207   107500.0
# 33       Lake Orion, MI, 48362  107500.0
# 34       Lake Orion, MI, 48362  121000.0
# 35      Providence, RI, 02903   107500.0
# 36   San Francisco, CA, 94134   107500.0
# 37    West Greenwich, RI, 2817  107500.0
# 38       Baltimore, MD, 21202   107500.0
# 39       South Paris, ME, 4281  107500.0
# 40          Boston, MA, 02116   107500.0
# 41          Boston, MA, 02109   107500.0

# %%
## Query 8

con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select j.company_name, j.job_type, l.city || ', ' || l.state || ', ' || l.zipcode as location from job_details j inner join job_location_details l where j.job_type = "Internship" and l.city LIKE "%Boston%";''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
r3
# Out:
#                     company_name    job_type            location
# 0      Carrier Klimatechnik GmbH  Internship  Boston, MA, 02109
# 1      Carrier Klimatechnik GmbH  Internship  Boston, MA, 02109
# 2      Carrier Klimatechnik GmbH  Internship  Boston, MA, 02109
# 3      Carrier Klimatechnik GmbH  Internship  Boston, MA, 02109
# 4                         Circle  Internship  Boston, MA, 02109
# ...                          ...         ...                 ...
# 23270                Veeder Root  Internship  Boston, MA, 02116
# 23271                Veeder Root  Internship  Boston, MA, 02116
# 23272                Veeder Root  Internship  Boston, MA, 02116
# 23273                Veeder Root  Internship  Boston, MA, 02116
# 23274                Veeder Root  Internship  Boston, MA, 02116
#
# [23275 rows x 3 columns]

# %%
## Query 9

con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select j.job_title, AVG(j.job_rating), c.company_name from job_details j inner join company_details c on j.company_name = c.company_name where j.job_title LIKE "%Developer%" group by j.job_title, c.company_name;''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
r3
# Out:
#                                             job_title  AVG(j.job_rating)  \
# 0                    2023 Intern - Software Developer                4.3
# 1                  2023 Internship: Backend Developer                3.9
# 2                      Angular Developer (Full Stack)                4.1
# 3                                Full Stack Developer                4.3
# 4                                Full Stack Developer                5.0
# 5                                Full Stack Developer                4.0
# 6            Full Stack JavaScript Developer - NO C2C                4.3
# 7            Full Stack Software Engineer / Developer                3.8
# 8                               IT Software Developer                4.2
# 9                    Integration Developer I - Remote                4.0
# 10                        Intern - Software Developer                3.5
# 11                     JR Software Developer (Remote)                2.7
# 12                            Java Back End Developer                3.8
# 13      Java Developer - Local Candidates Only Please                3.7
# 14                                 Jr. Java Developer                2.8
# 15                             Jr. Software Developer                3.5
# 16           Mid-Level Java Developer (with training)                2.8
# 17                        Remote Full-Stack Developer                3.7
# 18                        Senior Full Stack Developer                4.1
# 19  Senior Full Stack Developer - Opportunity for ...                4.1
# 20               Software Developer (Remote-Friendly)                4.1
# 21                         Software Developer 1 (MFE)                4.2
# 22                           Software Developer Co-Op                3.8
# 23                              Software Developer II                4.3
# 24                    Software Developer III - Remote                4.0
# 25                                      Web Developer                4.6
#
#                     company_name
# 0                          Adobe
# 1                            IBM
# 2        #twiceasnice Recruiting
# 3                 AllSTEM - Jobs
# 4                         Engtal
# 5                    Gridiron IT
# 6                     Neteffects
# 7      JPMorgan Chase Bank, N.A.
# 8              Miami-Dade County
# 9   Arkansas Children's Hospital
# 10                        Nelnet
# 11                       Jaggaer
# 12     JPMorgan Chase Bank, N.A.
# 13               The Judge Group
# 14                      Genspark
# 15       Amazon.com Services LLC
# 16                      GenSpark
# 17                   CyberCoders
# 18            Buchanan & Edwards
# 19                        VMware
# 20                      Vendasta
# 21                           MIT
# 22     Carrier Klimatechnik GmbH
# 23                NMR Consulting
# 24  Arkansas Children's Hospital
# 25                   Emonics LLC

# %%
## Query 10

con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select l.city || ', ' || l.state || ', ' || l.zipcode as Location from job_location_details l inner join job_details j on l.job_id = j.job_id where j.job_type = "Internship" and j.job_title LIKE "%Software Engineer%";''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
r3
# Out:
#                       Location
# 0      Grand Island, NE, 68801
# 1     West Greenwich, RI, 2817
# 2        Lake Orion, MI, 48362
# 3        South Paris, ME, 4281
# 4         Hartford, CT, 06105
# 5     West Greenwich, RI, 2817
# 6           Boston, MA, 02110
# 7          Chubbuck, ID, 83202
# 8           Boston, MA, 02109
# 9           Denver, CO, 80207
# 10    West Greenwich, RI, 2817
# 11          Boston, MA, 02116
# 12       Lake Orion, MI, 48362
# 13       South Paris, ME, 4281
# 14          Denver, CO, 80207
# 15          Boston, MA, 02110
# 16       Lake Orion, MI, 48362
# 17          Boston, MA, 02109
# 18          Denver, CO, 80207
# 19          Boston, MA, 02110
# 20   San Francisco, CA, 94134
# 21          Boston, MA, 02109
# 22      Providence, RI, 02903
# 23       Lake Orion, MI, 48362
# 24       South Paris, ME, 4281
# 25          Boston, MA, 02110
# 26         Chubbuck, ID, 83202
# 27   San Francisco, CA, 94134
# 28          Boston, MA, 02109
# 29      Providence, RI, 02903
# 30          Denver, CO, 80207
# 31        Hartford, CT, 06105
# 32     Grand Island, NE, 68801
# 33   San Francisco, CA, 94134
# 34          Boston, MA, 02110
# 35     Marlborough, MA, 01752
# 36    West Greenwich, RI, 2817
# 37          Boston, MA, 02116
# 38        Hartford, CT, 06105
# 39    West Greenwich, RI, 2817
# 40          Denver, CO, 80207
# 41        Hartford, CT, 06105
# 42          Denver, CO, 80207
# 43     Marlborough, MA, 01752
# 44          Boston, MA, 02109
# 45        Hartford, CT, 06105
# 46       Lake Orion, MI, 48362
# 47   San Francisco, CA, 94134
# 48  Remote in Boston, MA, 2108
# 49       Baltimore, MD, 21202
# 50       Huntsville, AL, 35808
# 51           Beverly, MA, 1915
# 52         Merrimack, NH, 3054

# %%
## Query 11

con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select j.job_link as URL from job_details j where job_title LIKE "%Java%" UNION Select c.company_website as URL from company_details c where c.company_name LIKE "%Cigna%";''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
r3
# Out:
#                                                   URL
# 0                    https://www.indeed.com/cmp/Cigna
# 1   https://www.indeed.com/company/GenSpark/jobs/J...
# 2   https://www.indeed.com/company/GenSpark/jobs/M...
# 3   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 5   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 6   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 7   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 8   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 9   https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 10  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 11  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 12  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 13  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 14  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 15  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 16  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 17  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 18  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 19  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 20  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 21  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 22  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 23  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 24  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 25  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 26  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 27  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 28  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 29  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 30  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 31  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 32  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 33  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 34  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 35  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 36  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 37  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 38  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 39  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 40  https://www.indeed.com/rc/clk?jk=0069738a858a0...
# 41  https://www.indeed.com/rc/clk?jk=3152d5516021d...
# 42  https://www.indeed.com/rc/clk?jk=c27909b0a23a1...

# %%
## Query 12

con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select j.job_title, j.job_link, s.min_salary as salary from job_details j inner join salary_details s on j.job_id = s.job_id where j.job_title LIKE "%Co-op%" group by j.job_title,s.min_salary, j.job_link having avg(j.job_rating) > 3.0;''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
r3
# Out:
#                                            job_title  \
# 0     Co-op Software Development Engineer- 2023 (US)
# 1                           Software Developer Co-Op
# 2   Software Engineer Co-Op (Spring 2023 - Yarmouth)
# 3  Software Engineering Co-Op - Med Devices Janua...
#
#                                             job_link        salary
# 0  https://www.indeed.com/rc/clk?jk=4dedded7ed5b4...   9137.000000
# 1  https://www.indeed.com/rc/clk?jk=a27f7ca274631...      0.000000
# 2  https://www.indeed.com/rc/clk?jk=5a748f5c432c9...      1.000000
# 3  https://www.indeed.com/rc/clk?jk=91d141b6b62c1...  68641.781811

# %%
## Query 13

con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select j.job_title, j.job_link, s.min_salary as salary from job_details j inner join salary_details s on j.job_id = s.job_id where j.job_post_date >= DATE("now", "-30 day");''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
r3
# Out:
# Empty DataFrame
# Columns: [job_title, job_link, salary]
# Index: []

# %%
## Query 14

con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select j.job_title, l.city || ', ' || l.state || ', ' || l.zipcode as location, j.job_desc, j.job_type from job_details j inner join job_location_details l on j.job_id = l.job_id where j.job_type = "Contract";''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
r3
# Out:
#                job_title                   location  \
# 0   Service Desk Analyst    Grand Island, NE, 68801
# 1  Due Diligence Analyst    Grand Island, NE, 68801
# 2  Due Diligence Analyst         Boston, MA, 02109
# 3  Due Diligence Analyst  San Francisco, CA, 94134
# 4  Due Diligence Analyst         Boston, MA, 02116
#
#                                             job_desc  job_type
# 0  Monitor and answer the Service Desk phone, e-m...  Contract
# 1  7+ years of experience in the residential mort...  Contract
# 2  7+ years of experience in the residential mort...  Contract
# 3  7+ years of experience in the residential mort...  Contract
# 4  7+ years of experience in the residential mort...  Contract

# %%
## Query 15

con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select j.job_title, j.job_link, c.company_website, j.job_type, s.min_salary as salary, l.city || ', ' || l.state || ', ' || l.zipcode as location from job_details j inner join company_details c on j.company_name = c.company_name inner join salary_details s on j.job_id = s.job_id inner join job_location_details l on j.job_id = l.job_id where l.state LIKE "%MA%" and j.job_title LIKE "%Software%";''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
r3
# Out:
#                                      job_title  \
# 0             2023 Intern - Software Developer
# 1          Onshape Software Engineering Intern
# 2    Software Engineering Intern (Summer 2023)
# 3              Software Engineer Intern, Audio
# 4       Software Engineer Intern (Summer 2023)
# ..                                         ...
# 140            Software Developer III - Remote
# 141                  Jr Software Engineer Java
# 142                          Software Engineer
# 143       Software Engineer I (Remote Option*)
# 144                      IT Software Developer
#
#                                               job_link  \
# 0    https://www.indeed.com/rc/clk?jk=9b239bcadff12...
# 1    https://www.indeed.com/rc/clk?jk=b99c8db751fe6...
# 2    https://www.indeed.com/rc/clk?jk=3faf42dbd2873...
# 3    https://www.indeed.com/rc/clk?jk=3f615609afbde...
# 4    https://www.indeed.com/rc/clk?jk=584ececefd063...
# ..                                                 ...
# 140  https://www.indeed.com/rc/clk?jk=f757e8ca08988...
# 141  https://www.indeed.com/rc/clk?jk=0069738a858a0...
# 142  https://www.indeed.com/company/Hexure/jobs/Sof...
# 143  https://www.indeed.com/rc/clk?jk=c2b8034e5dd8b...
# 144  https://www.indeed.com/rc/clk?jk=0c6201a24f1d0...
#
#                                        company_website       job_type  \
# 0                     https://www.indeed.com/cmp/Adobe  Full-time\n+1
# 1              https://www.indeed.com/cmp/Ptc-c5e4d329     Internship
# 2                   https://www.indeed.com/cmp/Dropbox  Full-time\n+1
# 3                    https://www.indeed.com/cmp/Roku-1     Internship
# 4                   https://www.indeed.com/cmp/Netflix     Internship
# ..                                                 ...            ...
# 140  https://www.indeed.com/cmp/Arkansas-Children's...      Full-time
# 141             https://www.indeed.com/cmp/Vsolvit-LLC      Full-time
# 142                https://www.indeed.com/cmp/Hexure-1      Full-time
# 143                    https://www.indeed.com/cmp/Nike      Full-time
# 144       https://www.indeed.com/cmp/Miami-Dade-County      Full-time
#
#             salary            location
# 0     79800.000000  Boston, MA, 02116
# 1      4000.000000  Boston, MA, 02110
# 2     68641.781811  Boston, MA, 02116
# 3     68641.781811  Boston, MA, 02109
# 4     76200.000000  Boston, MA, 02116
# ..             ...                 ...
# 140   68641.781811  Boston, MA, 02110
# 141      35.000000  Boston, MA, 02110
# 142   68000.000000  Boston, MA, 02110
# 143  107500.000000  Boston, MA, 02109
# 144   73674.000000  Boston, MA, 02116
#
# [145 rows x 6 columns]

# %%
con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select j.job_title, j.job_link, j.job_type, s.min_salary as salary from job_details j inner join salary_details s on j.job_id = s.job_id where j.job_type LIKE "%Full-time%" and j.job_title LIKE "%Intern%";''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
# Out:
#                           job_title  \
# 0  2023 Intern - Software Developer
#
#                                             job_link       job_type   salary
# 0  https://www.indeed.com/rc/clk?jk=9b239bcadff12...  Full-time\n+1  79800.0

# %%
con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select c.company_name from company_details c inner join job_details j on c.company_name = j.company_name where j.job_title LIKE "%Full Stack%" group by c.company_name having max(j.job_rating) > 4.2;''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
# Out:
#      company_name
# 0  AllSTEM - Jobs

# %%
con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select j.job_title, AVG(j.job_rating), c.company_name from job_details j inner join company_details c on j.company_name = c.company_name where j.job_title LIKE "%Developer%" group by j.job_title, c.company_name;''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
# Out:
#                           job_title  AVG(j.job_rating) company_name
# 0  2023 Intern - Software Developer                4.3        Adobe

# %%
con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select j.job_link as URL from job_details j where job_title LIKE "%Java%" UNION Select c.company_website as URL from company_details c where c.company_name LIKE "%Cigna%";''')

r3 = pd.read_sql(q1, con)
r3.head(1)
#print(r1)
# Out:
#                                 URL
# 0  https://www.indeed.com/cmp/Cigna

# %%
con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select j.job_title, j.job_link, j.company_name, j.job_rating from job_details j inner join job_hashtags h on j.job_id = h.job_id where h.hashtags in (select skillset from user_skillset_details where user_platform_name = "@Hilton");''')

r3 = pd.read_sql(q1, con)
r3.head(1)
# Out:
# Empty DataFrame
# Columns: [job_title, job_link, company_name, job_rating]
# Index: []

# %%
con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''Select j.job_title, j.job_link, c.company_name, c.company_website from job_details inner join company_details c on j.company_name = c.company_name where j.job_post_date >= DATE('now', '-7 day')");''')

r3 = pd.read_sql(q1, con)
r3.head(1)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:2020, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2019 try:
# -> 2020     cur.execute(*args, **kwargs)
#    2021     return cur
#
# OperationalError: unrecognized token: "");"
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Input In [77], in <cell line: 5>()
#       1 con = sqlite3.connect('JobsFinalDatabase.db')
#       2 q1 = (
#       3 '''Select j.job_title, j.job_link, c.company_name, c.company_website from job_details inner join company_details c on j.company_name = c.company_name where j.job_post_date >= DATE('now', '-7 day')");''')
# ----> 5 r3 = pd.read_sql(q1, con)
#       6 r3.head(1)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:566, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     563 pandas_sql = pandasSQL_builder(con)
#     565 if isinstance(pandas_sql, SQLiteDatabase):
# --> 566     return pandas_sql.read_query(
#     567         sql,
#     568         index_col=index_col,
#     569         params=params,
#     570         coerce_float=coerce_float,
#     571         parse_dates=parse_dates,
#     572         chunksize=chunksize,
#     573     )
#     575 try:
#     576     _is_table_name = pandas_sql.has_table(sql)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:2080, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2068 def read_query(
#    2069     self,
#    2070     sql,
#    (...)
#    2076     dtype: DtypeArg | None = None,
#    2077 ):
#    2079     args = _convert_params(sql, params)
# -> 2080     cursor = self.execute(*args)
#    2081     columns = [col_desc[0] for col_desc in cursor.description]
#    2083     if chunksize is not None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/sql.py:2032, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2029     raise ex from inner_exc
#    2031 ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2032 raise ex from exc
#
# DatabaseError: Execution failed on sql 'Select j.job_title, j.job_link, c.company_name, c.company_website from job_details inner join company_details c on j.company_name = c.company_name where j.job_post_date >= DATE('now', '-7 day')");': unrecognized token: "");"
