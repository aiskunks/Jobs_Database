# %%
import pandas as pd
from datetime import datetime, timedelta

# %%
import sqlite3
import plotly.express as px

# %%
dfdb = pd.read_csv("JobsNormalize.csv")
dfdb
# Out:
#       Unnamed: 0                                         Job_Titile  \
# 0              0                   Board Certified Behavior Analyst
# 1              1  Economic Analyst – Remote ***Guaranteed minimu...
# 2              2                                 Recruiting Analyst
# 3              3              Legal Compliance Analyst - Hybrid job
# 4              4  Board Certified Behavior Analyst (BCBA) - Cape...
# ...          ...                                                ...
# 3777        3777                Software Engineer (Remote USA Only)
# 3778        3778                         Graduate Software Engineer
# 3779        3779  2023 University Graduate - Software Developmen...
# 3780        3780            Software Engineer (Remote Work Options)
# 3781        3781                                Software Engineer 1
#
#                                                 Job_URL  \
# 0     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1     https://www.indeed.com/company/Augusta/jobs/Ec...
# 2     https://www.indeed.com/rc/clk?jk=fc9e8f57f0724...
# 3     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# ...                                                 ...
# 3777  https://www.indeed.com/rc/clk?jk=2d1bcaf75519d...
# 3778  https://www.indeed.com/rc/clk?jk=ab60705252c60...
# 3779  https://www.indeed.com/rc/clk?jk=5d518aade2b7c...
# 3780  https://www.indeed.com/rc/clk?jk=fdfd4880ee0af...
# 3781  https://www.indeed.com/rc/clk?jk=c321400a3836d...
#
#                                             Company_URL  \
# 0     https://www.indeed.com/cmp/North-Oakland-Autis...
# 1                  https://www.indeed.com/cmp/Augusta-7
# 2                    https://www.indeed.com/cmp/Discord
# 3                   https://www.indeed.com/cmp/Odoo-Inc
# 4                                                   NaN
# ...                                                 ...
# 3777                https://www.indeed.com/cmp/Experian
# 3778                  https://www.indeed.com/cmp/Wise-6
# 3779                   https://www.indeed.com/cmp/Adobe
# 3780       https://www.indeed.com/cmp/Shelter-Insurance
# 3781  https://www.indeed.com/cmp/Pacific-Northwest-N...
#
#                                     Company  Rating  \
# 0               North Oakland Autism Center     3.9
# 1                   Augusta Precious Metals     3.8
# 2                                   Discord     4.3
# 3                                  Odoo Inc     4.5
# 4                                       NaN     NaN
# ...                                     ...     ...
# 3777                               Experian     3.6
# 3778                                   Wise     4.1
# 3779                                  Adobe     4.3
# 3780                      Shelter Insurance     3.7
# 3781  Pacific Northwest National Laboratory     4.0
#
#                          Salary       Job_Tyoe  \
# 0      $50,000 - $90,000 a year  Full-time\n+1
# 1          From $100,000 a year  Full-time\n+1
# 2               $133,000 a year            NaN
# 3     $75,000 - $110,000 a year      Full-time
# 4      $70,000 - $85,000 a year  Full-time\n+1
# ...                         ...            ...
# 3777                  Full-time      Full-time
# 3778                  Full-time      Full-time
# 3779                  Full-time      Full-time
# 3780             $68,640 a year  Full-time\n+1
# 3781                  Full-time      Full-time
#
#                                         Job_description Post_Date State  \
# 0     Our ideal candidate will competently manage a ...  11/13/22    MI
# 1     We will provide in-house systems and complianc...  12/08/22   NaN
# 2     Colorado residents only: Minimum salary of $10...  11/13/22   NaN
# 3     Odoo ERP system is enterprise resource plannin...       NaN    CA
# 4     Full-time salaried positions: Monday-Friday (w...  11/13/22    MA
# ...                                                 ...       ...   ...
# 3777  In addition to a competitive base salary and v...  12/11/22   NaN
# 3778  At Wise you'll work on challenging technical p...  12/09/22   NaN
# 3779  Adobe is seeking talented and passionate Softw...  11/17/22   NaN
# 3780  Develop, test, maintain and document software ...  12/11/22   NaN
# 3781  The candidate will be required to communicate ...  12/07/22   NaN
#
#                              Location
# 0                 Lake Orion MI 48362
# 1             San Francisco CA 94134
# 2                         Hyannis MA
# 3                 South Paris ME 4281
# 4                     Hyattsville MD
# ...                               ...
# 3777             Providence RI 02903
# 3778  Hybrid remote in Boston MA 2110
# 3779                 Boston MA 02116
# 3780       Remote in Hartford CT 6152
# 3781       Remote in Hartford CT 6102
#
# [3782 rows x 12 columns]

# %% [markdown]
# Inital Table

# %%
#connection to the Database
conn = sqlite3.connect('JobsFinalDatabase.db')

try:
    conn.cursor()
    print("DB Connected");
except Exception as ex:
    print("DB not Connected");
# Out:
# DB Connected

# %%
#Create table JOBS_LISTING_TABLE
conn = sqlite3.connect('JobsFinalDatabase.db')
print("Opened database successfully");
conn.execute('''DROP TABLE IF EXISTS job_basic_details;''')
conn.execute('''CREATE TABLE IF NOT EXISTS job_basic_details
         (
        job_title TEXT,
        company_name TEXT,
        location TEXT,
        salary TEXT,
        job_type TEXT,
        job_post_date datetime,
        job_rating Float,
        job_link TEXT,
        job_desc TEXT,
        company_website TEXT
         );''')

print("job_basic_details Table created successfully");

conn.close()
# Out:
# Opened database successfully
# job_basic_details Table created successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
print("Opened database successfully");
conn.execute('''DROP TABLE IF EXISTS user_basic_details;''')
conn.execute('''CREATE TABLE IF NOT EXISTS user_basic_details
         (
        user_name TEXT  ,
        dob datetime,
        user_location TEXT,
        mobile_number TEXT,
        email_id TEXT,
        portfolio_link TEXT,
        skillset TEXT,
        saved_application_id TEXT,
        certifications TEXT
         );''')

print("user_basic_details Table created successfully");

conn.close()
# Out:
# Opened database successfully
# user_basic_details Table created successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
print("Opened database successfully");
conn.execute('''DROP TABLE IF EXISTS user_login_basic_details;''')
conn.execute('''CREATE TABLE IF NOT EXISTS user_login_basic_details
         (
        user_platform_name TEXT  ,
        user_password TEXT,
        user_role TEXT
         );''')

print("user_login_basic_details Table created successfully");

conn.close()
# Out:
# Opened database successfully
# user_login_basic_details Table created successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
for row in dfdb.itertuples():
    conn.execute('INSERT or IGNORE INTO job_basic_details(job_title, company_name, location, salary, job_type, job_post_date, job_rating, job_link, job_desc, company_website) VALUES (?,?,?,?,?,?,?,?,?,?)',(
                row.Job_Titile, 
                row.Company,
                row.Location,
                row.Salary,
                row.Job_Tyoe,
                row.Post_Date,
                row.Rating,
                row.Job_URL,
                row.Job_description,
                row.Company_URL
                )
                )
    conn.commit()
print("job_basic_details Table values inserted successfully");
conn.close()
# Out:
# job_basic_details Table values inserted successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
for row in dfdb.itertuples():
    conn.execute('INSERT or IGNORE INTO job_basic_details(job_title, company_name, location, salary, job_type, job_post_date, job_rating, job_link, job_desc, company_website) VALUES (?,?,?,?,?,?,?,?,?,?)',(
                row.Job_Titile, 
                row.Company,
                row.Location,
                row.Salary,
                row.Job_Tyoe,
                row.Post_Date,
                row.Rating,
                row.Job_URL,
                row.Job_description,
                row.Company_URL
                )
                )
    conn.commit()
print("job_basic_details Table values inserted successfully");
conn.close()
# Out:
# job_basic_details Table values inserted successfully

# %%
con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''SELECT * from job_basic_details;''')

r1 = pd.read_sql(q1, con)
r1.head(1)
#print(r1)
r1
# Out:
#                                               job_title  \
# 0                      Board Certified Behavior Analyst
# 1     Economic Analyst – Remote ***Guaranteed minimu...
# 2                                    Recruiting Analyst
# 3                 Legal Compliance Analyst - Hybrid job
# 4     Board Certified Behavior Analyst (BCBA) - Cape...
# ...                                                 ...
# 7559                Software Engineer (Remote USA Only)
# 7560                         Graduate Software Engineer
# 7561  2023 University Graduate - Software Developmen...
# 7562            Software Engineer (Remote Work Options)
# 7563                                Software Engineer 1
#
#                                company_name                         location  \
# 0               North Oakland Autism Center              Lake Orion MI 48362
# 1                   Augusta Precious Metals          San Francisco CA 94134
# 2                                   Discord                      Hyannis MA
# 3                                  Odoo Inc              South Paris ME 4281
# 4                                      None                  Hyattsville MD
# ...                                     ...                              ...
# 7559                               Experian             Providence RI 02903
# 7560                                   Wise  Hybrid remote in Boston MA 2110
# 7561                                  Adobe                 Boston MA 02116
# 7562                      Shelter Insurance       Remote in Hartford CT 6152
# 7563  Pacific Northwest National Laboratory       Remote in Hartford CT 6102
#
#                          salary       job_type job_post_date  job_rating  \
# 0      $50,000 - $90,000 a year  Full-time\n+1      11/13/22         3.9
# 1          From $100,000 a year  Full-time\n+1      12/08/22         3.8
# 2               $133,000 a year           None      11/13/22         4.3
# 3     $75,000 - $110,000 a year      Full-time          None         4.5
# 4      $70,000 - $85,000 a year  Full-time\n+1      11/13/22         NaN
# ...                         ...            ...           ...         ...
# 7559                  Full-time      Full-time      12/11/22         3.6
# 7560                  Full-time      Full-time      12/09/22         4.1
# 7561                  Full-time      Full-time      11/17/22         4.3
# 7562             $68,640 a year  Full-time\n+1      12/11/22         3.7
# 7563                  Full-time      Full-time      12/07/22         4.0
#
#                                                job_link  \
# 0     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1     https://www.indeed.com/company/Augusta/jobs/Ec...
# 2     https://www.indeed.com/rc/clk?jk=fc9e8f57f0724...
# 3     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4     https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# ...                                                 ...
# 7559  https://www.indeed.com/rc/clk?jk=2d1bcaf75519d...
# 7560  https://www.indeed.com/rc/clk?jk=ab60705252c60...
# 7561  https://www.indeed.com/rc/clk?jk=5d518aade2b7c...
# 7562  https://www.indeed.com/rc/clk?jk=fdfd4880ee0af...
# 7563  https://www.indeed.com/rc/clk?jk=c321400a3836d...
#
#                                                job_desc  \
# 0     Our ideal candidate will competently manage a ...
# 1     We will provide in-house systems and complianc...
# 2     Colorado residents only: Minimum salary of $10...
# 3     Odoo ERP system is enterprise resource plannin...
# 4     Full-time salaried positions: Monday-Friday (w...
# ...                                                 ...
# 7559  In addition to a competitive base salary and v...
# 7560  At Wise you'll work on challenging technical p...
# 7561  Adobe is seeking talented and passionate Softw...
# 7562  Develop, test, maintain and document software ...
# 7563  The candidate will be required to communicate ...
#
#                                         company_website
# 0     https://www.indeed.com/cmp/North-Oakland-Autis...
# 1                  https://www.indeed.com/cmp/Augusta-7
# 2                    https://www.indeed.com/cmp/Discord
# 3                   https://www.indeed.com/cmp/Odoo-Inc
# 4                                                  None
# ...                                                 ...
# 7559                https://www.indeed.com/cmp/Experian
# 7560                  https://www.indeed.com/cmp/Wise-6
# 7561                   https://www.indeed.com/cmp/Adobe
# 7562       https://www.indeed.com/cmp/Shelter-Insurance
# 7563  https://www.indeed.com/cmp/Pacific-Northwest-N...
#
# [7564 rows x 10 columns]

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
conn.execute('INSERT or IGNORE INTO user_basic_details(user_name, dob, user_location, mobile_number, email_id, portfolio_link, skillset, saved_application_id, certifications) VALUES (?,?,?,?,?,?,?,?,?)',(
                "@Hilton", 
                "1998-04-02",
                "Boston,MA,02345",
                "7658904321",
                "hilton.savage@gmail.com",
                "www.hilton.com",
                "Java, Software, Database",
                "123, 234, 345",
                "CFA, AWS CCP"
                )
                )
conn.commit()
print("user_basic_details Table values inserted successfully");
conn.close()
# Out:
# user_basic_details Table values inserted successfully

# %%
conn = sqlite3.connect('JobsFinalDatabase.db')
conn.execute('INSERT or IGNORE INTO user_login_basic_details(user_platform_name, user_password, user_role) VALUES (?,?,?)',(
                "@Hilton", 
                "Hilton@123",
                "seeker"
                )
                )
conn.commit()
print("user_login_basic_details Table values inserted successfully");
conn.close()
# Out:
# user_login_basic_details Table values inserted successfully

# %% [markdown]
# 1NF Form

# %%
con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''SELECT * from user_basic_details;''')

r1 = pd.read_sql(q1, con)
r1.head(1)
#print(r1)
r1
# Out:
#   user_name         dob    user_location mobile_number  \
# 0   @Hilton  1998-04-02  Boston,MA,02345    7658904321
#
#                   email_id  portfolio_link                  skillset  \
# 0  hilton.savage@gmail.com  www.hilton.com  Java, Software, Database
#
#   saved_application_id certifications
# 0        123, 234, 345   CFA, AWS CCP

# %%
con = sqlite3.connect('JobsFinalDatabase.db')
q1 = (
'''SELECT * from user_login_basic_details;''')

r1 = pd.read_sql(q1, con)
r1.head(1)
#print(r1)
r1
# Out:
#   user_platform_name user_password user_role
# 0            @Hilton    Hilton@123    seeker
