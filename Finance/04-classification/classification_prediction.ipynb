# %% [markdown]
# # Simple Classification Model with SVM
# ## Purpose
# Build a classification mode using svm which can be used to predict the job title based on the skill set
#
# ## Steps
# 1. Normalize title and skill fields
# 2. Vectorize skill
# 3. Label encode titles
# 4. Create SVM model and train the model
# 5. Make prediction: Vectorize skillset and use it as an input to the model, inverse transform the result into human readable text
#
# ## Method Used
# * Support Vector Machine
# * Cross Validation
#
# ## Conclusion
# * Prediction works as expected
# * Cross validation score isn't good enough since the job titles in the data are not normalized enough

# %%
import json
import re
import unidecode
import numpy as np
import pandas as pd
from collections import defaultdict
from nltk.stem import WordNetLemmatizer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import cross_validate
from sklearn.multiclass import OneVsRestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline, make_union
from sklearn.preprocessing import FunctionTransformer, LabelEncoder
from tqdm import tqdm
import nltk
from matplotlib import pyplot as plt
import seaborn as sns
tqdm.pandas()
from nltk import word_tokenize
from nltk.corpus import stopwords

# %%
train = pd.read_csv('../00-data/jobdb.csv')

# %%
train['title_simp']=''
train.head()
# Out:
#                                                title  \
# 0                 Computer Vision Scientist/Engineer
# 1                    Staff Computer Vision Scientist
# 2      Data Scientist, Deep Learning/Computer Vision
# 3                  Computer Vision Research Engineer
# 4  Senior Software Engineer for OFP Development F...
#
#                        company          location  \
# 0  Expedition Technology, Inc.        Dulles, VA
# 1                       WeWork     Palo Alto, CA
# 2                       Yummly  Redwood City, CA
# 3  Expedition Technology, Inc.        Dulles, VA
# 4           Decisive Analytics        Dayton, OH
#
#                                          description  \
# 0  Computer Vision Scientist/Engineer\r\r\r\n\r\r...
# 1  Research Scientist/Manager:\r\r\r\nComputer Vi...
# 2  Born from the belief that great things come to...
# 3  Computer Vision Research Engineer\r\r\r\n\r\r\...
# 4  Overview\r\r\r\n\r\r\r\nDECISIVE ANALYTICS Cor...
#
#                          salary  \
# 0                           NaN
# 1                           NaN
# 2  $124K-$170K (Glassdoor est.)
# 3                           NaN
# 4    $53K-$94K (Glassdoor est.)
#
#                                                 link  \
# 0                                                NaN
# 1  https://www.glassdoor.com/partner/jobListing.h...
# 2  https://www.glassdoor.com/partner/jobListing.h...
# 3                                                NaN
# 4  https://www.glassdoor.com/partner/jobListing.h...
#
#                              skills    education title_simp
# 0  r,python,c/c++,julia,c++,pytorch    bs,phd,ms
# 1                      r,python,c++       phd,ms
# 2                          python,r           ms
# 3                          python,r  bachelor,ms
# 4                                 r        bs,ms

# %%
#get the skills and concatenate using space
def preprocess(ingredients):
    words = []
    for word in str(ingredients).split(','):
        if len(word) > 0: words.append(word)
    return ' '.join(words)

#lower case the description and remove stopwords
def tokenize_title(description):
    tokens = word_tokenize(description)
    stopset = set(stopwords.words('english'))
    tokens = [w.lower() for w in tokens if not w in stopset]
    text = ' '.join(nltk.Text(tokens))
    return text

# %%
train['x'] = train['skills'].progress_apply(preprocess)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 677/677 [00:00<00:00, 225557.53it/s]

# %%
train['title_simp']=train['title'].apply(tokenize_title)
train.head()
# Out:
#                                                title  \
# 0                 Computer Vision Scientist/Engineer
# 1                    Staff Computer Vision Scientist
# 2      Data Scientist, Deep Learning/Computer Vision
# 3                  Computer Vision Research Engineer
# 4  Senior Software Engineer for OFP Development F...
#
#                        company          location  \
# 0  Expedition Technology, Inc.        Dulles, VA
# 1                       WeWork     Palo Alto, CA
# 2                       Yummly  Redwood City, CA
# 3  Expedition Technology, Inc.        Dulles, VA
# 4           Decisive Analytics        Dayton, OH
#
#                                          description  \
# 0  Computer Vision Scientist/Engineer\r\r\r\n\r\r...
# 1  Research Scientist/Manager:\r\r\r\nComputer Vi...
# 2  Born from the belief that great things come to...
# 3  Computer Vision Research Engineer\r\r\r\n\r\r\...
# 4  Overview\r\r\r\n\r\r\r\nDECISIVE ANALYTICS Cor...
#
#                          salary  \
# 0                           NaN
# 1                           NaN
# 2  $124K-$170K (Glassdoor est.)
# 3                           NaN
# 4    $53K-$94K (Glassdoor est.)
#
#                                                 link  \
# 0                                                NaN
# 1  https://www.glassdoor.com/partner/jobListing.h...
# 2  https://www.glassdoor.com/partner/jobListing.h...
# 3                                                NaN
# 4  https://www.glassdoor.com/partner/jobListing.h...
#
#                              skills    education  \
# 0  r,python,c/c++,julia,c++,pytorch    bs,phd,ms
# 1                      r,python,c++       phd,ms
# 2                          python,r           ms
# 3                          python,r  bachelor,ms
# 4                                 r        bs,ms
#
#                                           title_simp  \
# 0                 computer vision scientist/engineer
# 1                    staff computer vision scientist
# 2     data scientist , deep learning/computer vision
# 3                  computer vision research engineer
# 4  senior software engineer ofp development f-15 ...
#
#                                   x
# 0  r python c/c++ julia c++ pytorch
# 1                      r python c++
# 2                          python r
# 3                          python r
# 4                                 r

# %%
#Verctorize the skills as predictors
vectorizer = make_pipeline(
    TfidfVectorizer(sublinear_tf=True),
    FunctionTransformer(lambda x: x.astype('float16'), validate=False)
)

x_train = vectorizer.fit_transform(train['x'].values)
x_train.sort_indices()

# %%
#label encode the title as target
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train['title_simp'].values)
dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
# Out:
# {'-computer vision research scientist': 0,
#  'ai bootcamp experienced machine learning engineers data scientists': 1,
#  'ai research scientist - computer vision': 2,
#  'applied artificial intelligence machine learning-scientist/engineer ( patuxent river , md orlando , florida )': 3,
#  'applied research scientist , computer vision': 4,
#  'applied research scientist - machine learning': 5,
#  'applied scientist , machine learning': 6,
#  'applied scientist - artificial intelligence': 7,
#  'applied scientist - computer vision': 8,
#  'c++ computer vision software engineer': 9,
#  'c++ software engineer - advanced visualization': 10,
#  'camera software - imaging computer vision research engineer': 11,
#  'co-op software engineer - machine learning ( summer & fall 2019 )': 12,
#  'computer scientist ( machine learning ) , vision systems group': 13,
#  'computer scientist , vision & learning': 14,
#  'computer scientist / neural networks , computer vision ( active ts/sci )': 15,
#  'computer scientist/vision engineer': 16,
#  'computer vision': 17,
#  'computer vision & deep learning engineer': 18,
#  'computer vision & deep learning research scientist': 19,
#  'computer vision / deep learning - visual inertial odometry': 20,
#  'computer vision / deep learning intern': 21,
#  'computer vision / machine learning developer': 22,
#  'computer vision / machine learning engineer': 23,
#  'computer vision / machine learning research engineer': 24,
#  'computer vision algorithm engineer': 25,
#  'computer vision camera systems engineer': 26,
#  'computer vision developer intern': 27,
#  'computer vision engineer': 28,
#  'computer vision engineer ( all experience levels jr. – sr . )': 29,
#  'computer vision engineer ( perception algorithms )': 30,
#  'computer vision engineer , 3d reconstruction': 31,
#  'computer vision engineer , 3d vision': 32,
#  'computer vision engineer , c-sats , inc .': 33,
#  'computer vision engineer , embedded': 34,
#  'computer vision engineer , self-driving': 35,
#  'computer vision engineer , self-driving - san francisco': 36,
#  'computer vision engineer - intern': 37,
#  'computer vision engineer / augmented reality designer': 38,
#  'computer vision intern': 39,
#  'computer vision intern ( academic year )': 40,
#  'computer vision machine learning engineer phd': 41,
#  'computer vision platform engineer': 42,
#  'computer vision postdoctoral scholar': 43,
#  'computer vision research engineer': 44,
#  'computer vision research engineer , uber ai': 45,
#  'computer vision research engineer intern , uber ai': 46,
#  'computer vision research scientist': 47,
#  'computer vision research scientist ( phd student grad )': 48,
#  'computer vision research scientist / architect ( slam robotics )': 49,
#  'computer vision researcher/engineer': 50,
#  'computer vision robotics manager': 51,
#  'computer vision scientist': 52,
#  'computer vision scientist ( deep learning exp )': 53,
#  'computer vision scientist - exciting robotics company': 54,
#  'computer vision scientist/engineer': 55,
#  'computer vision scientist/engineer , autopilot': 56,
#  'computer vision scientist/engineer-perception': 57,
#  'computer vision software engineer': 58,
#  'computer vision software engineer - intern': 59,
#  'computer vision software engineer - relocation': 60,
#  'computer vision summer intern ( sf )': 61,
#  'computer vision sw engineer': 62,
#  'computer vision/deep learning research engineer': 63,
#  'data analyst - computer vision': 64,
#  'data scientist ( machine learning )': 65,
#  'data scientist , computer vision': 66,
#  'data scientist , deep learning/computer vision': 67,
#  'data scientist , machine learning intern , summer 2019': 68,
#  'data scientist - actimize division': 69,
#  'data scientist - computer vision': 70,
#  'data scientist - computer vision specialization': 71,
#  'data scientist - machine learning': 72,
#  'data scientist - machine vision': 73,
#  'data scientist / computer vision engineer - r & d': 74,
#  'data scientist ai computer vision experience': 75,
#  'data scientist machine vision': 76,
#  'data scientist/ computer vision specialization': 77,
#  'deep learning / computer vision research software engineer': 78,
#  'deep learning engineer ( computer vision )': 79,
#  'deep learning scientist': 80,
#  'dsp software engineer - image signal processing , computer vision , neural network': 81,
#  'farmwise.io - senior computer vision scientist/engineer': 82,
#  'full stack developer specialty mobile app computer vision - summer intern': 83,
#  'image analytics scientist': 84,
#  'image processing/computer vision specialist': 85,
#  'image signal processing scientist': 86,
#  'imagery data scientist': 87,
#  'intern robotics lab research': 88,
#  'intern- computer vision engineering': 89,
#  'internship : machine learning computer vision': 90,
#  'internship : understanding deep learning': 91,
#  'jr computer vision / slam / 3d reconstruction engineer': 92,
#  'jr. data scientist ( image processing / computer vision )': 93,
#  'jr/mid level visualization software engineer': 94,
#  'junior computer vision engineer': 95,
#  'lead algorithm engineer - computer vision !': 96,
#  'lead computer vision scientist': 97,
#  'lead machine learning data scientist': 98,
#  'lead machine learning engineer , entity understanding': 99,
#  'lead machine learning scientist': 100,
#  'lead scientist - image analytics': 101,
#  'lead software engineer , cloud-based computer vision': 102,
#  'leanpath summer intern java backend machine vision': 103,
#  'machine learning / computer vision / ai engineer': 104,
#  'machine learning / computer vision engineer': 105,
#  'machine learning /computer vision engineer , san francisco or': 106,
#  'machine learning /computer vision engineer , san francisco or mountain view , ca': 107,
#  'machine learning computer vision engineer': 108,
#  'machine learning data scientist': 109,
#  'machine learning engineer': 110,
#  'machine learning engineer - active ts/sci required': 111,
#  'machine learning engineer - ai , ml , algorithms': 112,
#  'machine learning research scientist': 113,
#  'machine learning scientist': 114,
#  'machine learning scientist , computer vision': 115,
#  'machine learning scientist , digital & computational pathology': 116,
#  'machine learning scientist - speech - computer vision': 117,
#  'machine learning scientist intern - summer internship': 118,
#  'machine learning scientist with audio dsp background': 119,
#  'machine learning senior scientist': 120,
#  'machine learning/computer vision engineer': 121,
#  'machine learning/computer vision scientist': 122,
#  'machine vision engineer': 123,
#  'manager , computer vision': 124,
#  'ml engineer ( computer vision )': 125,
#  'natural language processing machine learning engineer': 126,
#  'postdoctoral scientist - image processing computer vision': 127,
#  'principal ai scientist - machine learning': 128,
#  'principal computer vision/deep learning engineer': 129,
#  'principal data scientist / computer vision engineer': 130,
#  'principal machine learning/computer vision scientist': 131,
#  'principal research scientist - computer vision machine learning': 132,
#  'principal scientist , machine learning': 133,
#  'principal software engineer - machine learning': 134,
#  'prinipal artificial intelligence advisor ( top secret clearance )': 135,
#  'raytheon vision systems - senior multi-disciplined engineer i': 136,
#  'research engineer , computer vision': 137,
#  'research engineer , image processing': 138,
#  'research engineer - computer vision': 139,
#  'research engineer : deep learning computer vision': 140,
#  'research scientist ( computer vision )': 141,
#  'research scientist , 3d computer vision & state estimation ( phd student grad )': 142,
#  'research scientist , computer vision': 143,
#  'research scientist , computer vision ( phd student grad )': 144,
#  'research scientist , computer vision ( phd university grad )': 145,
#  'research scientist , mobile computer vision': 146,
#  'research scientist - computer vision': 147,
#  'research scientist - computer vision , deep learning , perception': 148,
#  'research scientist - computer vision/machine learning': 149,
#  'research scientist / computer vision / deep learning / artificial intelligence': 150,
#  'research scientist computer vision / machine learning': 151,
#  'research scientist postdoctoral associate-computer vision , mouselight': 152,
#  'research scientist senior research scientist - deep learning': 153,
#  'robotics automation engineer': 154,
#  'robotics computer vision engineer': 155,
#  'robotics computer vision scientist , perception - amazon scout': 156,
#  'robotics research engineer - simulation computer vision !': 157,
#  'sap ixp intern - leonardo machine learning data scientist': 158,
#  'scientist : computer vision & machine learning engineer': 159,
#  'scientist iv - machine learning computer vision': 160,
#  'scientist iv post doc - machine learning computer vision': 161,
#  'sdet , computer vision - contractor': 162,
#  'senior / lead deep learning computer scientist': 163,
#  'senior 3d computer vision & deep learning engineer': 164,
#  'senior algorithm engineer - computer vision !': 165,
#  'senior algorithm research scientist ( machine learning / optimization )': 166,
#  'senior applied research engineer - advanced computer vision & graphics': 167,
#  'senior applied research engineer - biological computer vision': 168,
#  'senior applied research engineer - computer vision & machine learning': 169,
#  'senior applied scientist - computer vision , deep learning': 170,
#  'senior applied scientist - computer vision , machine learning': 171,
#  'senior applied scientist - machine learning': 172,
#  'senior applied scientist - machine learning ( advertising team )': 173,
#  'senior applied scientist - machine learning / computer vision': 174,
#  'senior artificial intelligence engineer': 175,
#  'senior cloud-based computer vision software engineer - contractor': 176,
#  'senior computer vision engineer': 177,
#  'senior computer vision software engineer': 178,
#  'senior data scientist , machine learning': 179,
#  'senior data scientist - machine learning': 180,
#  'senior data scientist : machine learning engineer': 181,
#  'senior data scientist machine learning': 182,
#  'senior data scientist/machine learning - data science/ai/machine learning': 183,
#  'senior data scientist| machine learning researcher|': 184,
#  'senior deep learning engineer ( computer vision': 185,
#  'senior human vision scientist': 186,
#  'senior machine learning data scientist': 187,
#  'senior machine learning engineer': 188,
#  'senior machine learning engineer , entity understanding': 189,
#  'senior machine learning engineer , machine learning graphics': 190,
#  'senior machine learning engineer - computer vision': 191,
#  'senior machine learning infrastructure engineer': 192,
#  'senior machine learning scientist': 193,
#  'senior research scientist - computer vision': 194,
#  'senior research scientist- computer vision machine learning': 195,
#  'senior research scientist/data scientist , machine learning': 196,
#  'senior robotics software engineer': 197,
#  'senior scientist - computer vision , deep learning perception': 198,
#  'senior slam , computer vision engineer hot virtual augmented reality device start-up': 199,
#  'senior software computer vision engineer': 200,
#  'senior software engineer , computer vision': 201,
#  'senior software engineer , machine learning': 202,
#  'senior software engineer ofp development f-15 division .': 203,
#  'senior speech recognition scientist': 204,
#  'senior system software engineer - programmable vision accelerator': 205,
#  'software developer computer vision/deep learning': 206,
#  'software development engineer , computer vision': 207,
#  'software development engineer , perception computer vision - amazon scout': 208,
#  'software engineer ( computer vision )': 209,
#  'software engineer ( sr./principal level ) - artificial intelligence machine learning': 210,
#  'software engineer , computer vision': 211,
#  'software engineer , computer vision tools': 212,
#  'software engineer , deep learning/computer vision': 213,
#  'software engineer , mobile computer vision': 214,
#  'software engineer , robotics': 215,
#  'software engineer - artificial intelligence machine learning': 216,
#  'software engineer - computer vision': 217,
#  'software engineer - computer vision perception': 218,
#  'software engineer - machine learning': 219,
#  'software engineer - machine vision': 220,
#  'software engineer asc ( level 1 ) - artificial intelligence': 221,
#  'software engineer comp vision machine learnin': 222,
#  'software engineer ii - artificial machine intelligence': 223,
#  'software engineering , computer vision intern': 224,
#  'spark insights - data scientist - computer vision': 225,
#  'sr . scientist , machine learning': 226,
#  'sr applied scientist computer vision - aws global infrastructure': 227,
#  'sr. computer vision engineer': 228,
#  'sr. data scientist : computer vision & deep learning': 229,
#  'sr. lead computer vision engineer': 230,
#  'sr. machine learning applied scientist': 231,
#  'sr. machine learning scientist': 232,
#  'sr. research scientist , computer vision': 233,
#  'sr. software engineer ( computer vision )': 234,
#  'sr./mid deep learning scientist': 235,
#  'staff computer vision scientist': 236,
#  'staff machine learning scientist': 237,
#  'staff software engineer ( computer vision )': 238,
#  'stereo vision mapping engineer': 239,
#  'top secret clearance - machine learning engineer/scientist': 240,
#  'video machine learning engineer/scientist': 241,
#  'vision signal processing lead engineer': 242,
#  'visiting scientist - robotics ( ste )': 243}

# %%
#Initialize model with rbf kernel
classifier = SVC(C=250, # penalty parameter
                kernel='rbf', # kernel type, rbf working fine here
                gamma=1, # kernel coefficient
                coef0=1, # change to 1 from default value of 0.0
                shrinking=True, # using shrinking heuristics
                tol=0.001, # stopping criterion tolerance
                cache_size=500, # 500 MB cache size  
                max_iter=-1, # no limit, let it run
                random_state=None)
#model = OneVsRestClassifier(classifier, n_jobs=4)

# %%
#Cross validation
scores = cross_validate(classifier, x_train, y_train, cv=3)
scores['test_score'].mean()
# Out:
# C:\Users\FRE\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=3.
#   % (min_groups, self.n_splits)), Warning)
# 0.35696601380197884

# %%
classifier.fit(x_train, y_train)
# Out:
# SVC(C=250, cache_size=500, class_weight=None, coef0=1,
#   decision_function_shape='ovr', degree=3, gamma=1.4, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred = label_encoder.inverse_transform(classifier.predict(x_train))
y_true = label_encoder.inverse_transform(y_train)

print(f'accuracy score on train data: {accuracy_score(y_true, y_pred)}')

def report2dict(cr):
    rows = []
    for row in cr.split("\n"):
        parsed_row = [x for x in row.split("  ") if len(x) > 0]
        if len(parsed_row) > 0: rows.append(parsed_row)
    measures = rows[0]
    classes = defaultdict(dict)
    for row in rows[1:]:
        class_label = row[0]
        for j, m in enumerate(measures):
            classes[class_label][m.strip()] = float(row[j + 1].strip())
    return classes
report = classification_report(y_true, y_pred)
pd.DataFrame(report2dict(report)).T
# Out:
# accuracy score on train data: 0.4194977843426883
# C:\Users\FRE\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\FRE\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\FRE\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#                                                     f1-score  precision  \
# -computer vision research scientist                     0.00       0.00
#  ai bootcamp experienced machine learning engin...      0.00       0.00
# ai research scientist - computer vision                 0.00       0.00
# applied artificial intelligence machine learnin...      0.00       0.00
#  applied research scientist , computer vision           0.00       0.00
# applied research scientist - machine learning           0.00       0.00
#  applied scientist , machine learning                   1.00       1.00
# applied scientist - artificial intelligence             0.00       0.00
# applied scientist - computer vision                     0.00       0.00
# c++ computer vision software engineer                   0.00       0.00
#  c++ software engineer - advanced visualization         0.00       0.00
# camera software - imaging computer vision resea...      0.00       0.00
# co-op software engineer - machine learning ( su...      0.00       0.00
#  computer scientist ( machine learning ) , visi...      0.00       0.00
#  computer scientist , vision & learning                 0.00       0.00
#  computer scientist / neural networks , compute...      0.00       0.00
#  computer scientist/vision engineer                     0.00       0.00
# computer vision                                         0.86       0.75
#  computer vision & deep learning engineer               0.00       0.00
#  computer vision & deep learning research scien...      1.00       1.00
#  computer vision / deep learning - visual inert...      0.00       0.00
#  computer vision / deep learning intern                 0.00       0.00
#  computer vision / machine learning developer           0.00       0.00
# computer vision / machine learning engineer             0.00       0.00
#  computer vision / machine learning research en...      0.00       0.00
#  computer vision algorithm engineer                     0.00       0.00
# computer vision camera systems engineer                 0.00       0.00
#  computer vision developer intern                       0.00       0.00
#  computer vision engineer                               0.38       0.25
# computer vision engineer ( all experience level...      0.00       0.00
# ...                                                      ...        ...
# software engineer - computer vision                     0.00       0.00
#  software engineer - computer vision perception         0.00       0.00
#  software engineer - machine learning                   0.00       0.00
#  software engineer - machine vision                     0.00       0.00
# software engineer asc ( level 1 ) - artificial ...      1.00       1.00
# software engineer comp vision machine learnin           0.00       0.00
#  software engineer ii - artificial machine inte...      1.00       1.00
# software engineering , computer vision intern           0.00       0.00
# spark insights - data scientist - computer vision       1.00       1.00
# sr . scientist , machine learning                       1.00       1.00
#  sr applied scientist computer vision - aws glo...      0.00       0.00
#  sr. computer vision engineer                           0.00       0.00
#  sr. data scientist : computer vision & deep le...      1.00       1.00
# sr. lead computer vision engineer                       0.00       0.00
#  sr. machine learning applied scientist                 0.00       0.00
#  sr. machine learning scientist                         0.00       0.00
#  sr. research scientist , computer vision               0.00       0.00
# sr. software engineer ( computer vision )               0.00       0.00
# sr./mid deep learning scientist                         0.00       0.00
# staff computer vision scientist                         0.00       0.00
#  staff machine learning scientist                       0.00       0.00
# staff software engineer ( computer vision )             0.87       0.77
#  stereo vision mapping engineer                         0.00       0.00
#  top secret clearance - machine learning engine...      0.57       0.40
# video machine learning engineer/scientist               0.00       0.00
#  vision signal processing lead engineer                 0.00       0.00
# visiting scientist - robotics ( ste )                   0.00       0.00
# micro avg                                               0.42       0.42
# macro avg                                               0.25       0.24
#  weighted avg                                           0.32       0.28
#
#                                                     recall  support
# -computer vision research scientist                   0.00      2.0
#  ai bootcamp experienced machine learning engin...    0.00      1.0
# ai research scientist - computer vision               0.00      2.0
# applied artificial intelligence machine learnin...    0.00      1.0
#  applied research scientist , computer vision         0.00      1.0
# applied research scientist - machine learning         0.00      1.0
#  applied scientist , machine learning                 1.00      1.0
# applied scientist - artificial intelligence           0.00      1.0
# applied scientist - computer vision                   0.00      2.0
# c++ computer vision software engineer                 0.00      2.0
#  c++ software engineer - advanced visualization       0.00      1.0
# camera software - imaging computer vision resea...    0.00      7.0
# co-op software engineer - machine learning ( su...    0.00      2.0
#  computer scientist ( machine learning ) , visi...    0.00      1.0
#  computer scientist , vision & learning               0.00      2.0
#  computer scientist / neural networks , compute...    0.00      2.0
#  computer scientist/vision engineer                   0.00      2.0
# computer vision                                       1.00      3.0
#  computer vision & deep learning engineer             0.00      2.0
#  computer vision & deep learning research scien...    1.00      2.0
#  computer vision / deep learning - visual inert...    0.00      4.0
#  computer vision / deep learning intern               0.00      1.0
#  computer vision / machine learning developer         0.00      1.0
# computer vision / machine learning engineer           0.00      7.0
#  computer vision / machine learning research en...    0.00      2.0
#  computer vision algorithm engineer                   0.00      1.0
# computer vision camera systems engineer               0.00      7.0
#  computer vision developer intern                     0.00      3.0
#  computer vision engineer                             0.79     84.0
# computer vision engineer ( all experience level...    0.00      1.0
# ...                                                    ...      ...
# software engineer - computer vision                   0.00      1.0
#  software engineer - computer vision perception       0.00      1.0
#  software engineer - machine learning                 0.00      2.0
#  software engineer - machine vision                   0.00      1.0
# software engineer asc ( level 1 ) - artificial ...    1.00      1.0
# software engineer comp vision machine learnin         0.00      2.0
#  software engineer ii - artificial machine inte...    1.00      2.0
# software engineering , computer vision intern         0.00      1.0
# spark insights - data scientist - computer vision     1.00      2.0
# sr . scientist , machine learning                     1.00      1.0
#  sr applied scientist computer vision - aws glo...    0.00      1.0
#  sr. computer vision engineer                         0.00      4.0
#  sr. data scientist : computer vision & deep le...    1.00      2.0
# sr. lead computer vision engineer                     0.00      1.0
#  sr. machine learning applied scientist               0.00      1.0
#  sr. machine learning scientist                       0.00      2.0
#  sr. research scientist , computer vision             0.00      2.0
# sr. software engineer ( computer vision )             0.00      6.0
# sr./mid deep learning scientist                       0.00      2.0
# staff computer vision scientist                       0.00      5.0
#  staff machine learning scientist                     0.00      1.0
# staff software engineer ( computer vision )           1.00     10.0
#  stereo vision mapping engineer                       0.00      1.0
#  top secret clearance - machine learning engine...    1.00      2.0
# video machine learning engineer/scientist             0.00      1.0
#  vision signal processing lead engineer               0.00      2.0
# visiting scientist - robotics ( ste )                 0.00      1.0
# micro avg                                             0.42    677.0
# macro avg                                             0.29    677.0
#  weighted avg                                         0.42    677.0
#
# [247 rows x 4 columns]

# %%
test=pd.read_csv('test.csv')
test.head
# Out:
# <bound method NDFrame.head of    title      skills
# 0    NaN        java
# 1    NaN      python
# 2    NaN  python,c++>

# %%
test['x'] = train['skills'].progress_apply(preprocess)
# Out:
#   0%|                                                                                          | 0/677 [00:00<?, ?it/s]
#
# 100%|████████████████████████████████████████████████████████████████████████████| 677/677 [00:00<00:00, 339333.63it/s]

# %%
x_test = vectorizer.transform(test['x'].values)

# %%
y_pred = label_encoder.inverse_transform(classifier.predict(x_test))

# %%
test['x'].head
# Out:
# <bound method NDFrame.head of 0    r python c/c++ julia c++ pytorch
# 1                        r python c++
# 2                            python r
# Name: x, dtype: object>

# %%
print(y_pred)
# Out:
# ['machine learning engineer' 'computer vision engineer'
#  'computer vision engineer']
