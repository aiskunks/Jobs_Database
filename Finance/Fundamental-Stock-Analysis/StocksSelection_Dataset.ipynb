# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import readline
from yahoofinancials import YahooFinancials as yf2
import os
#Pull data from Wikipedia page
wiki_page_table = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
df = wiki_page_table[0]   #first object contains information
#df.to_csv("S&P500-Symbols.csv", columns=['Symbol'])     #save tickers

df_copy = df.copy()
####################################final edit, ticker symbol of all stocks
# symbols = df_copy["Symbol"].tolist()

# %%
df_copy = df.copy()
df_unique_sectors = df_copy["GICS Sector"].unique()
print(df_unique_sectors)

#Store dataframes according to sectors of the stocks
df_industrials = df_copy[df_copy["GICS Sector"]=="Industrials"]
df_health_care = df_copy[df_copy["GICS Sector"]=="Health Care"]
df_information_technology = df_copy[df_copy["GICS Sector"]=="Information Technology"]
df_communication_services = df_copy[df_copy["GICS Sector"]=="Communication Services"]
df_consumer_discretionary = df_copy[df_copy["GICS Sector"]=="Consumer Discretionary"]
df_utilities = df_copy[df_copy["GICS Sector"]=="Utilities"]
df_financials = df_copy[df_copy["GICS Sector"]=="Financials"]
df_materials = df_copy[df_copy["GICS Sector"]=="Materials"]
df_real_estate = df_copy[df_copy["GICS Sector"]=="Real Estate"]
df_consumer_staples = df_copy[df_copy["GICS Sector"]=="Consumer Staples"]
df_energy = df_copy[df_copy["GICS Sector"]=="Energy"]
# Out:
# ['Industrials' 'Health Care' 'Information Technology'
#  'Communication Services' 'Consumer Discretionary' 'Utilities'
#  'Financials' 'Materials' 'Real Estate' 'Consumer Staples' 'Energy']

# %%
# drop unwanted columns
df_industrials = df_industrials.drop(columns=['SEC filings','CIK'])
df_health_care = df_health_care.drop(columns=['SEC filings','CIK']) 
df_information_technology = df_information_technology.drop(columns=['SEC filings','CIK'])
df_communication_services = df_communication_services.drop(columns=['SEC filings','CIK'])
df_consumer_discretionary = df_consumer_discretionary.drop(columns=['SEC filings','CIK'])
df_utilities = df_utilities.drop(columns=['SEC filings','CIK'])
df_financials = df_financials.drop(columns=['SEC filings','CIK'])
df_materials = df_materials.drop(columns=['SEC filings','CIK'])
df_real_estate = df_real_estate.drop(columns=['SEC filings','CIK'])
df_consumer_staples = df_consumer_staples.drop(columns=['SEC filings','CIK'])
df_energy = df_energy.drop(columns=['SEC filings','CIK'])

# %%
#get the symbols for all sector in one variable
industrials_symbols = df_industrials["Symbol"].tolist()
health_care_symbols = df_health_care["Symbol"].tolist()
information_technology_symbols = df_information_technology["Symbol"].tolist()
communication_services_symbols = df_communication_services["Symbol"].tolist()
consumer_discretionary_symbols = df_consumer_discretionary["Symbol"].tolist()
utilities_symbols = df_utilities["Symbol"].tolist()
financials_symbols = df_financials["Symbol"].tolist()
materials_symbols = df_materials["Symbol"].tolist()
real_estate_symbols = df_real_estate["Symbol"].tolist()
consumer_staples_symbols = df_consumer_staples["Symbol"].tolist()
energy_symbols = df_energy["Symbol"].tolist()

# %%
print(health_care_symbols)
# Out:
# ['ABT', 'ABBV', 'ABMD', 'A', 'ALGN', 'ABC', 'AMGN', 'ANTM', 'BAX', 'BDX', 'BIO', 'TECH', 'BIIB', 'BSX', 'BMY', 'CAH', 'CTLT', 'CNC', 'CERN', 'CRL', 'CI', 'COO', 'CVS', 'DHR', 'DVA', 'XRAY', 'DXCM', 'EW', 'GILD', 'HCA', 'HSIC', 'HOLX', 'HUM', 'IDXX', 'ILMN', 'INCY', 'ISRG', 'IQV', 'JNJ', 'LH', 'LLY', 'MCK', 'MDT', 'MRK', 'MTD', 'MRNA', 'OGN', 'PKI', 'PFE', 'DGX', 'REGN', 'RMD', 'STE', 'SYK', 'TFX', 'TMO', 'UNH', 'UHS', 'VRTX', 'VTRS', 'WAT', 'WST', 'ZBH', 'ZTS']

# %%
#-------------------------------------------------------------------------------------------------------------------------
##################################################      REAL ESTATE     ##################################################
#-------------------------------------------------------------------------------------------------------------------------
print("\n--------------------------------   FETCHING DATA for REAL ESTATE SECTOR --------------------------------")
tickers = yf.Tickers('ARE AMT AVB BXP CBRE CCI DLR DRE EQIX EQR ESS EXR FRT PEAK HST IRM KIM MAA PLD PSA O REG SBAC SPG UDR VTR VNO WELL WY')
print("-----------------------------------------------    DATA FETCHED SUCCESSFULLY   -----------------------------------------------\n")
dummy2 = pd.DataFrame()
dummy2 = df[df["GICS Sector"]=="Real Estate"]

#----------------------------------------------------   PEG RATIO   ----------------------------------------------------
# drop_symbol=dummy2.index[dummy2["Symbol"] == 0].tolist()
# dummy2=dummy2.drop(df.index[drop_symbol])
pegRatio = []
print("\n-----------------------------------------------    Calculating PEG RATIO   -----------------------------------------------")
pegRatio.append(tickers.tickers['ARE'].info["pegRatio"])
pegRatio.append(tickers.tickers['AMT'].info["pegRatio"])
pegRatio.append(tickers.tickers['AVB'].info["pegRatio"])
pegRatio.append(tickers.tickers['BXP'].info["pegRatio"])
pegRatio.append(tickers.tickers['CBRE'].info["pegRatio"])
pegRatio.append(tickers.tickers['CCI'].info["pegRatio"])
pegRatio.append(tickers.tickers['DLR'].info["pegRatio"])
pegRatio.append(tickers.tickers['DRE'].info["pegRatio"])
pegRatio.append(tickers.tickers['EQIX'].info["pegRatio"])
pegRatio.append(tickers.tickers['EQR'].info["pegRatio"])
pegRatio.append(tickers.tickers['ESS'].info["pegRatio"])
pegRatio.append(tickers.tickers['EXR'].info["pegRatio"])
pegRatio.append(tickers.tickers['FRT'].info["pegRatio"])
pegRatio.append(tickers.tickers['PEAK'].info["pegRatio"])
pegRatio.append(tickers.tickers['HST'].info["pegRatio"])
pegRatio.append(tickers.tickers['IRM'].info["pegRatio"])
pegRatio.append(tickers.tickers['KIM'].info["pegRatio"])
pegRatio.append(tickers.tickers['MAA'].info["pegRatio"])
pegRatio.append(tickers.tickers['PLD'].info["pegRatio"])
pegRatio.append(tickers.tickers['PSA'].info["pegRatio"])
pegRatio.append(tickers.tickers['O'].info["pegRatio"])
pegRatio.append(tickers.tickers['REG'].info["pegRatio"])
pegRatio.append(tickers.tickers['SBAC'].info["pegRatio"])
pegRatio.append(tickers.tickers['SPG'].info["pegRatio"])
pegRatio.append(tickers.tickers['UDR'].info["pegRatio"])
pegRatio.append(tickers.tickers['VTR'].info["pegRatio"])
pegRatio.append(tickers.tickers['VNO'].info["pegRatio"])
pegRatio.append(tickers.tickers['WELL'].info["pegRatio"])
pegRatio.append(tickers.tickers['WY'].info["pegRatio"])
print("-----------------------------------------  PEG RATIO Calculated Successfully   -----------------------------------------\n")
# industrial_pegRatio = []
# for ticker in industrials_symbols:
#     industrial_pegRatio = df_industrials[["Symbols"]==ticker].info["pegRatio"]

# print(df_industrials[["Symbol"]=="MMM"].info["pegRatio"])
# Out:
# --------------------------------   FETCHING DATA for REAL ESTATE SECTOR --------------------------------
# -----------------------------------------------    DATA FETCHED SUCCESSFULLY   -----------------------------------------------
#
#
# -----------------------------------------------    Calculating PEG RATIO   -----------------------------------------------
# -----------------------------------------  PEG RATIO Calculated Successfully   -----------------------------------------

# %%
#----------------------------------------------------   TRALING PE   ----------------------------------------------------
# Used Forward PE where trailing value was NONE, PEAK, HST, VRT VNO
trailingPE = []
print("\n-----------------------------------------------    Calculating TRAILING PE -----------------------------------------------")
trailingPE.append(tickers.tickers['ARE'].info["trailingPE"])
trailingPE.append(tickers.tickers['AMT'].info["trailingPE"])
trailingPE.append(tickers.tickers['AVB'].info["trailingPE"])
trailingPE.append(tickers.tickers['BXP'].info["trailingPE"])
trailingPE.append(tickers.tickers['CBRE'].info["trailingPE"])
trailingPE.append(tickers.tickers['CCI'].info["trailingPE"])
trailingPE.append(tickers.tickers['DLR'].info["trailingPE"])
trailingPE.append(tickers.tickers['DRE'].info["trailingPE"])
trailingPE.append(tickers.tickers['EQIX'].info["trailingPE"])
trailingPE.append(tickers.tickers['EQR'].info["trailingPE"])
trailingPE.append(tickers.tickers['ESS'].info["trailingPE"])
trailingPE.append(tickers.tickers['EXR'].info["trailingPE"])
trailingPE.append(tickers.tickers['FRT'].info["trailingPE"])
trailingPE.append(tickers.tickers['PEAK'].info["forwardPE"])
trailingPE.append(tickers.tickers['HST'].info["forwardPE"])
trailingPE.append(tickers.tickers['IRM'].info["trailingPE"])
trailingPE.append(tickers.tickers['KIM'].info["trailingPE"])
trailingPE.append(tickers.tickers['MAA'].info["trailingPE"])
trailingPE.append(tickers.tickers['PLD'].info["trailingPE"])
trailingPE.append(tickers.tickers['PSA'].info["trailingPE"])
trailingPE.append(tickers.tickers['O'].info["trailingPE"])
trailingPE.append(tickers.tickers['REG'].info["trailingPE"])
trailingPE.append(tickers.tickers['SBAC'].info["trailingPE"])
trailingPE.append(tickers.tickers['SPG'].info["trailingPE"])
trailingPE.append(tickers.tickers['UDR'].info["trailingPE"])
trailingPE.append(tickers.tickers['VTR'].info["forwardPE"])
trailingPE.append(tickers.tickers['VNO'].info["forwardPE"])
trailingPE.append(tickers.tickers['WELL'].info["trailingPE"])
trailingPE.append(tickers.tickers['WY'].info["trailingPE"])
print("-----------------------------------------  TRAILING PE Calculated Successfully -----------------------------------------\n")

##----------------------------------------------------   CURRENT RATIO   ----------------------------------------------------
# Current Ratio : The current ratio measures a company's ability to pay current, or 
# short-term, liabilities (debt and payables) with its current, or short-term, 
# assets (cash, inventory, and receivables).
print("\n-----------------------------------------------    Calculating CURRENT RATIO   -----------------------------------------------")
currentRatio = []
currentRatio.append(tickers.tickers['ARE'].info["currentRatio"])
currentRatio.append(tickers.tickers['AMT'].info["currentRatio"])
currentRatio.append(tickers.tickers['AVB'].info["currentRatio"])
currentRatio.append(tickers.tickers['BXP'].info["currentRatio"])
currentRatio.append(tickers.tickers['CBRE'].info["currentRatio"])
currentRatio.append(tickers.tickers['CCI'].info["currentRatio"])
currentRatio.append(tickers.tickers['DLR'].info["currentRatio"])
currentRatio.append(tickers.tickers['DRE'].info["currentRatio"])
currentRatio.append(tickers.tickers['EQIX'].info["currentRatio"])
currentRatio.append(tickers.tickers['EQR'].info["currentRatio"])
currentRatio.append(tickers.tickers['ESS'].info["currentRatio"])
currentRatio.append(tickers.tickers['EXR'].info["currentRatio"])
currentRatio.append(tickers.tickers['FRT'].info["currentRatio"])
currentRatio.append(tickers.tickers['PEAK'].info["currentRatio"])
currentRatio.append(tickers.tickers['HST'].info["currentRatio"])
currentRatio.append(tickers.tickers['IRM'].info["currentRatio"])
currentRatio.append(tickers.tickers['KIM'].info["currentRatio"])
currentRatio.append(tickers.tickers['MAA'].info["currentRatio"])
currentRatio.append(tickers.tickers['PLD'].info["currentRatio"])
currentRatio.append(tickers.tickers['PSA'].info["currentRatio"])
currentRatio.append(tickers.tickers['O'].info["currentRatio"])
currentRatio.append(tickers.tickers['REG'].info["currentRatio"])
currentRatio.append(tickers.tickers['SBAC'].info["currentRatio"])
currentRatio.append(tickers.tickers['SPG'].info["currentRatio"])
currentRatio.append(tickers.tickers['UDR'].info["currentRatio"])
currentRatio.append(tickers.tickers['VTR'].info["currentRatio"])
currentRatio.append(tickers.tickers['VNO'].info["currentRatio"])
currentRatio.append(tickers.tickers['WELL'].info["currentRatio"])
currentRatio.append(tickers.tickers['WY'].info["currentRatio"])

print("------------------------------------------  CURRENT RATIO Calculated Successfully   --------------------------------------\n")


#----------------------------------------------------  QUICK RATIO   ----------------------------------------------------
# Quick Ratio: The quick ratio, often referred to as the acid-test ratio, 
# includes only assets that can be converted to cash within 90 days or less.

print("\n-----------------------------------------------    Calculating QUICK RATIO -----------------------------------------------")
quickRatio = []
quickRatio.append(tickers.tickers['ARE'].info["quickRatio"])
quickRatio.append(tickers.tickers['AMT'].info["quickRatio"])
quickRatio.append(tickers.tickers['AVB'].info["quickRatio"])
quickRatio.append(tickers.tickers['BXP'].info["quickRatio"])
quickRatio.append(tickers.tickers['CBRE'].info["quickRatio"])
quickRatio.append(tickers.tickers['CCI'].info["quickRatio"])
quickRatio.append(tickers.tickers['DLR'].info["quickRatio"])
quickRatio.append(tickers.tickers['DRE'].info["quickRatio"])
quickRatio.append(tickers.tickers['EQIX'].info["quickRatio"])
quickRatio.append(tickers.tickers['EQR'].info["quickRatio"])
quickRatio.append(tickers.tickers['ESS'].info["quickRatio"])
quickRatio.append(tickers.tickers['EXR'].info["quickRatio"])
quickRatio.append(tickers.tickers['FRT'].info["quickRatio"])
quickRatio.append(tickers.tickers['PEAK'].info["quickRatio"])
quickRatio.append(tickers.tickers['HST'].info["quickRatio"])
quickRatio.append(tickers.tickers['IRM'].info["quickRatio"])
quickRatio.append(tickers.tickers['KIM'].info["quickRatio"])
quickRatio.append(tickers.tickers['MAA'].info["quickRatio"])
quickRatio.append(tickers.tickers['PLD'].info["quickRatio"])
quickRatio.append(tickers.tickers['PSA'].info["quickRatio"])
quickRatio.append(tickers.tickers['O'].info["quickRatio"])
quickRatio.append(tickers.tickers['REG'].info["quickRatio"])
quickRatio.append(tickers.tickers['SBAC'].info["quickRatio"])
quickRatio.append(tickers.tickers['SPG'].info["quickRatio"])
quickRatio.append(tickers.tickers['UDR'].info["quickRatio"])
quickRatio.append(tickers.tickers['VTR'].info["quickRatio"])
quickRatio.append(tickers.tickers['VNO'].info["quickRatio"])
quickRatio.append(tickers.tickers['WELL'].info["quickRatio"])
quickRatio.append(tickers.tickers['WY'].info["quickRatio"])

print("------------------------------------------  QUICK RATIO Calculated Successfully ------------------------------------------\n")


# #----------------------------------------------------   EARNINGS GROWTH RATE   ----------------------------------------------------
# # Earnings Growth Rate
# print("\n------------------------------------------    Calculating EARNINGS GROWTH RATE    -----------------------------------------")
# earningsGrowth = []
# earningsGrowth.append(tickers.tickers['ARE'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['AMT'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['AVB'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['BXP'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['CBRE'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['CCI'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['DLR'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['DRE'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['EQIX'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['EQR'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['ESS'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['EXR'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['FRT'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['PEAK'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['HST'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['IRM'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['KIM'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['MAA'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['PLD'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['PSA'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['O'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['REG'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['SBAC'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['SPG'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['UDR'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['VTR'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['VNO'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['WELL'].info["earningsGrowth"])
# earningsGrowth.append(tickers.tickers['WY'].info["earningsGrowth"])
# dummy2["Earnings Growth Rate"] = earningsGrowth
# print("------------------------------------------  EARNINGS GROWTH RATE Calculated Successfully -------------------------------------------\n")


#----------------------------------------------------   DIVIDEND YIELD   ----------------------------------------------------
print("\n-----------------------------------------------    Calculating DIVIDEND YIELD  -----------------------------------------------")
dividendYield = []
dividendYield.append(tickers.tickers['ARE'].info["dividendYield"])
dividendYield.append(tickers.tickers['AMT'].info["dividendYield"])
dividendYield.append(tickers.tickers['AVB'].info["dividendYield"])
dividendYield.append(tickers.tickers['BXP'].info["dividendYield"])
dividendYield.append(tickers.tickers['CBRE'].info["dividendYield"])
dividendYield.append(tickers.tickers['CCI'].info["dividendYield"])
dividendYield.append(tickers.tickers['DLR'].info["dividendYield"])
dividendYield.append(tickers.tickers['DRE'].info["dividendYield"])
dividendYield.append(tickers.tickers['EQIX'].info["dividendYield"])
dividendYield.append(tickers.tickers['EQR'].info["dividendYield"])
dividendYield.append(tickers.tickers['ESS'].info["dividendYield"])
dividendYield.append(tickers.tickers['EXR'].info["dividendYield"])
dividendYield.append(tickers.tickers['FRT'].info["dividendYield"])
dividendYield.append(tickers.tickers['PEAK'].info["dividendYield"])
dividendYield.append(tickers.tickers['HST'].info["dividendYield"])
dividendYield.append(tickers.tickers['IRM'].info["dividendYield"])
dividendYield.append(tickers.tickers['KIM'].info["dividendYield"])
dividendYield.append(tickers.tickers['MAA'].info["dividendYield"])
dividendYield.append(tickers.tickers['PLD'].info["dividendYield"])
dividendYield.append(tickers.tickers['PSA'].info["dividendYield"])
dividendYield.append(tickers.tickers['O'].info["dividendYield"])
dividendYield.append(tickers.tickers['REG'].info["dividendYield"])
dividendYield.append(tickers.tickers['SBAC'].info["dividendYield"])
dividendYield.append(tickers.tickers['SPG'].info["dividendYield"])
dividendYield.append(tickers.tickers['UDR'].info["dividendYield"])
dividendYield.append(tickers.tickers['VTR'].info["dividendYield"])
dividendYield.append(tickers.tickers['VNO'].info["dividendYield"])
dividendYield.append(tickers.tickers['WELL'].info["dividendYield"])
dividendYield.append(tickers.tickers['WY'].info["dividendYield"])
# dividendYield = [i * 100 for i in dividendYield]
# try:
#     for i in dividendYield:
#         dividendYield = (i * 100)
# except Exception as e:
#     print("nan")

print("----------------------------------------  DIVIDEND YIELD Calculated Successfully  ----------------------------------------\n")


#----------------------------------------------------   TRAILING EPS   ----------------------------------------------------
print("\n-----------------------------------------------    Calculating TRAILING EPS    -----------------------------------------------")
trailingEps = []
trailingEps.append(tickers.tickers['ARE'].info["trailingEps"])
trailingEps.append(tickers.tickers['AMT'].info["trailingEps"])
trailingEps.append(tickers.tickers['AVB'].info["trailingEps"])
trailingEps.append(tickers.tickers['BXP'].info["trailingEps"])
trailingEps.append(tickers.tickers['CBRE'].info["trailingEps"])
trailingEps.append(tickers.tickers['CCI'].info["trailingEps"])
trailingEps.append(tickers.tickers['DLR'].info["trailingEps"])
trailingEps.append(tickers.tickers['DRE'].info["trailingEps"])
trailingEps.append(tickers.tickers['EQIX'].info["trailingEps"])
trailingEps.append(tickers.tickers['EQR'].info["trailingEps"])
trailingEps.append(tickers.tickers['ESS'].info["trailingEps"])
trailingEps.append(tickers.tickers['EXR'].info["trailingEps"])
trailingEps.append(tickers.tickers['FRT'].info["trailingEps"])
trailingEps.append(tickers.tickers['PEAK'].info["trailingEps"])
trailingEps.append(tickers.tickers['HST'].info["trailingEps"])
trailingEps.append(tickers.tickers['IRM'].info["trailingEps"])
trailingEps.append(tickers.tickers['KIM'].info["trailingEps"])
trailingEps.append(tickers.tickers['MAA'].info["trailingEps"])
trailingEps.append(tickers.tickers['PLD'].info["trailingEps"])
trailingEps.append(tickers.tickers['PSA'].info["trailingEps"])
trailingEps.append(tickers.tickers['O'].info["trailingEps"])
trailingEps.append(tickers.tickers['REG'].info["trailingEps"])
trailingEps.append(tickers.tickers['SBAC'].info["trailingEps"])
trailingEps.append(tickers.tickers['SPG'].info["trailingEps"])
trailingEps.append(tickers.tickers['UDR'].info["trailingEps"])
trailingEps.append(tickers.tickers['VTR'].info["trailingEps"])
trailingEps.append(tickers.tickers['VNO'].info["trailingEps"])
trailingEps.append(tickers.tickers['WELL'].info["trailingEps"])
trailingEps.append(tickers.tickers['WY'].info["trailingEps"])

print("--------------------------------------------  TRAILING EPS Calculated Successfully    -------------------------------------------\n")
# Out:
# -----------------------------------------------    Calculating TRAILING PE -----------------------------------------------
# -----------------------------------------  TRAILING PE Calculated Successfully -----------------------------------------
#
#
# -----------------------------------------------    Calculating CURRENT RATIO   -----------------------------------------------
# ------------------------------------------  CURRENT RATIO Calculated Successfully   --------------------------------------
#
#
# -----------------------------------------------    Calculating QUICK RATIO -----------------------------------------------
# ------------------------------------------  QUICK RATIO Calculated Successfully ------------------------------------------
#
#
# -----------------------------------------------    Calculating DIVIDEND YIELD  -----------------------------------------------
# ...

# %%
dummy2["Trailing PE"] = trailingPE
dummy2["Peg Ratio"] = pegRatio
dummy2["Trailing EPS"] = trailingEps
dummy2["Current Ratio"] = currentRatio
dummy2["QUICK Ratio"] = quickRatio
dummy2["Dividend Yield"] = dividendYield
dummy2 = dummy2.drop(columns=['SEC filings','CIK'])
dummy2.to_csv("RealEstate.csv")
os.system('say "your program ran successfully"')
# Out:
# 0

# %%
print(df_information_technology["Symbol"].tolist())
print(len(df_information_technology["Symbol"].tolist()))
# Out:
# ['ACN', 'ADBE', 'AMD', 'AKAM', 'APH', 'ADI', 'ANSS', 'AAPL', 'AMAT', 'ANET', 'ADSK', 'ADP', 'AVGO', 'BR', 'CDNS', 'CDW', 'CDAY', 'CSCO', 'CTXS', 'CTSH', 'GLW', 'DXC', 'ENPH', 'FFIV', 'FIS', 'FISV', 'FLT', 'FTNT', 'IT', 'GPN', 'HPE', 'HPQ', 'INTC', 'IBM', 'INTU', 'IPGP', 'JKHY', 'JNPR', 'KEYS', 'KLAC', 'LRCX', 'MA', 'MCHP', 'MU', 'MSFT', 'MPWR', 'MSI', 'NTAP', 'NLOK', 'NVDA', 'NXPI', 'ORCL', 'PAYX', 'PAYC', 'PYPL', 'PTC', 'QRVO', 'QCOM', 'CRM', 'STX', 'NOW', 'SWKS', 'SNPS', 'TEL', 'TER', 'TXN', 'TRMB', 'TYL', 'VRSN', 'V', 'WDC', 'WU', 'XLNX', 'ZBRA']
# 74

# %%
#-------------------------------------------------------------------------------------------------------------------------
##################################################      Information Technology    ##################################################
#-------------------------------------------------------------------------------------------------------------------------

print("\n--------------------------------    FETCHING DATA for INFORMATION TECHNOLOGY SECTOR   -----------------------------------")
tickers = yf.Tickers("ACN ADBE AMD AKAM APH ADI ANSS AAPL AMAT ANET ADSK ADP AVGO BR CDNS CDW CDAY CSCO CTXS CTSH GLW DXC ENPH FFIV FIS FISV FLT FTNT IT GPN HPE HPQ INTC IBM INTU IPGP JKHY JNPR KEYS KLAC LRCX MA MCHP MU MSFT MPWR MSI NTAP NLOK NVDA NXPI ORCL PAYX PAYC PYPL PTC QRVO QCOM CRM STX NOW SWKS SNPS TEL TER TXN TRMB TYL VRSN V WDC WU XLNX ZBRA")
print("-----------------------------------------------    DATA FETCHED SUCCESSFULLY   -----------------------------------------------\n")
dummy3 = pd.DataFrame()
dummy3 = df[df["GICS Sector"]=="Information Technology"]

#----------------------------------------------------   CURRENT RATIO   ----------------------------------------------------

currentRatio = []
print("\n-----------------------------------------------    Calculating CURRENT RATIO  -----------------------------------------------")
currentRatio.append(tickers.tickers['ACN'].info["currentRatio"])
currentRatio.append(tickers.tickers['ADBE'].info["currentRatio"])
currentRatio.append(tickers.tickers['AMD'].info["currentRatio"])
currentRatio.append(tickers.tickers['AKAM'].info["currentRatio"])
currentRatio.append(tickers.tickers['APH'].info["currentRatio"])
currentRatio.append(tickers.tickers['ADI'].info["currentRatio"])
currentRatio.append(tickers.tickers['ANSS'].info["currentRatio"])
currentRatio.append(tickers.tickers['AAPL'].info["currentRatio"])
currentRatio.append(tickers.tickers['AMAT'].info["currentRatio"])
currentRatio.append(tickers.tickers['ANET'].info["currentRatio"])
currentRatio.append(tickers.tickers['ADSK'].info["currentRatio"])
currentRatio.append(tickers.tickers['ADP'].info["currentRatio"])
currentRatio.append(tickers.tickers['AVGO'].info["currentRatio"])
currentRatio.append(tickers.tickers['BR'].info["currentRatio"])
currentRatio.append(tickers.tickers['CDNS'].info["currentRatio"])
currentRatio.append(tickers.tickers['CDW'].info["currentRatio"])
currentRatio.append(tickers.tickers['CDAY'].info["currentRatio"])
currentRatio.append(tickers.tickers['CSCO'].info["currentRatio"])
currentRatio.append(tickers.tickers['CTXS'].info["currentRatio"])
currentRatio.append(tickers.tickers['CTSH'].info["currentRatio"])
currentRatio.append(tickers.tickers['GLW'].info["currentRatio"])
currentRatio.append(tickers.tickers['DXC'].info["currentRatio"])
currentRatio.append(tickers.tickers['ENPH'].info["currentRatio"])
currentRatio.append(tickers.tickers['FFIV'].info["currentRatio"])
currentRatio.append(tickers.tickers['FIS'].info["currentRatio"])
currentRatio.append(tickers.tickers['FISV'].info["currentRatio"])
currentRatio.append(tickers.tickers['FLT'].info["currentRatio"])
currentRatio.append(tickers.tickers['FTNT'].info["currentRatio"])
currentRatio.append(tickers.tickers['IT'].info["currentRatio"])
currentRatio.append(tickers.tickers['GPN'].info["currentRatio"])
currentRatio.append(tickers.tickers['HPE'].info["currentRatio"])
currentRatio.append(tickers.tickers['HPQ'].info["currentRatio"])
currentRatio.append(tickers.tickers['INTC'].info["currentRatio"])
currentRatio.append(tickers.tickers['IBM'].info["currentRatio"])
currentRatio.append(tickers.tickers['INTU'].info["currentRatio"])
currentRatio.append(tickers.tickers['IPGP'].info["currentRatio"])
currentRatio.append(tickers.tickers['JKHY'].info["currentRatio"])
currentRatio.append(tickers.tickers['JNPR'].info["currentRatio"])
currentRatio.append(tickers.tickers['KEYS'].info["currentRatio"])
currentRatio.append(tickers.tickers['KLAC'].info["currentRatio"])
currentRatio.append(tickers.tickers['LRCX'].info["currentRatio"])
currentRatio.append(tickers.tickers['MA'].info["currentRatio"])
currentRatio.append(tickers.tickers['MCHP'].info["currentRatio"])
currentRatio.append(tickers.tickers['MU'].info["currentRatio"])
currentRatio.append(tickers.tickers['MSFT'].info["currentRatio"])
currentRatio.append(tickers.tickers['MPWR'].info["currentRatio"])
currentRatio.append(tickers.tickers['MSI'].info["currentRatio"])
currentRatio.append(tickers.tickers['NTAP'].info["currentRatio"])
currentRatio.append(tickers.tickers['NLOK'].info["currentRatio"])
currentRatio.append(tickers.tickers['NVDA'].info["currentRatio"])
currentRatio.append(tickers.tickers['NXPI'].info["currentRatio"])
currentRatio.append(tickers.tickers['ORCL'].info["currentRatio"])
currentRatio.append(tickers.tickers['PAYX'].info["currentRatio"])
currentRatio.append(tickers.tickers['PAYC'].info["currentRatio"])
currentRatio.append(tickers.tickers['PYPL'].info["currentRatio"])
currentRatio.append(tickers.tickers['PTC'].info["currentRatio"])
currentRatio.append(tickers.tickers['QRVO'].info["currentRatio"])
currentRatio.append(tickers.tickers['QCOM'].info["currentRatio"])
currentRatio.append(tickers.tickers['CRM'].info["currentRatio"])
currentRatio.append(tickers.tickers['STX'].info["currentRatio"])
currentRatio.append(tickers.tickers['NOW'].info["currentRatio"])
currentRatio.append(tickers.tickers['SWKS'].info["currentRatio"])
currentRatio.append(tickers.tickers['SNPS'].info["currentRatio"])
currentRatio.append(tickers.tickers['TEL'].info["currentRatio"])
currentRatio.append(tickers.tickers['TER'].info["currentRatio"])
currentRatio.append(tickers.tickers['TXN'].info["currentRatio"])
currentRatio.append(tickers.tickers['TRMB'].info["currentRatio"])
currentRatio.append(tickers.tickers['TYL'].info["currentRatio"])
currentRatio.append(tickers.tickers['VRSN'].info["currentRatio"])
currentRatio.append(tickers.tickers['V'].info["currentRatio"])
currentRatio.append(tickers.tickers['WDC'].info["currentRatio"])
currentRatio.append(tickers.tickers['WU'].info["currentRatio"])
currentRatio.append(tickers.tickers['XLNX'].info["currentRatio"])
currentRatio.append(tickers.tickers['ZBRA'].info["currentRatio"])


print("-----------------------------------------  CURRENT RATIO Calculated Successfully   -----------------------------------------\n")


os.system('say "Shubh, your program ran successfully"')
# Out:
# --------------------------------    FETCHING DATA for INFORMATION TECHNOLOGY SECTOR   -----------------------------------
# -----------------------------------------------    DATA FETCHED SUCCESSFULLY   -----------------------------------------------
#
#
# -----------------------------------------------    Calculating CURRENT RATIO  -----------------------------------------------
# -----------------------------------------  CURRENT RATIO Calculated Successfully   -----------------------------------------
# 0

# %%
#----------------------------------------------------   TRALING PE RATIO   ----------------------------------------------------
# CDAY,
trailingPE = []
print("\n-----------------------------------------------    Calculating TRALING PE  -----------------------------------------------")
trailingPE.append(tickers.tickers['ACN'].info["trailingPE"])
trailingPE.append(tickers.tickers['ADBE'].info["trailingPE"])
trailingPE.append(tickers.tickers['AMD'].info["trailingPE"])
trailingPE.append(tickers.tickers['AKAM'].info["trailingPE"])
trailingPE.append(tickers.tickers['APH'].info["trailingPE"])
trailingPE.append(tickers.tickers['ADI'].info["trailingPE"])
trailingPE.append(tickers.tickers['ANSS'].info["trailingPE"])
trailingPE.append(tickers.tickers['AAPL'].info["trailingPE"])
trailingPE.append(tickers.tickers['AMAT'].info["trailingPE"])
trailingPE.append(tickers.tickers['ANET'].info["trailingPE"])
trailingPE.append(tickers.tickers['ADSK'].info["trailingPE"])
trailingPE.append(tickers.tickers['ADP'].info["trailingPE"])
trailingPE.append(tickers.tickers['AVGO'].info["trailingPE"])
trailingPE.append(tickers.tickers['BR'].info["trailingPE"])
trailingPE.append(tickers.tickers['CDNS'].info["trailingPE"])
trailingPE.append(tickers.tickers['CDW'].info["trailingPE"])
trailingPE.append(tickers.tickers['CDAY'].info["forwardPE"])
trailingPE.append(tickers.tickers['CSCO'].info["trailingPE"])
trailingPE.append(tickers.tickers['CTXS'].info["trailingPE"])
trailingPE.append(tickers.tickers['CTSH'].info["trailingPE"])
trailingPE.append(tickers.tickers['GLW'].info["trailingPE"])
trailingPE.append(tickers.tickers['DXC'].info["forwardPE"])
trailingPE.append(tickers.tickers['ENPH'].info["trailingPE"])
trailingPE.append(tickers.tickers['FFIV'].info["trailingPE"])
trailingPE.append(tickers.tickers['FIS'].info["trailingPE"])
trailingPE.append(tickers.tickers['FISV'].info["trailingPE"])
trailingPE.append(tickers.tickers['FLT'].info["trailingPE"])
trailingPE.append(tickers.tickers['FTNT'].info["trailingPE"])
trailingPE.append(tickers.tickers['IT'].info["trailingPE"])
trailingPE.append(tickers.tickers['GPN'].info["trailingPE"])
trailingPE.append(tickers.tickers['HPE'].info["trailingPE"])
trailingPE.append(tickers.tickers['HPQ'].info["trailingPE"])
trailingPE.append(tickers.tickers['INTC'].info["trailingPE"])
trailingPE.append(tickers.tickers['IBM'].info["trailingPE"])
trailingPE.append(tickers.tickers['INTU'].info["trailingPE"])
trailingPE.append(tickers.tickers['IPGP'].info["trailingPE"])
trailingPE.append(tickers.tickers['JKHY'].info["trailingPE"])
trailingPE.append(tickers.tickers['JNPR'].info["trailingPE"])
trailingPE.append(tickers.tickers['KEYS'].info["trailingPE"])
trailingPE.append(tickers.tickers['KLAC'].info["trailingPE"])
trailingPE.append(tickers.tickers['LRCX'].info["trailingPE"])
trailingPE.append(tickers.tickers['MA'].info["trailingPE"])
trailingPE.append(tickers.tickers['MCHP'].info["trailingPE"])
trailingPE.append(tickers.tickers['MU'].info["trailingPE"])
trailingPE.append(tickers.tickers['MSFT'].info["trailingPE"])
trailingPE.append(tickers.tickers['MPWR'].info["trailingPE"])
trailingPE.append(tickers.tickers['MSI'].info["trailingPE"])
trailingPE.append(tickers.tickers['NTAP'].info["trailingPE"])
trailingPE.append(tickers.tickers['NLOK'].info["forwardPE"])
trailingPE.append(tickers.tickers['NVDA'].info["trailingPE"])
trailingPE.append(tickers.tickers['NXPI'].info["trailingPE"])
trailingPE.append(tickers.tickers['ORCL'].info["trailingPE"])
trailingPE.append(tickers.tickers['PAYX'].info["trailingPE"])
trailingPE.append(tickers.tickers['PAYC'].info["trailingPE"])
trailingPE.append(tickers.tickers['PYPL'].info["trailingPE"])
trailingPE.append(tickers.tickers['PTC'].info["trailingPE"])
trailingPE.append(tickers.tickers['QRVO'].info["trailingPE"])
trailingPE.append(tickers.tickers['QCOM'].info["trailingPE"])
trailingPE.append(tickers.tickers['CRM'].info["trailingPE"])
trailingPE.append(tickers.tickers['STX'].info["trailingPE"])
trailingPE.append(tickers.tickers['NOW'].info["trailingPE"])
trailingPE.append(tickers.tickers['SWKS'].info["trailingPE"])
trailingPE.append(tickers.tickers['SNPS'].info["trailingPE"])
trailingPE.append(tickers.tickers['TEL'].info["trailingPE"])
trailingPE.append(tickers.tickers['TER'].info["trailingPE"])
trailingPE.append(tickers.tickers['TXN'].info["trailingPE"])
trailingPE.append(tickers.tickers['TRMB'].info["trailingPE"])
trailingPE.append(tickers.tickers['TYL'].info["trailingPE"])
trailingPE.append(tickers.tickers['VRSN'].info["trailingPE"])
trailingPE.append(tickers.tickers['V'].info["trailingPE"])
trailingPE.append(tickers.tickers['WDC'].info["trailingPE"])
trailingPE.append(tickers.tickers['WU'].info["trailingPE"])
trailingPE.append(tickers.tickers['XLNX'].info["trailingPE"])
trailingPE.append(tickers.tickers['ZBRA'].info["trailingPE"])

print("-----------------------------------------  TRAILING PE RATIO Calculated Successfully   -----------------------------------------\n")


#----------------------------------------------------   PEG RATIO   ----------------------------------------------------
pegRatio = []
print("\n-----------------------------------------------    Calculating PEG RATIO   -----------------------------------------------")
pegRatio.append(tickers.tickers['ACN'].info["pegRatio"])
pegRatio.append(tickers.tickers['ADBE'].info["pegRatio"])
pegRatio.append(tickers.tickers['AMD'].info["pegRatio"])
pegRatio.append(tickers.tickers['AKAM'].info["pegRatio"])
pegRatio.append(tickers.tickers['APH'].info["pegRatio"])
pegRatio.append(tickers.tickers['ADI'].info["pegRatio"])
pegRatio.append(tickers.tickers['ANSS'].info["pegRatio"])
pegRatio.append(tickers.tickers['AAPL'].info["pegRatio"])
pegRatio.append(tickers.tickers['AMAT'].info["pegRatio"])
pegRatio.append(tickers.tickers['ANET'].info["pegRatio"])
pegRatio.append(tickers.tickers['ADSK'].info["pegRatio"])
pegRatio.append(tickers.tickers['ADP'].info["pegRatio"])
pegRatio.append(tickers.tickers['AVGO'].info["pegRatio"])
pegRatio.append(tickers.tickers['BR'].info["pegRatio"])
pegRatio.append(tickers.tickers['CDNS'].info["pegRatio"])
pegRatio.append(tickers.tickers['CDW'].info["pegRatio"])
pegRatio.append(tickers.tickers['CDAY'].info["pegRatio"])
pegRatio.append(tickers.tickers['CSCO'].info["pegRatio"])
pegRatio.append(tickers.tickers['CTXS'].info["pegRatio"])
pegRatio.append(tickers.tickers['CTSH'].info["pegRatio"])
pegRatio.append(tickers.tickers['GLW'].info["pegRatio"])
pegRatio.append(tickers.tickers['DXC'].info["pegRatio"])
pegRatio.append(tickers.tickers['ENPH'].info["pegRatio"])
pegRatio.append(tickers.tickers['FFIV'].info["pegRatio"])
pegRatio.append(tickers.tickers['FIS'].info["pegRatio"])
pegRatio.append(tickers.tickers['FISV'].info["pegRatio"])
pegRatio.append(tickers.tickers['FLT'].info["pegRatio"])
pegRatio.append(tickers.tickers['FTNT'].info["pegRatio"])
pegRatio.append(tickers.tickers['IT'].info["pegRatio"])
pegRatio.append(tickers.tickers['GPN'].info["pegRatio"])
pegRatio.append(tickers.tickers['HPE'].info["pegRatio"])
pegRatio.append(tickers.tickers['HPQ'].info["pegRatio"])
pegRatio.append(tickers.tickers['INTC'].info["pegRatio"])
pegRatio.append(tickers.tickers['IBM'].info["pegRatio"])
pegRatio.append(tickers.tickers['INTU'].info["pegRatio"])
pegRatio.append(tickers.tickers['IPGP'].info["pegRatio"])
pegRatio.append(tickers.tickers['JKHY'].info["pegRatio"])
pegRatio.append(tickers.tickers['JNPR'].info["pegRatio"])
pegRatio.append(tickers.tickers['KEYS'].info["pegRatio"])
pegRatio.append(tickers.tickers['KLAC'].info["pegRatio"])
pegRatio.append(tickers.tickers['LRCX'].info["pegRatio"])
pegRatio.append(tickers.tickers['MA'].info["pegRatio"])
pegRatio.append(tickers.tickers['MCHP'].info["pegRatio"])
pegRatio.append(tickers.tickers['MU'].info["pegRatio"])
pegRatio.append(tickers.tickers['MSFT'].info["pegRatio"])
pegRatio.append(tickers.tickers['MPWR'].info["pegRatio"])
pegRatio.append(tickers.tickers['MSI'].info["pegRatio"])
pegRatio.append(tickers.tickers['NTAP'].info["pegRatio"])
pegRatio.append(tickers.tickers['NLOK'].info["pegRatio"])
pegRatio.append(tickers.tickers['NVDA'].info["pegRatio"])
pegRatio.append(tickers.tickers['NXPI'].info["pegRatio"])
pegRatio.append(tickers.tickers['ORCL'].info["pegRatio"])
pegRatio.append(tickers.tickers['PAYX'].info["pegRatio"])
pegRatio.append(tickers.tickers['PAYC'].info["pegRatio"])
pegRatio.append(tickers.tickers['PYPL'].info["pegRatio"])
pegRatio.append(tickers.tickers['PTC'].info["pegRatio"])
pegRatio.append(tickers.tickers['QRVO'].info["pegRatio"])
pegRatio.append(tickers.tickers['QCOM'].info["pegRatio"])
pegRatio.append(tickers.tickers['CRM'].info["pegRatio"])
pegRatio.append(tickers.tickers['STX'].info["pegRatio"])
pegRatio.append(tickers.tickers['NOW'].info["pegRatio"])
pegRatio.append(tickers.tickers['SWKS'].info["pegRatio"])
pegRatio.append(tickers.tickers['SNPS'].info["pegRatio"])
pegRatio.append(tickers.tickers['TEL'].info["pegRatio"])
pegRatio.append(tickers.tickers['TER'].info["pegRatio"])
pegRatio.append(tickers.tickers['TXN'].info["pegRatio"])
pegRatio.append(tickers.tickers['TRMB'].info["pegRatio"])
pegRatio.append(tickers.tickers['TYL'].info["pegRatio"])
pegRatio.append(tickers.tickers['VRSN'].info["pegRatio"])
pegRatio.append(tickers.tickers['V'].info["pegRatio"])
pegRatio.append(tickers.tickers['WDC'].info["pegRatio"])
pegRatio.append(tickers.tickers['WU'].info["pegRatio"])
pegRatio.append(tickers.tickers['XLNX'].info["pegRatio"])
pegRatio.append(tickers.tickers['ZBRA'].info["pegRatio"])


print("-----------------------------------------  PEG RATIO Calculated Successfully   -----------------------------------------\n")

#----------------------------------------------------   QUICK RATIO   ----------------------------------------------------

quickRatio = []
print("\n-----------------------------------------------    Calculating QUICK RATIO  -----------------------------------------------")
quickRatio.append(tickers.tickers['ACN'].info["quickRatio"])
quickRatio.append(tickers.tickers['ADBE'].info["quickRatio"])
quickRatio.append(tickers.tickers['AMD'].info["quickRatio"])
quickRatio.append(tickers.tickers['AKAM'].info["quickRatio"])
quickRatio.append(tickers.tickers['APH'].info["quickRatio"])
quickRatio.append(tickers.tickers['ADI'].info["quickRatio"])
quickRatio.append(tickers.tickers['ANSS'].info["quickRatio"])
quickRatio.append(tickers.tickers['AAPL'].info["quickRatio"])
quickRatio.append(tickers.tickers['AMAT'].info["quickRatio"])
quickRatio.append(tickers.tickers['ANET'].info["quickRatio"])
quickRatio.append(tickers.tickers['ADSK'].info["quickRatio"])
quickRatio.append(tickers.tickers['ADP'].info["quickRatio"])
quickRatio.append(tickers.tickers['AVGO'].info["quickRatio"])
quickRatio.append(tickers.tickers['BR'].info["quickRatio"])
quickRatio.append(tickers.tickers['CDNS'].info["quickRatio"])
quickRatio.append(tickers.tickers['CDW'].info["quickRatio"])
quickRatio.append(tickers.tickers['CDAY'].info["quickRatio"])
quickRatio.append(tickers.tickers['CSCO'].info["quickRatio"])
quickRatio.append(tickers.tickers['CTXS'].info["quickRatio"])
quickRatio.append(tickers.tickers['CTSH'].info["quickRatio"])
quickRatio.append(tickers.tickers['GLW'].info["quickRatio"])
quickRatio.append(tickers.tickers['DXC'].info["quickRatio"])
quickRatio.append(tickers.tickers['ENPH'].info["quickRatio"])
quickRatio.append(tickers.tickers['FFIV'].info["quickRatio"])
quickRatio.append(tickers.tickers['FIS'].info["quickRatio"])
quickRatio.append(tickers.tickers['FISV'].info["quickRatio"])
quickRatio.append(tickers.tickers['FLT'].info["quickRatio"])
quickRatio.append(tickers.tickers['FTNT'].info["quickRatio"])
quickRatio.append(tickers.tickers['IT'].info["quickRatio"])
quickRatio.append(tickers.tickers['GPN'].info["quickRatio"])
quickRatio.append(tickers.tickers['HPE'].info["quickRatio"])
quickRatio.append(tickers.tickers['HPQ'].info["quickRatio"])
quickRatio.append(tickers.tickers['INTC'].info["quickRatio"])
quickRatio.append(tickers.tickers['IBM'].info["quickRatio"])
quickRatio.append(tickers.tickers['INTU'].info["quickRatio"])
quickRatio.append(tickers.tickers['IPGP'].info["quickRatio"])
quickRatio.append(tickers.tickers['JKHY'].info["quickRatio"])
quickRatio.append(tickers.tickers['JNPR'].info["quickRatio"])
quickRatio.append(tickers.tickers['KEYS'].info["quickRatio"])
quickRatio.append(tickers.tickers['KLAC'].info["quickRatio"])
quickRatio.append(tickers.tickers['LRCX'].info["quickRatio"])
quickRatio.append(tickers.tickers['MA'].info["quickRatio"])
quickRatio.append(tickers.tickers['MCHP'].info["quickRatio"])
quickRatio.append(tickers.tickers['MU'].info["quickRatio"])
quickRatio.append(tickers.tickers['MSFT'].info["quickRatio"])
quickRatio.append(tickers.tickers['MPWR'].info["quickRatio"])
quickRatio.append(tickers.tickers['MSI'].info["quickRatio"])
quickRatio.append(tickers.tickers['NTAP'].info["quickRatio"])
quickRatio.append(tickers.tickers['NLOK'].info["quickRatio"])
quickRatio.append(tickers.tickers['NVDA'].info["quickRatio"])
quickRatio.append(tickers.tickers['NXPI'].info["quickRatio"])
quickRatio.append(tickers.tickers['ORCL'].info["quickRatio"])
quickRatio.append(tickers.tickers['PAYX'].info["quickRatio"])
quickRatio.append(tickers.tickers['PAYC'].info["quickRatio"])
quickRatio.append(tickers.tickers['PYPL'].info["quickRatio"])
quickRatio.append(tickers.tickers['PTC'].info["quickRatio"])
quickRatio.append(tickers.tickers['QRVO'].info["quickRatio"])
quickRatio.append(tickers.tickers['QCOM'].info["quickRatio"])
quickRatio.append(tickers.tickers['CRM'].info["quickRatio"])
quickRatio.append(tickers.tickers['STX'].info["quickRatio"])
quickRatio.append(tickers.tickers['NOW'].info["quickRatio"])
quickRatio.append(tickers.tickers['SWKS'].info["quickRatio"])
quickRatio.append(tickers.tickers['SNPS'].info["quickRatio"])
quickRatio.append(tickers.tickers['TEL'].info["quickRatio"])
quickRatio.append(tickers.tickers['TER'].info["quickRatio"])
quickRatio.append(tickers.tickers['TXN'].info["quickRatio"])
quickRatio.append(tickers.tickers['TRMB'].info["quickRatio"])
quickRatio.append(tickers.tickers['TYL'].info["quickRatio"])
quickRatio.append(tickers.tickers['VRSN'].info["quickRatio"])
quickRatio.append(tickers.tickers['V'].info["quickRatio"])
quickRatio.append(tickers.tickers['WDC'].info["quickRatio"])
quickRatio.append(tickers.tickers['WU'].info["quickRatio"])
quickRatio.append(tickers.tickers['XLNX'].info["quickRatio"])
quickRatio.append(tickers.tickers['ZBRA'].info["quickRatio"])

print("-----------------------------------------  QUICK RATIO Calculated Successfully   -----------------------------------------\n")

#----------------------------------------------------   DIVIDEND YIELD   ----------------------------------------------------

dividendYield = []
print("\n-----------------------------------------------    Calculating DIVIDEND YIELD  -----------------------------------------------")
dividendYield.append(tickers.tickers['ACN'].info["dividendYield"])
dividendYield.append(tickers.tickers['ADBE'].info["dividendYield"])
dividendYield.append(tickers.tickers['AMD'].info["dividendYield"])
dividendYield.append(tickers.tickers['AKAM'].info["dividendYield"])
dividendYield.append(tickers.tickers['APH'].info["dividendYield"])
dividendYield.append(tickers.tickers['ADI'].info["dividendYield"])
dividendYield.append(tickers.tickers['ANSS'].info["dividendYield"])
dividendYield.append(tickers.tickers['AAPL'].info["dividendYield"])
dividendYield.append(tickers.tickers['AMAT'].info["dividendYield"])
dividendYield.append(tickers.tickers['ANET'].info["dividendYield"])
dividendYield.append(tickers.tickers['ADSK'].info["dividendYield"])
dividendYield.append(tickers.tickers['ADP'].info["dividendYield"])
dividendYield.append(tickers.tickers['AVGO'].info["dividendYield"])
dividendYield.append(tickers.tickers['BR'].info["dividendYield"])
dividendYield.append(tickers.tickers['CDNS'].info["dividendYield"])
dividendYield.append(tickers.tickers['CDW'].info["dividendYield"])
dividendYield.append(tickers.tickers['CDAY'].info["dividendYield"])
dividendYield.append(tickers.tickers['CSCO'].info["dividendYield"])
dividendYield.append(tickers.tickers['CTXS'].info["dividendYield"])
dividendYield.append(tickers.tickers['CTSH'].info["dividendYield"])
dividendYield.append(tickers.tickers['GLW'].info["dividendYield"])
dividendYield.append(tickers.tickers['DXC'].info["dividendYield"])
dividendYield.append(tickers.tickers['ENPH'].info["dividendYield"])
dividendYield.append(tickers.tickers['FFIV'].info["dividendYield"])
dividendYield.append(tickers.tickers['FIS'].info["dividendYield"])
dividendYield.append(tickers.tickers['FISV'].info["dividendYield"])
dividendYield.append(tickers.tickers['FLT'].info["dividendYield"])
dividendYield.append(tickers.tickers['FTNT'].info["dividendYield"])
dividendYield.append(tickers.tickers['IT'].info["dividendYield"])
dividendYield.append(tickers.tickers['GPN'].info["dividendYield"])
dividendYield.append(tickers.tickers['HPE'].info["dividendYield"])
dividendYield.append(tickers.tickers['HPQ'].info["dividendYield"])
dividendYield.append(tickers.tickers['INTC'].info["dividendYield"])
dividendYield.append(tickers.tickers['IBM'].info["dividendYield"])
dividendYield.append(tickers.tickers['INTU'].info["dividendYield"])
dividendYield.append(tickers.tickers['IPGP'].info["dividendYield"])
dividendYield.append(tickers.tickers['JKHY'].info["dividendYield"])
dividendYield.append(tickers.tickers['JNPR'].info["dividendYield"])
dividendYield.append(tickers.tickers['KEYS'].info["dividendYield"])
dividendYield.append(tickers.tickers['KLAC'].info["dividendYield"])
dividendYield.append(tickers.tickers['LRCX'].info["dividendYield"])
dividendYield.append(tickers.tickers['MA'].info["dividendYield"])
dividendYield.append(tickers.tickers['MCHP'].info["dividendYield"])
dividendYield.append(tickers.tickers['MU'].info["dividendYield"])
dividendYield.append(tickers.tickers['MSFT'].info["dividendYield"])
dividendYield.append(tickers.tickers['MPWR'].info["dividendYield"])
dividendYield.append(tickers.tickers['MSI'].info["dividendYield"])
dividendYield.append(tickers.tickers['NTAP'].info["dividendYield"])
dividendYield.append(tickers.tickers['NLOK'].info["dividendYield"])
dividendYield.append(tickers.tickers['NVDA'].info["dividendYield"])
dividendYield.append(tickers.tickers['NXPI'].info["dividendYield"])
dividendYield.append(tickers.tickers['ORCL'].info["dividendYield"])
dividendYield.append(tickers.tickers['PAYX'].info["dividendYield"])
dividendYield.append(tickers.tickers['PAYC'].info["dividendYield"])
dividendYield.append(tickers.tickers['PYPL'].info["dividendYield"])
dividendYield.append(tickers.tickers['PTC'].info["dividendYield"])
dividendYield.append(tickers.tickers['QRVO'].info["dividendYield"])
dividendYield.append(tickers.tickers['QCOM'].info["dividendYield"])
dividendYield.append(tickers.tickers['CRM'].info["dividendYield"])
dividendYield.append(tickers.tickers['STX'].info["dividendYield"])
dividendYield.append(tickers.tickers['NOW'].info["dividendYield"])
dividendYield.append(tickers.tickers['SWKS'].info["dividendYield"])
dividendYield.append(tickers.tickers['SNPS'].info["dividendYield"])
dividendYield.append(tickers.tickers['TEL'].info["dividendYield"])
dividendYield.append(tickers.tickers['TER'].info["dividendYield"])
dividendYield.append(tickers.tickers['TXN'].info["dividendYield"])
dividendYield.append(tickers.tickers['TRMB'].info["dividendYield"])
dividendYield.append(tickers.tickers['TYL'].info["dividendYield"])
dividendYield.append(tickers.tickers['VRSN'].info["dividendYield"])
dividendYield.append(tickers.tickers['V'].info["dividendYield"])
dividendYield.append(tickers.tickers['WDC'].info["dividendYield"])
dividendYield.append(tickers.tickers['WU'].info["dividendYield"])
dividendYield.append(tickers.tickers['XLNX'].info["dividendYield"])
dividendYield.append(tickers.tickers['ZBRA'].info["dividendYield"])

print("-----------------------------------------  DIVIDEND YIELD Calculated Successfully   -----------------------------------------\n")

#----------------------------------------------------   TRAILING EPS   ----------------------------------------------------

trailingEps = []
print("\n-----------------------------------------------    Calculating TRAILING EPS  -----------------------------------------------")
trailingEps.append(tickers.tickers['ACN'].info["trailingEps"])
trailingEps.append(tickers.tickers['ADBE'].info["trailingEps"])
trailingEps.append(tickers.tickers['AMD'].info["trailingEps"])
trailingEps.append(tickers.tickers['AKAM'].info["trailingEps"])
trailingEps.append(tickers.tickers['APH'].info["trailingEps"])
trailingEps.append(tickers.tickers['ADI'].info["trailingEps"])
trailingEps.append(tickers.tickers['ANSS'].info["trailingEps"])
trailingEps.append(tickers.tickers['AAPL'].info["trailingEps"])
trailingEps.append(tickers.tickers['AMAT'].info["trailingEps"])
trailingEps.append(tickers.tickers['ANET'].info["trailingEps"])
trailingEps.append(tickers.tickers['ADSK'].info["trailingEps"])
trailingEps.append(tickers.tickers['ADP'].info["trailingEps"])
trailingEps.append(tickers.tickers['AVGO'].info["trailingEps"])
trailingEps.append(tickers.tickers['BR'].info["trailingEps"])
trailingEps.append(tickers.tickers['CDNS'].info["trailingEps"])
trailingEps.append(tickers.tickers['CDW'].info["trailingEps"])
trailingEps.append(tickers.tickers['CDAY'].info["trailingEps"])
trailingEps.append(tickers.tickers['CSCO'].info["trailingEps"])
trailingEps.append(tickers.tickers['CTXS'].info["trailingEps"])
trailingEps.append(tickers.tickers['CTSH'].info["trailingEps"])
trailingEps.append(tickers.tickers['GLW'].info["trailingEps"])
trailingEps.append(tickers.tickers['DXC'].info["trailingEps"])
trailingEps.append(tickers.tickers['ENPH'].info["trailingEps"])
trailingEps.append(tickers.tickers['FFIV'].info["trailingEps"])
trailingEps.append(tickers.tickers['FIS'].info["trailingEps"])
trailingEps.append(tickers.tickers['FISV'].info["trailingEps"])
trailingEps.append(tickers.tickers['FLT'].info["trailingEps"])
trailingEps.append(tickers.tickers['FTNT'].info["trailingEps"])
trailingEps.append(tickers.tickers['IT'].info["trailingEps"])
trailingEps.append(tickers.tickers['GPN'].info["trailingEps"])
trailingEps.append(tickers.tickers['HPE'].info["trailingEps"])
trailingEps.append(tickers.tickers['HPQ'].info["trailingEps"])
trailingEps.append(tickers.tickers['INTC'].info["trailingEps"])
trailingEps.append(tickers.tickers['IBM'].info["trailingEps"])
trailingEps.append(tickers.tickers['INTU'].info["trailingEps"])
trailingEps.append(tickers.tickers['IPGP'].info["trailingEps"])
trailingEps.append(tickers.tickers['JKHY'].info["trailingEps"])
trailingEps.append(tickers.tickers['JNPR'].info["trailingEps"])
trailingEps.append(tickers.tickers['KEYS'].info["trailingEps"])
trailingEps.append(tickers.tickers['KLAC'].info["trailingEps"])
trailingEps.append(tickers.tickers['LRCX'].info["trailingEps"])
trailingEps.append(tickers.tickers['MA'].info["trailingEps"])
trailingEps.append(tickers.tickers['MCHP'].info["trailingEps"])
trailingEps.append(tickers.tickers['MU'].info["trailingEps"])
trailingEps.append(tickers.tickers['MSFT'].info["trailingEps"])
trailingEps.append(tickers.tickers['MPWR'].info["trailingEps"])
trailingEps.append(tickers.tickers['MSI'].info["trailingEps"])
trailingEps.append(tickers.tickers['NTAP'].info["trailingEps"])
trailingEps.append(tickers.tickers['NLOK'].info["trailingEps"])
trailingEps.append(tickers.tickers['NVDA'].info["trailingEps"])
trailingEps.append(tickers.tickers['NXPI'].info["trailingEps"])
trailingEps.append(tickers.tickers['ORCL'].info["trailingEps"])
trailingEps.append(tickers.tickers['PAYX'].info["trailingEps"])
trailingEps.append(tickers.tickers['PAYC'].info["trailingEps"])
trailingEps.append(tickers.tickers['PYPL'].info["trailingEps"])
trailingEps.append(tickers.tickers['PTC'].info["trailingEps"])
trailingEps.append(tickers.tickers['QRVO'].info["trailingEps"])
trailingEps.append(tickers.tickers['QCOM'].info["trailingEps"])
trailingEps.append(tickers.tickers['CRM'].info["trailingEps"])
trailingEps.append(tickers.tickers['STX'].info["trailingEps"])
trailingEps.append(tickers.tickers['NOW'].info["trailingEps"])
trailingEps.append(tickers.tickers['SWKS'].info["trailingEps"])
trailingEps.append(tickers.tickers['SNPS'].info["trailingEps"])
trailingEps.append(tickers.tickers['TEL'].info["trailingEps"])
trailingEps.append(tickers.tickers['TER'].info["trailingEps"])
trailingEps.append(tickers.tickers['TXN'].info["trailingEps"])
trailingEps.append(tickers.tickers['TRMB'].info["trailingEps"])
trailingEps.append(tickers.tickers['TYL'].info["trailingEps"])
trailingEps.append(tickers.tickers['VRSN'].info["trailingEps"])
trailingEps.append(tickers.tickers['V'].info["trailingEps"])
trailingEps.append(tickers.tickers['WDC'].info["trailingEps"])
trailingEps.append(tickers.tickers['WU'].info["trailingEps"])
trailingEps.append(tickers.tickers['XLNX'].info["trailingEps"])
trailingEps.append(tickers.tickers['ZBRA'].info["trailingEps"])

print("-----------------------------------------  TRAILING EPS Calculated Successfully   -----------------------------------------\n")
os.system('say "Shubh, your program ran successfully"')
# Out:
# -----------------------------------------------    Calculating TRALING PE  -----------------------------------------------
# -----------------------------------------  TRAILING PE RATIO Calculated Successfully   -----------------------------------------
#
#
# -----------------------------------------------    Calculating PEG RATIO   -----------------------------------------------
# -----------------------------------------  PEG RATIO Calculated Successfully   -----------------------------------------
#
#
# -----------------------------------------------    Calculating QUICK RATIO  -----------------------------------------------
# -----------------------------------------  QUICK RATIO Calculated Successfully   -----------------------------------------
#
#
# -----------------------------------------------    Calculating DIVIDEND YIELD  -----------------------------------------------
# ...

# %%
dummy3["Trailing PE"] = trailingPE
dummy3["Peg Ratio"] = pegRatio
dummy3["Trailing EPS"] = trailingEps
dummy3["Current Ratio"] = currentRatio
dummy3["Quick Ratio"] = quickRatio
dummy3["Dividend Yield"] = dividendYield
dummy3 = dummy3.drop(columns=['SEC filings','CIK'])
dummy3.to_csv("InformationTechnology.csv")
os.system('say "Shubh, your program ran successfully"')
# Out:
# /Users/shubhammandhare/opt/anaconda3/envs/540/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/shubhammandhare/opt/anaconda3/envs/540/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/shubhammandhare/opt/anaconda3/envs/540/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
#-------------------------------------------------------------------------------------------------------------------------
##################################################      HEALTH CARE    ##################################################
#-------------------------------------------------------------------------------------------------------------------------

print("\n--------------------------------    FETCHING DATA for HEALTH CARE SECTOR   -----------------------------------")
tickers = yf.Tickers("ABT ABBV ABMD A ALGN ABC AMGN ANTM BAX BDX BIO TECH BIIB BSX BMY CAH CTLT CNC CERN CRL CI COO CVS DHR DVA XRAY DXCM EW GILD HCA HSIC HOLX HUM IDXX ILMN INCY ISRG IQV JNJ LH LLY MCK MDT MRK MTD MRNA OGN PKI PFE DGX REGN RMD STE SYK TFX TMO UNH UHS VRTX VTRS WAT WST ZBH ZTS")
print("-----------------------------------------------    DATA FETCHED SUCCESSFULLY   -----------------------------------------------\n")
dummy5 = pd.DataFrame()
dummy5 = df[df["GICS Sector"]=="Health Care"]

#----------------------------------------------------   CURRENT RATIO   ----------------------------------------------------

currentRatio = []
print("\n-----------------------------------------------    Calculating CURRENT RATIO  -----------------------------------------------")
currentRatio.append(tickers.tickers['ABT'].info["currentRatio"])
currentRatio.append(tickers.tickers['ABBV'].info["currentRatio"])
currentRatio.append(tickers.tickers['ABMD'].info["currentRatio"])
currentRatio.append(tickers.tickers['A'].info["currentRatio"])
currentRatio.append(tickers.tickers['ALGN'].info["currentRatio"])
currentRatio.append(tickers.tickers['ABC'].info["currentRatio"])
currentRatio.append(tickers.tickers['AMGN'].info["currentRatio"])
currentRatio.append(tickers.tickers['ANTM'].info["currentRatio"])
currentRatio.append(tickers.tickers['BAX'].info["currentRatio"])
currentRatio.append(tickers.tickers['BDX'].info["currentRatio"])
currentRatio.append(tickers.tickers['BIO'].info["currentRatio"])
currentRatio.append(tickers.tickers['TECH'].info["currentRatio"])
currentRatio.append(tickers.tickers['BIIB'].info["currentRatio"])
currentRatio.append(tickers.tickers['BSX'].info["currentRatio"])
currentRatio.append(tickers.tickers['BMY'].info["currentRatio"])
currentRatio.append(tickers.tickers['CAH'].info["currentRatio"])
currentRatio.append(tickers.tickers['CTLT'].info["currentRatio"])
currentRatio.append(tickers.tickers['CNC'].info["currentRatio"])
currentRatio.append(tickers.tickers['CERN'].info["currentRatio"])
currentRatio.append(tickers.tickers['CRL'].info["currentRatio"])
currentRatio.append(tickers.tickers['CI'].info["currentRatio"])
currentRatio.append(tickers.tickers['COO'].info["currentRatio"])
currentRatio.append(tickers.tickers['CVS'].info["currentRatio"])
currentRatio.append(tickers.tickers['DHR'].info["currentRatio"])
currentRatio.append(tickers.tickers['DVA'].info["currentRatio"])
currentRatio.append(tickers.tickers['XRAY'].info["currentRatio"])
currentRatio.append(tickers.tickers['DXCM'].info["currentRatio"])
currentRatio.append(tickers.tickers['EW'].info["currentRatio"])
currentRatio.append(tickers.tickers['GILD'].info["currentRatio"])
currentRatio.append(tickers.tickers['HCA'].info["currentRatio"])
currentRatio.append(tickers.tickers['HSIC'].info["currentRatio"])
currentRatio.append(tickers.tickers['HOLX'].info["currentRatio"])
currentRatio.append(tickers.tickers['HUM'].info["currentRatio"])
currentRatio.append(tickers.tickers['IDXX'].info["currentRatio"])
currentRatio.append(tickers.tickers['ILMN'].info["currentRatio"])
currentRatio.append(tickers.tickers['INCY'].info["currentRatio"])
currentRatio.append(tickers.tickers['ISRG'].info["currentRatio"])
currentRatio.append(tickers.tickers['IQV'].info["currentRatio"])
currentRatio.append(tickers.tickers['JNJ'].info["currentRatio"])
currentRatio.append(tickers.tickers['LH'].info["currentRatio"])
currentRatio.append(tickers.tickers['LLY'].info["currentRatio"])
currentRatio.append(tickers.tickers['MCK'].info["currentRatio"])
currentRatio.append(tickers.tickers['MDT'].info["currentRatio"])
currentRatio.append(tickers.tickers['MRK'].info["currentRatio"])
currentRatio.append(tickers.tickers['MTD'].info["currentRatio"])
currentRatio.append(tickers.tickers['MRNA'].info["currentRatio"])
currentRatio.append(tickers.tickers['OGN'].info["currentRatio"])
currentRatio.append(tickers.tickers['PKI'].info["currentRatio"])
currentRatio.append(tickers.tickers['PFE'].info["currentRatio"])
currentRatio.append(tickers.tickers['DGX'].info["currentRatio"])
currentRatio.append(tickers.tickers['REGN'].info["currentRatio"])
currentRatio.append(tickers.tickers['RMD'].info["currentRatio"])
currentRatio.append(tickers.tickers['STE'].info["currentRatio"])
currentRatio.append(tickers.tickers['SYK'].info["currentRatio"])
currentRatio.append(tickers.tickers['TFX'].info["currentRatio"])
currentRatio.append(tickers.tickers['TMO'].info["currentRatio"])
currentRatio.append(tickers.tickers['UNH'].info["currentRatio"])
currentRatio.append(tickers.tickers['UHS'].info["currentRatio"])
currentRatio.append(tickers.tickers['VRTX'].info["currentRatio"])
currentRatio.append(tickers.tickers['VTRS'].info["currentRatio"])
currentRatio.append(tickers.tickers['WAT'].info["currentRatio"])
currentRatio.append(tickers.tickers['WST'].info["currentRatio"])
currentRatio.append(tickers.tickers['ZBH'].info["currentRatio"])
currentRatio.append(tickers.tickers['ZTS'].info["currentRatio"])

print("-----------------------------------------  CURRENT RATIO Calculated Successfully   -----------------------------------------\n")



os.system('say "Shubh, your program ran successfully"')
# Out:
# --------------------------------    FETCHING DATA for HEALTH CARE SECTOR   -----------------------------------
# -----------------------------------------------    DATA FETCHED SUCCESSFULLY   -----------------------------------------------
#
#
# -----------------------------------------------    Calculating CURRENT RATIO  -----------------------------------------------
# -----------------------------------------  CURRENT RATIO Calculated Successfully   -----------------------------------------
# 0

# %%
#----------------------------------------------------   DIVIDEND YIELD   ----------------------------------------------------

dividendYield = []
print("\n-----------------------------------------------    Calculating DIVIDEND YIELD  -----------------------------------------------")
dividendYield.append(tickers.tickers['ABT'].info["dividendYield"])
dividendYield.append(tickers.tickers['ABBV'].info["dividendYield"])
dividendYield.append(tickers.tickers['ABMD'].info["dividendYield"])
dividendYield.append(tickers.tickers['A'].info["dividendYield"])
dividendYield.append(tickers.tickers['ALGN'].info["dividendYield"])
dividendYield.append(tickers.tickers['ABC'].info["dividendYield"])
dividendYield.append(tickers.tickers['AMGN'].info["dividendYield"])
dividendYield.append(tickers.tickers['ANTM'].info["dividendYield"])
dividendYield.append(tickers.tickers['BAX'].info["dividendYield"])
dividendYield.append(tickers.tickers['BDX'].info["dividendYield"])
dividendYield.append(tickers.tickers['BIO'].info["dividendYield"])
dividendYield.append(tickers.tickers['TECH'].info["dividendYield"])
dividendYield.append(tickers.tickers['BIIB'].info["dividendYield"])
dividendYield.append(tickers.tickers['BSX'].info["dividendYield"])
dividendYield.append(tickers.tickers['BMY'].info["dividendYield"])
dividendYield.append(tickers.tickers['CAH'].info["dividendYield"])
dividendYield.append(tickers.tickers['CTLT'].info["dividendYield"])
dividendYield.append(tickers.tickers['CNC'].info["dividendYield"])
dividendYield.append(tickers.tickers['CERN'].info["dividendYield"])
dividendYield.append(tickers.tickers['CRL'].info["dividendYield"])
dividendYield.append(tickers.tickers['CI'].info["dividendYield"])
dividendYield.append(tickers.tickers['COO'].info["dividendYield"])
dividendYield.append(tickers.tickers['CVS'].info["dividendYield"])
dividendYield.append(tickers.tickers['DHR'].info["dividendYield"])
dividendYield.append(tickers.tickers['DVA'].info["dividendYield"])
dividendYield.append(tickers.tickers['XRAY'].info["dividendYield"])
dividendYield.append(tickers.tickers['DXCM'].info["dividendYield"])
dividendYield.append(tickers.tickers['EW'].info["dividendYield"])
dividendYield.append(tickers.tickers['GILD'].info["dividendYield"])
dividendYield.append(tickers.tickers['HCA'].info["dividendYield"])
dividendYield.append(tickers.tickers['HSIC'].info["dividendYield"])
dividendYield.append(tickers.tickers['HOLX'].info["dividendYield"])
dividendYield.append(tickers.tickers['HUM'].info["dividendYield"])
dividendYield.append(tickers.tickers['IDXX'].info["dividendYield"])
dividendYield.append(tickers.tickers['ILMN'].info["dividendYield"])
dividendYield.append(tickers.tickers['INCY'].info["dividendYield"])
dividendYield.append(tickers.tickers['ISRG'].info["dividendYield"])
dividendYield.append(tickers.tickers['IQV'].info["dividendYield"])
dividendYield.append(tickers.tickers['JNJ'].info["dividendYield"])
dividendYield.append(tickers.tickers['LH'].info["dividendYield"])
dividendYield.append(tickers.tickers['LLY'].info["dividendYield"])
dividendYield.append(tickers.tickers['MCK'].info["dividendYield"])
dividendYield.append(tickers.tickers['MDT'].info["dividendYield"])
dividendYield.append(tickers.tickers['MRK'].info["dividendYield"])
dividendYield.append(tickers.tickers['MTD'].info["dividendYield"])
dividendYield.append(tickers.tickers['MRNA'].info["dividendYield"])
dividendYield.append(tickers.tickers['OGN'].info["dividendYield"])
dividendYield.append(tickers.tickers['PKI'].info["dividendYield"])
dividendYield.append(tickers.tickers['PFE'].info["dividendYield"])
dividendYield.append(tickers.tickers['DGX'].info["dividendYield"])
dividendYield.append(tickers.tickers['REGN'].info["dividendYield"])
dividendYield.append(tickers.tickers['RMD'].info["dividendYield"])
dividendYield.append(tickers.tickers['STE'].info["dividendYield"])
dividendYield.append(tickers.tickers['SYK'].info["dividendYield"])
dividendYield.append(tickers.tickers['TFX'].info["dividendYield"])
dividendYield.append(tickers.tickers['TMO'].info["dividendYield"])
dividendYield.append(tickers.tickers['UNH'].info["dividendYield"])
dividendYield.append(tickers.tickers['UHS'].info["dividendYield"])
dividendYield.append(tickers.tickers['VRTX'].info["dividendYield"])
dividendYield.append(tickers.tickers['VTRS'].info["forwardPE"])
dividendYield.append(tickers.tickers['WAT'].info["dividendYield"])
dividendYield.append(tickers.tickers['WST'].info["dividendYield"])
dividendYield.append(tickers.tickers['ZBH'].info["dividendYield"])
dividendYield.append(tickers.tickers['ZTS'].info["dividendYield"])

print("-----------------------------------------  DIVIDEND YIELD Calculated Successfully   -----------------------------------------\n")

#----------------------------------------------------   TRALING PE RATIO   ----------------------------------------------------
# BMY,MCK, VTRS
trailingPE = []
print("\n-----------------------------------------------    Calculating TRALING PE  -----------------------------------------------")
trailingPE.append(tickers.tickers['ABT'].info["trailingPE"])
trailingPE.append(tickers.tickers['ABBV'].info["trailingPE"])
trailingPE.append(tickers.tickers['ABMD'].info["trailingPE"])
trailingPE.append(tickers.tickers['A'].info["trailingPE"])
trailingPE.append(tickers.tickers['ALGN'].info["trailingPE"])
trailingPE.append(tickers.tickers['ABC'].info["trailingPE"])
trailingPE.append(tickers.tickers['AMGN'].info["trailingPE"])
trailingPE.append(tickers.tickers['ANTM'].info["trailingPE"])
trailingPE.append(tickers.tickers['BAX'].info["trailingPE"])
trailingPE.append(tickers.tickers['BDX'].info["trailingPE"])
trailingPE.append(tickers.tickers['BIO'].info["trailingPE"])
trailingPE.append(tickers.tickers['TECH'].info["trailingPE"])
trailingPE.append(tickers.tickers['BIIB'].info["trailingPE"])
trailingPE.append(tickers.tickers['BSX'].info["trailingPE"])
trailingPE.append(tickers.tickers['BMY'].info["forwardPE"])
trailingPE.append(tickers.tickers['CAH'].info["trailingPE"])
trailingPE.append(tickers.tickers['CTLT'].info["trailingPE"])
trailingPE.append(tickers.tickers['CNC'].info["trailingPE"])
trailingPE.append(tickers.tickers['CERN'].info["trailingPE"])
trailingPE.append(tickers.tickers['CRL'].info["trailingPE"])
trailingPE.append(tickers.tickers['CI'].info["trailingPE"])
trailingPE.append(tickers.tickers['COO'].info["trailingPE"])
trailingPE.append(tickers.tickers['CVS'].info["trailingPE"])
trailingPE.append(tickers.tickers['DHR'].info["trailingPE"])
trailingPE.append(tickers.tickers['DVA'].info["trailingPE"])
trailingPE.append(tickers.tickers['XRAY'].info["trailingPE"])
trailingPE.append(tickers.tickers['DXCM'].info["trailingPE"])
trailingPE.append(tickers.tickers['EW'].info["trailingPE"])
trailingPE.append(tickers.tickers['GILD'].info["trailingPE"])
trailingPE.append(tickers.tickers['HCA'].info["trailingPE"])
trailingPE.append(tickers.tickers['HSIC'].info["trailingPE"])
trailingPE.append(tickers.tickers['HOLX'].info["trailingPE"])
trailingPE.append(tickers.tickers['HUM'].info["trailingPE"])
trailingPE.append(tickers.tickers['IDXX'].info["trailingPE"])
trailingPE.append(tickers.tickers['ILMN'].info["trailingPE"])
trailingPE.append(tickers.tickers['INCY'].info["trailingPE"])
trailingPE.append(tickers.tickers['ISRG'].info["trailingPE"])
trailingPE.append(tickers.tickers['IQV'].info["trailingPE"])
trailingPE.append(tickers.tickers['JNJ'].info["trailingPE"])
trailingPE.append(tickers.tickers['LH'].info["trailingPE"])
trailingPE.append(tickers.tickers['LLY'].info["trailingPE"])
trailingPE.append(tickers.tickers['MCK'].info["forwardPE"])
trailingPE.append(tickers.tickers['MDT'].info["trailingPE"])
trailingPE.append(tickers.tickers['MRK'].info["trailingPE"])
trailingPE.append(tickers.tickers['MTD'].info["trailingPE"])
trailingPE.append(tickers.tickers['MRNA'].info["trailingPE"])
trailingPE.append(tickers.tickers['OGN'].info["forwardPE"])
trailingPE.append(tickers.tickers['PKI'].info["trailingPE"])
trailingPE.append(tickers.tickers['PFE'].info["trailingPE"])
trailingPE.append(tickers.tickers['DGX'].info["trailingPE"])
trailingPE.append(tickers.tickers['REGN'].info["trailingPE"])
trailingPE.append(tickers.tickers['RMD'].info["trailingPE"])
trailingPE.append(tickers.tickers['STE'].info["trailingPE"])
trailingPE.append(tickers.tickers['SYK'].info["trailingPE"])
trailingPE.append(tickers.tickers['TFX'].info["trailingPE"])
trailingPE.append(tickers.tickers['TMO'].info["trailingPE"])
trailingPE.append(tickers.tickers['UNH'].info["trailingPE"])
trailingPE.append(tickers.tickers['UHS'].info["trailingPE"])
trailingPE.append(tickers.tickers['VRTX'].info["trailingPE"])
trailingPE.append(tickers.tickers['VTRS'].info["forwardPE"])
trailingPE.append(tickers.tickers['WAT'].info["trailingPE"])
trailingPE.append(tickers.tickers['WST'].info["trailingPE"])
trailingPE.append(tickers.tickers['ZBH'].info["trailingPE"])
trailingPE.append(tickers.tickers['ZTS'].info["trailingPE"])


#----------------------------------------------------   QUICK RATIO   ----------------------------------------------------

quickRatio = []
print("\n-----------------------------------------------    Calculating QUICK RATIO  -----------------------------------------------")
quickRatio.append(tickers.tickers['ABT'].info["quickRatio"])
quickRatio.append(tickers.tickers['ABBV'].info["quickRatio"])
quickRatio.append(tickers.tickers['ABMD'].info["quickRatio"])
quickRatio.append(tickers.tickers['A'].info["quickRatio"])
quickRatio.append(tickers.tickers['ALGN'].info["quickRatio"])
quickRatio.append(tickers.tickers['ABC'].info["quickRatio"])
quickRatio.append(tickers.tickers['AMGN'].info["quickRatio"])
quickRatio.append(tickers.tickers['ANTM'].info["quickRatio"])
quickRatio.append(tickers.tickers['BAX'].info["quickRatio"])
quickRatio.append(tickers.tickers['BDX'].info["quickRatio"])
quickRatio.append(tickers.tickers['BIO'].info["quickRatio"])
quickRatio.append(tickers.tickers['TECH'].info["quickRatio"])
quickRatio.append(tickers.tickers['BIIB'].info["quickRatio"])
quickRatio.append(tickers.tickers['BSX'].info["quickRatio"])
quickRatio.append(tickers.tickers['BMY'].info["quickRatio"])
quickRatio.append(tickers.tickers['CAH'].info["quickRatio"])
quickRatio.append(tickers.tickers['CTLT'].info["quickRatio"])
quickRatio.append(tickers.tickers['CNC'].info["quickRatio"])
quickRatio.append(tickers.tickers['CERN'].info["quickRatio"])
quickRatio.append(tickers.tickers['CRL'].info["quickRatio"])
quickRatio.append(tickers.tickers['CI'].info["quickRatio"])
quickRatio.append(tickers.tickers['COO'].info["quickRatio"])
quickRatio.append(tickers.tickers['CVS'].info["quickRatio"])
quickRatio.append(tickers.tickers['DHR'].info["quickRatio"])
quickRatio.append(tickers.tickers['DVA'].info["quickRatio"])
quickRatio.append(tickers.tickers['XRAY'].info["quickRatio"])
quickRatio.append(tickers.tickers['DXCM'].info["quickRatio"])
quickRatio.append(tickers.tickers['EW'].info["quickRatio"])
quickRatio.append(tickers.tickers['GILD'].info["quickRatio"])
quickRatio.append(tickers.tickers['HCA'].info["quickRatio"])
quickRatio.append(tickers.tickers['HSIC'].info["quickRatio"])
quickRatio.append(tickers.tickers['HOLX'].info["quickRatio"])
quickRatio.append(tickers.tickers['HUM'].info["quickRatio"])
quickRatio.append(tickers.tickers['IDXX'].info["quickRatio"])
quickRatio.append(tickers.tickers['ILMN'].info["quickRatio"])
quickRatio.append(tickers.tickers['INCY'].info["quickRatio"])
quickRatio.append(tickers.tickers['ISRG'].info["quickRatio"])
quickRatio.append(tickers.tickers['IQV'].info["quickRatio"])
quickRatio.append(tickers.tickers['JNJ'].info["quickRatio"])
quickRatio.append(tickers.tickers['LH'].info["quickRatio"])
quickRatio.append(tickers.tickers['LLY'].info["quickRatio"])
quickRatio.append(tickers.tickers['MCK'].info["quickRatio"])
quickRatio.append(tickers.tickers['MDT'].info["quickRatio"])
quickRatio.append(tickers.tickers['MRK'].info["quickRatio"])
quickRatio.append(tickers.tickers['MTD'].info["quickRatio"])
quickRatio.append(tickers.tickers['MRNA'].info["quickRatio"])
quickRatio.append(tickers.tickers['OGN'].info["quickRatio"])
quickRatio.append(tickers.tickers['PKI'].info["quickRatio"])
quickRatio.append(tickers.tickers['PFE'].info["quickRatio"])
quickRatio.append(tickers.tickers['DGX'].info["quickRatio"])
quickRatio.append(tickers.tickers['REGN'].info["quickRatio"])
quickRatio.append(tickers.tickers['RMD'].info["quickRatio"])
quickRatio.append(tickers.tickers['STE'].info["quickRatio"])
quickRatio.append(tickers.tickers['SYK'].info["quickRatio"])
quickRatio.append(tickers.tickers['TFX'].info["quickRatio"])
quickRatio.append(tickers.tickers['TMO'].info["quickRatio"])
quickRatio.append(tickers.tickers['UNH'].info["quickRatio"])
quickRatio.append(tickers.tickers['UHS'].info["quickRatio"])
quickRatio.append(tickers.tickers['VRTX'].info["quickRatio"])
quickRatio.append(tickers.tickers['VTRS'].info["quickRatio"])
quickRatio.append(tickers.tickers['WAT'].info["quickRatio"])
quickRatio.append(tickers.tickers['WST'].info["quickRatio"])
quickRatio.append(tickers.tickers['ZBH'].info["quickRatio"])
quickRatio.append(tickers.tickers['ZTS'].info["quickRatio"])

print("-----------------------------------------  QUICK RATIO Calculated Successfully   -----------------------------------------\n")


#----------------------------------------------------   PEG RATIO   ----------------------------------------------------
pegRatio = []
print("\n-----------------------------------------------    Calculating PEG RATIO   -----------------------------------------------")
pegRatio.append(tickers.tickers['ABT'].info["pegRatio"])
pegRatio.append(tickers.tickers['ABBV'].info["pegRatio"])
pegRatio.append(tickers.tickers['ABMD'].info["pegRatio"])
pegRatio.append(tickers.tickers['A'].info["pegRatio"])
pegRatio.append(tickers.tickers['ALGN'].info["pegRatio"])
pegRatio.append(tickers.tickers['ABC'].info["pegRatio"])
pegRatio.append(tickers.tickers['AMGN'].info["pegRatio"])
pegRatio.append(tickers.tickers['ANTM'].info["pegRatio"])
pegRatio.append(tickers.tickers['BAX'].info["pegRatio"])
pegRatio.append(tickers.tickers['BDX'].info["pegRatio"])
pegRatio.append(tickers.tickers['BIO'].info["pegRatio"])
pegRatio.append(tickers.tickers['TECH'].info["pegRatio"])
pegRatio.append(tickers.tickers['BIIB'].info["pegRatio"])
pegRatio.append(tickers.tickers['BSX'].info["pegRatio"])
pegRatio.append(tickers.tickers['BMY'].info["pegRatio"])
pegRatio.append(tickers.tickers['CAH'].info["pegRatio"])
pegRatio.append(tickers.tickers['CTLT'].info["pegRatio"])
pegRatio.append(tickers.tickers['CNC'].info["pegRatio"])
pegRatio.append(tickers.tickers['CERN'].info["pegRatio"])
pegRatio.append(tickers.tickers['CRL'].info["pegRatio"])
pegRatio.append(tickers.tickers['CI'].info["pegRatio"])
pegRatio.append(tickers.tickers['COO'].info["pegRatio"])
pegRatio.append(tickers.tickers['CVS'].info["pegRatio"])
pegRatio.append(tickers.tickers['DHR'].info["pegRatio"])
pegRatio.append(tickers.tickers['DVA'].info["pegRatio"])
pegRatio.append(tickers.tickers['XRAY'].info["pegRatio"])
pegRatio.append(tickers.tickers['DXCM'].info["pegRatio"])
pegRatio.append(tickers.tickers['EW'].info["pegRatio"])
pegRatio.append(tickers.tickers['GILD'].info["pegRatio"])
pegRatio.append(tickers.tickers['HCA'].info["pegRatio"])
pegRatio.append(tickers.tickers['HSIC'].info["pegRatio"])
pegRatio.append(tickers.tickers['HOLX'].info["pegRatio"])
pegRatio.append(tickers.tickers['HUM'].info["pegRatio"])
pegRatio.append(tickers.tickers['IDXX'].info["pegRatio"])
pegRatio.append(tickers.tickers['ILMN'].info["pegRatio"])
pegRatio.append(tickers.tickers['INCY'].info["pegRatio"])
pegRatio.append(tickers.tickers['ISRG'].info["pegRatio"])
pegRatio.append(tickers.tickers['IQV'].info["pegRatio"])
pegRatio.append(tickers.tickers['JNJ'].info["pegRatio"])
pegRatio.append(tickers.tickers['LH'].info["pegRatio"])
pegRatio.append(tickers.tickers['LLY'].info["pegRatio"])
pegRatio.append(tickers.tickers['MCK'].info["pegRatio"])
pegRatio.append(tickers.tickers['MDT'].info["pegRatio"])
pegRatio.append(tickers.tickers['MRK'].info["pegRatio"])
pegRatio.append(tickers.tickers['MTD'].info["pegRatio"])
pegRatio.append(tickers.tickers['MRNA'].info["pegRatio"])
pegRatio.append(tickers.tickers['OGN'].info["pegRatio"])
pegRatio.append(tickers.tickers['PKI'].info["pegRatio"])
pegRatio.append(tickers.tickers['PFE'].info["pegRatio"])
pegRatio.append(tickers.tickers['DGX'].info["pegRatio"])
pegRatio.append(tickers.tickers['REGN'].info["pegRatio"])
pegRatio.append(tickers.tickers['RMD'].info["pegRatio"])
pegRatio.append(tickers.tickers['STE'].info["pegRatio"])
pegRatio.append(tickers.tickers['SYK'].info["pegRatio"])
pegRatio.append(tickers.tickers['TFX'].info["pegRatio"])
pegRatio.append(tickers.tickers['TMO'].info["pegRatio"])
pegRatio.append(tickers.tickers['UNH'].info["pegRatio"])
pegRatio.append(tickers.tickers['UHS'].info["pegRatio"])
pegRatio.append(tickers.tickers['VRTX'].info["pegRatio"])
pegRatio.append(tickers.tickers['VTRS'].info["pegRatio"])
pegRatio.append(tickers.tickers['WAT'].info["pegRatio"])
pegRatio.append(tickers.tickers['WST'].info["pegRatio"])
pegRatio.append(tickers.tickers['ZBH'].info["pegRatio"])
pegRatio.append(tickers.tickers['ZTS'].info["pegRatio"])


print("-----------------------------------------  PEG RATIO Calculated Successfully   -----------------------------------------\n")

#----------------------------------------------------   TRAILING EPS   ----------------------------------------------------

trailingEps = []
print("\n-----------------------------------------------    Calculating TRAILING EPS  -----------------------------------------------")
trailingEps.append(tickers.tickers['ABT'].info["trailingEps"])
trailingEps.append(tickers.tickers['ABBV'].info["trailingEps"])
trailingEps.append(tickers.tickers['ABMD'].info["trailingEps"])
trailingEps.append(tickers.tickers['A'].info["trailingEps"])
trailingEps.append(tickers.tickers['ALGN'].info["trailingEps"])
trailingEps.append(tickers.tickers['ABC'].info["trailingEps"])
trailingEps.append(tickers.tickers['AMGN'].info["trailingEps"])
trailingEps.append(tickers.tickers['ANTM'].info["trailingEps"])
trailingEps.append(tickers.tickers['BAX'].info["trailingEps"])
trailingEps.append(tickers.tickers['BDX'].info["trailingEps"])
trailingEps.append(tickers.tickers['BIO'].info["trailingEps"])
trailingEps.append(tickers.tickers['TECH'].info["trailingEps"])
trailingEps.append(tickers.tickers['BIIB'].info["trailingEps"])
trailingEps.append(tickers.tickers['BSX'].info["trailingEps"])
trailingEps.append(tickers.tickers['BMY'].info["forwardPE"])
trailingEps.append(tickers.tickers['CAH'].info["trailingEps"])
trailingEps.append(tickers.tickers['CTLT'].info["trailingEps"])
trailingEps.append(tickers.tickers['CNC'].info["trailingEps"])
trailingEps.append(tickers.tickers['CERN'].info["trailingEps"])
trailingEps.append(tickers.tickers['CRL'].info["trailingEps"])
trailingEps.append(tickers.tickers['CI'].info["trailingEps"])
trailingEps.append(tickers.tickers['COO'].info["trailingEps"])
trailingEps.append(tickers.tickers['CVS'].info["trailingEps"])
trailingEps.append(tickers.tickers['DHR'].info["trailingEps"])
trailingEps.append(tickers.tickers['DVA'].info["trailingEps"])
trailingEps.append(tickers.tickers['XRAY'].info["trailingEps"])
trailingEps.append(tickers.tickers['DXCM'].info["trailingEps"])
trailingEps.append(tickers.tickers['EW'].info["trailingEps"])
trailingEps.append(tickers.tickers['GILD'].info["trailingEps"])
trailingEps.append(tickers.tickers['HCA'].info["trailingEps"])
trailingEps.append(tickers.tickers['HSIC'].info["trailingEps"])
trailingEps.append(tickers.tickers['HOLX'].info["trailingEps"])
trailingEps.append(tickers.tickers['HUM'].info["trailingEps"])
trailingEps.append(tickers.tickers['IDXX'].info["trailingEps"])
trailingEps.append(tickers.tickers['ILMN'].info["trailingEps"])
trailingEps.append(tickers.tickers['INCY'].info["trailingEps"])
trailingEps.append(tickers.tickers['ISRG'].info["trailingEps"])
trailingEps.append(tickers.tickers['IQV'].info["trailingEps"])
trailingEps.append(tickers.tickers['JNJ'].info["trailingEps"])
trailingEps.append(tickers.tickers['LH'].info["trailingEps"])
trailingEps.append(tickers.tickers['LLY'].info["trailingEps"])
trailingEps.append(tickers.tickers['MCK'].info["forwardPE"])
trailingEps.append(tickers.tickers['MDT'].info["trailingEps"])
trailingEps.append(tickers.tickers['MRK'].info["trailingEps"])
trailingEps.append(tickers.tickers['MTD'].info["trailingEps"])
trailingEps.append(tickers.tickers['MRNA'].info["trailingEps"])
trailingEps.append(tickers.tickers['OGN'].info["trailingEps"])
trailingEps.append(tickers.tickers['PKI'].info["trailingEps"])
trailingEps.append(tickers.tickers['PFE'].info["trailingEps"])
trailingEps.append(tickers.tickers['DGX'].info["trailingEps"])
trailingEps.append(tickers.tickers['REGN'].info["trailingEps"])
trailingEps.append(tickers.tickers['RMD'].info["trailingEps"])
trailingEps.append(tickers.tickers['STE'].info["trailingEps"])
trailingEps.append(tickers.tickers['SYK'].info["trailingEps"])
trailingEps.append(tickers.tickers['TFX'].info["trailingEps"])
trailingEps.append(tickers.tickers['TMO'].info["trailingEps"])
trailingEps.append(tickers.tickers['UNH'].info["trailingEps"])
trailingEps.append(tickers.tickers['UHS'].info["trailingEps"])
trailingEps.append(tickers.tickers['VRTX'].info["trailingEps"])
trailingEps.append(tickers.tickers['VTRS'].info["trailingEps"])
trailingEps.append(tickers.tickers['WAT'].info["trailingEps"])
trailingEps.append(tickers.tickers['WST'].info["trailingEps"])
trailingEps.append(tickers.tickers['ZBH'].info["trailingEps"])
trailingEps.append(tickers.tickers['ZTS'].info["trailingEps"])

print("-----------------------------------------  TRAILING EPS Calculated Successfully   -----------------------------------------\n")
os.system('say "Shubh, your program ran successfully"')
# Out:
# -----------------------------------------------    Calculating DIVIDEND YIELD  -----------------------------------------------
# -----------------------------------------  DIVIDEND YIELD Calculated Successfully   -----------------------------------------
#
#
# -----------------------------------------------    Calculating TRALING PE  -----------------------------------------------
#
# -----------------------------------------------    Calculating QUICK RATIO  -----------------------------------------------
# -----------------------------------------  QUICK RATIO Calculated Successfully   -----------------------------------------
#
#
# -----------------------------------------------    Calculating PEG RATIO   -----------------------------------------------
# -----------------------------------------  PEG RATIO Calculated Successfully   -----------------------------------------
#
#
# ...

# %%
dummy5["Trailing PE"] = trailingPE
dummy5["Peg Ratio"] = pegRatio
dummy5["Trailing EPS"] = trailingEps
dummy5["Current Ratio"] = currentRatio
dummy5["QUICK Ratio"] = quickRatio
dummy5["Dividend Yield"] = dividendYield
dummy5 = dummy5.drop(columns=['SEC filings','CIK'])
dummy5.to_csv("HealthCare.csv")
os.system('say "Shubh, your program ran successfully"')
# Out:
# /Users/shubhammandhare/opt/anaconda3/envs/540/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/shubhammandhare/opt/anaconda3/envs/540/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/shubhammandhare/opt/anaconda3/envs/540/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
print(df_financials["Symbol"].tolist())
# Out:
# ['AFL', 'ALL', 'AXP', 'AIG', 'AMP', 'AON', 'AJG', 'AIZ', 'BAC', 'BRK.B', 'BLK', 'BK', 'BRO', 'COF', 'CBOE', 'SCHW', 'CB', 'CINF', 'C', 'CFG', 'CME', 'CMA', 'DFS', 'RE', 'FITB', 'FRC', 'BEN', 'GL', 'GS', 'HIG', 'HBAN', 'ICE', 'IVZ', 'JPM', 'KEY', 'LNC', 'L', 'MTB', 'MKTX', 'MMC', 'MET', 'MCO', 'MS', 'MSCI', 'NDAQ', 'NTRS', 'PBCT', 'PNC', 'PFG', 'PGR', 'PRU', 'RJF', 'RF', 'SPGI', 'STT', 'SIVB', 'SYF', 'TROW', 'TRV', 'TFC', 'USB', 'WRB', 'WFC', 'WLTW', 'ZION']

# %%
print("\n--------------------------------    FETCHING DATA for FINANCIALS SECTOR   -----------------------------------")
tickers = yf.Tickers("AFL ALL AXP AIG AMP AON AJG AIZ BAC BRK-B BLK BK BRO COF CBOE SCHW CB CINF C CFG CME CMA DFS RE FITB FRC BEN GL GS HIG HBAN ICE IVZ JPM KEY LNC L MTB MKTX MMC MET MCO MS MSCI NDAQ NTRS PBCT PNC PFG PGR PRU RJF RF SPGI STT SIVB SYF TROW TRV TFC USB WRB WFC WLTW ZION")
print("-----------------------------------------------    DATA FETCHED SUCCESSFULLY   -----------------------------------------------\n")
dummy7 = pd.DataFrame()
dummy7 = df[df["GICS Sector"]=="Financials"]

#----------------------------------------------------   DIVIDEND YIELD   ----------------------------------------------------

dividendYield = []
print("\n-----------------------------------------------    Calculating DIVIDEND YIELD  -----------------------------------------------")
dividendYield.append(tickers.tickers['AFL'].info["dividendYield"])
dividendYield.append(tickers.tickers['ALL'].info["dividendYield"])
dividendYield.append(tickers.tickers['AXP'].info["dividendYield"])
dividendYield.append(tickers.tickers['AIG'].info["dividendYield"])
dividendYield.append(tickers.tickers['AMP'].info["dividendYield"])
dividendYield.append(tickers.tickers['AON'].info["dividendYield"])
dividendYield.append(tickers.tickers['AJG'].info["dividendYield"])
dividendYield.append(tickers.tickers['AIZ'].info["dividendYield"])
dividendYield.append(tickers.tickers['BAC'].info["dividendYield"])
dividendYield.append(tickers.tickers['BRK-B'].info["dividendYield"])
dividendYield.append(tickers.tickers['BLK'].info["dividendYield"])
dividendYield.append(tickers.tickers['BK'].info["dividendYield"])
dividendYield.append(tickers.tickers['BRO'].info["dividendYield"])
dividendYield.append(tickers.tickers['COF'].info["dividendYield"])
dividendYield.append(tickers.tickers['CBOE'].info["dividendYield"])
dividendYield.append(tickers.tickers['SCHW'].info["dividendYield"])
dividendYield.append(tickers.tickers['CB'].info["dividendYield"])
dividendYield.append(tickers.tickers['CINF'].info["dividendYield"])
dividendYield.append(tickers.tickers['C'].info["dividendYield"])
dividendYield.append(tickers.tickers['CFG'].info["dividendYield"])
dividendYield.append(tickers.tickers['CME'].info["dividendYield"])
dividendYield.append(tickers.tickers['CMA'].info["dividendYield"])
dividendYield.append(tickers.tickers['DFS'].info["dividendYield"])
dividendYield.append(tickers.tickers['RE'].info["dividendYield"])
dividendYield.append(tickers.tickers['FITB'].info["dividendYield"])
dividendYield.append(tickers.tickers['FRC'].info["dividendYield"])
dividendYield.append(tickers.tickers['BEN'].info["dividendYield"])
dividendYield.append(tickers.tickers['GL'].info["dividendYield"])
dividendYield.append(tickers.tickers['GS'].info["dividendYield"])
dividendYield.append(tickers.tickers['HIG'].info["dividendYield"])
dividendYield.append(tickers.tickers['HBAN'].info["dividendYield"])
dividendYield.append(tickers.tickers['ICE'].info["dividendYield"])
dividendYield.append(tickers.tickers['IVZ'].info["dividendYield"])
dividendYield.append(tickers.tickers['JPM'].info["dividendYield"])
dividendYield.append(tickers.tickers['KEY'].info["dividendYield"])
dividendYield.append(tickers.tickers['LNC'].info["dividendYield"])
dividendYield.append(tickers.tickers['L'].info["dividendYield"])
dividendYield.append(tickers.tickers['MTB'].info["dividendYield"])
dividendYield.append(tickers.tickers['MKTX'].info["dividendYield"])
dividendYield.append(tickers.tickers['MMC'].info["dividendYield"])
dividendYield.append(tickers.tickers['MET'].info["dividendYield"])
dividendYield.append(tickers.tickers['MCO'].info["dividendYield"])
dividendYield.append(tickers.tickers['MS'].info["dividendYield"])
dividendYield.append(tickers.tickers['MSCI'].info["dividendYield"])
dividendYield.append(tickers.tickers['NDAQ'].info["dividendYield"])
dividendYield.append(tickers.tickers['NTRS'].info["dividendYield"])
dividendYield.append(tickers.tickers['PBCT'].info["dividendYield"])
dividendYield.append(tickers.tickers['PNC'].info["dividendYield"])
dividendYield.append(tickers.tickers['PFG'].info["dividendYield"])
dividendYield.append(tickers.tickers['PGR'].info["dividendYield"])
dividendYield.append(tickers.tickers['PRU'].info["dividendYield"])
dividendYield.append(tickers.tickers['RJF'].info["dividendYield"])
dividendYield.append(tickers.tickers['RF'].info["dividendYield"])
dividendYield.append(tickers.tickers['SPGI'].info["dividendYield"])
dividendYield.append(tickers.tickers['STT'].info["dividendYield"])
dividendYield.append(tickers.tickers['SIVB'].info["dividendYield"])
dividendYield.append(tickers.tickers['SYF'].info["dividendYield"])
dividendYield.append(tickers.tickers['TROW'].info["dividendYield"])
dividendYield.append(tickers.tickers['TRV'].info["dividendYield"])
dividendYield.append(tickers.tickers['TFC'].info["dividendYield"])
dividendYield.append(tickers.tickers['USB'].info["dividendYield"])
dividendYield.append(tickers.tickers['WRB'].info["dividendYield"])
dividendYield.append(tickers.tickers['WFC'].info["dividendYield"])
dividendYield.append(tickers.tickers['WLTW'].info["dividendYield"])
dividendYield.append(tickers.tickers['ZION'].info["dividendYield"])

print("-----------------------------------------  DIVIDEND YIELD Calculated Successfully   -----------------------------------------\n")
# Out:
# --------------------------------    FETCHING DATA for FINANCIALS SECTOR   -----------------------------------
# -----------------------------------------------    DATA FETCHED SUCCESSFULLY   -----------------------------------------------
#
#
# -----------------------------------------------    Calculating DIVIDEND YIELD  -----------------------------------------------
# -----------------------------------------  DIVIDEND YIELD Calculated Successfully   -----------------------------------------

# %%
#----------------------------------------------------   TRALING PE RATIO   ----------------------------------------------------
# BMY,MCK, VTRS
pegRatio = []
print("\n-----------------------------------------------    Calculating PEG RATIO  -----------------------------------------------")
pegRatio.append(tickers.tickers['AFL'].info["pegRatio"])
pegRatio.append(tickers.tickers['ALL'].info["pegRatio"])
pegRatio.append(tickers.tickers['AXP'].info["pegRatio"])
pegRatio.append(tickers.tickers['AIG'].info["pegRatio"])
pegRatio.append(tickers.tickers['AMP'].info["pegRatio"])
pegRatio.append(tickers.tickers['AON'].info["pegRatio"])
pegRatio.append(tickers.tickers['AJG'].info["pegRatio"])
pegRatio.append(tickers.tickers['AIZ'].info["pegRatio"])
pegRatio.append(tickers.tickers['BAC'].info["pegRatio"])
pegRatio.append(tickers.tickers['BRK-B'].info["pegRatio"])
pegRatio.append(tickers.tickers['BLK'].info["pegRatio"])
pegRatio.append(tickers.tickers['BK'].info["pegRatio"])
pegRatio.append(tickers.tickers['BRO'].info["pegRatio"])
pegRatio.append(tickers.tickers['COF'].info["pegRatio"])
pegRatio.append(tickers.tickers['CBOE'].info["pegRatio"])
pegRatio.append(tickers.tickers['SCHW'].info["pegRatio"])
pegRatio.append(tickers.tickers['CB'].info["pegRatio"])
pegRatio.append(tickers.tickers['CINF'].info["pegRatio"])
pegRatio.append(tickers.tickers['C'].info["pegRatio"])
pegRatio.append(tickers.tickers['CFG'].info["pegRatio"])
pegRatio.append(tickers.tickers['CME'].info["pegRatio"])
pegRatio.append(tickers.tickers['CMA'].info["pegRatio"])
pegRatio.append(tickers.tickers['DFS'].info["pegRatio"])
pegRatio.append(tickers.tickers['RE'].info["pegRatio"])
pegRatio.append(tickers.tickers['FITB'].info["pegRatio"])
pegRatio.append(tickers.tickers['FRC'].info["pegRatio"])
pegRatio.append(tickers.tickers['BEN'].info["pegRatio"])
pegRatio.append(tickers.tickers['GL'].info["pegRatio"])
pegRatio.append(tickers.tickers['GS'].info["pegRatio"])
pegRatio.append(tickers.tickers['HIG'].info["pegRatio"])
pegRatio.append(tickers.tickers['HBAN'].info["pegRatio"])
pegRatio.append(tickers.tickers['ICE'].info["pegRatio"])
pegRatio.append(tickers.tickers['IVZ'].info["pegRatio"])
pegRatio.append(tickers.tickers['JPM'].info["pegRatio"])
pegRatio.append(tickers.tickers['KEY'].info["pegRatio"])
pegRatio.append(tickers.tickers['LNC'].info["pegRatio"])
pegRatio.append(tickers.tickers['L'].info["pegRatio"])
pegRatio.append(tickers.tickers['MTB'].info["pegRatio"])
pegRatio.append(tickers.tickers['MKTX'].info["pegRatio"])
pegRatio.append(tickers.tickers['MMC'].info["pegRatio"])
pegRatio.append(tickers.tickers['MET'].info["pegRatio"])
pegRatio.append(tickers.tickers['MCO'].info["pegRatio"])
pegRatio.append(tickers.tickers['MS'].info["pegRatio"])
pegRatio.append(tickers.tickers['MSCI'].info["pegRatio"])
pegRatio.append(tickers.tickers['NDAQ'].info["pegRatio"])
pegRatio.append(tickers.tickers['NTRS'].info["pegRatio"])
pegRatio.append(tickers.tickers['PBCT'].info["pegRatio"])
pegRatio.append(tickers.tickers['PNC'].info["pegRatio"])
pegRatio.append(tickers.tickers['PFG'].info["pegRatio"])
pegRatio.append(tickers.tickers['PGR'].info["pegRatio"])
pegRatio.append(tickers.tickers['PRU'].info["pegRatio"])
pegRatio.append(tickers.tickers['RJF'].info["pegRatio"])
pegRatio.append(tickers.tickers['RF'].info["pegRatio"])
pegRatio.append(tickers.tickers['SPGI'].info["pegRatio"])
pegRatio.append(tickers.tickers['STT'].info["pegRatio"])
pegRatio.append(tickers.tickers['SIVB'].info["pegRatio"])
pegRatio.append(tickers.tickers['SYF'].info["pegRatio"])
pegRatio.append(tickers.tickers['TROW'].info["pegRatio"])
pegRatio.append(tickers.tickers['TRV'].info["pegRatio"])
pegRatio.append(tickers.tickers['TFC'].info["pegRatio"])
pegRatio.append(tickers.tickers['USB'].info["pegRatio"])
pegRatio.append(tickers.tickers['WRB'].info["pegRatio"])
pegRatio.append(tickers.tickers['WFC'].info["pegRatio"])
pegRatio.append(tickers.tickers['WLTW'].info["pegRatio"])
pegRatio.append(tickers.tickers['ZION'].info["pegRatio"])
print("-----------------------------------------  PEG RATIO Calculated Successfully   -----------------------------------------\n")
# Out:
# -----------------------------------------------    Calculating PEG RATIO  -----------------------------------------------
# -----------------------------------------  PEG RATIO Calculated Successfully   -----------------------------------------

# %%
#----------------------------------------------------   CURRENT RATIO   ----------------------------------------------------

currentRatio = []
print("\n-----------------------------------------------    Calculating CURRENT RATIO  -----------------------------------------------")
currentRatio.append(tickers.tickers['AFL'].info["currentRatio"])
currentRatio.append(tickers.tickers['ALL'].info["currentRatio"])
currentRatio.append(tickers.tickers['AXP'].info["currentRatio"])
currentRatio.append(tickers.tickers['AIG'].info["currentRatio"])
currentRatio.append(tickers.tickers['AMP'].info["currentRatio"])
currentRatio.append(tickers.tickers['AON'].info["currentRatio"])
currentRatio.append(tickers.tickers['AJG'].info["currentRatio"])
currentRatio.append(tickers.tickers['AIZ'].info["currentRatio"])
currentRatio.append(tickers.tickers['BAC'].info["currentRatio"])
currentRatio.append(tickers.tickers['BRK-B'].info["currentRatio"])
currentRatio.append(tickers.tickers['BLK'].info["currentRatio"])
currentRatio.append(tickers.tickers['BK'].info["currentRatio"])
currentRatio.append(tickers.tickers['BRO'].info["currentRatio"])
currentRatio.append(tickers.tickers['COF'].info["currentRatio"])
currentRatio.append(tickers.tickers['CBOE'].info["currentRatio"])
currentRatio.append(tickers.tickers['SCHW'].info["currentRatio"])
currentRatio.append(tickers.tickers['CB'].info["currentRatio"])
currentRatio.append(tickers.tickers['CINF'].info["currentRatio"])
currentRatio.append(tickers.tickers['C'].info["currentRatio"])
currentRatio.append(tickers.tickers['CFG'].info["currentRatio"])
currentRatio.append(tickers.tickers['CME'].info["currentRatio"])
currentRatio.append(tickers.tickers['CMA'].info["currentRatio"])
currentRatio.append(tickers.tickers['DFS'].info["currentRatio"])
currentRatio.append(tickers.tickers['RE'].info["currentRatio"])
currentRatio.append(tickers.tickers['FITB'].info["currentRatio"])
currentRatio.append(tickers.tickers['FRC'].info["currentRatio"])
currentRatio.append(tickers.tickers['BEN'].info["currentRatio"])
currentRatio.append(tickers.tickers['GL'].info["currentRatio"])
currentRatio.append(tickers.tickers['GS'].info["currentRatio"])
currentRatio.append(tickers.tickers['HIG'].info["currentRatio"])
currentRatio.append(tickers.tickers['HBAN'].info["currentRatio"])
currentRatio.append(tickers.tickers['ICE'].info["currentRatio"])
currentRatio.append(tickers.tickers['IVZ'].info["currentRatio"])
currentRatio.append(tickers.tickers['JPM'].info["currentRatio"])
currentRatio.append(tickers.tickers['KEY'].info["currentRatio"])
currentRatio.append(tickers.tickers['LNC'].info["currentRatio"])
currentRatio.append(tickers.tickers['L'].info["currentRatio"])
currentRatio.append(tickers.tickers['MTB'].info["currentRatio"])
currentRatio.append(tickers.tickers['MKTX'].info["currentRatio"])
currentRatio.append(tickers.tickers['MMC'].info["currentRatio"])
currentRatio.append(tickers.tickers['MET'].info["currentRatio"])
currentRatio.append(tickers.tickers['MCO'].info["currentRatio"])
currentRatio.append(tickers.tickers['MS'].info["currentRatio"])
currentRatio.append(tickers.tickers['MSCI'].info["currentRatio"])
currentRatio.append(tickers.tickers['NDAQ'].info["currentRatio"])
currentRatio.append(tickers.tickers['NTRS'].info["currentRatio"])
currentRatio.append(tickers.tickers['PBCT'].info["currentRatio"])
currentRatio.append(tickers.tickers['PNC'].info["currentRatio"])
currentRatio.append(tickers.tickers['PFG'].info["currentRatio"])
currentRatio.append(tickers.tickers['PGR'].info["currentRatio"])
currentRatio.append(tickers.tickers['PRU'].info["currentRatio"])
currentRatio.append(tickers.tickers['RJF'].info["currentRatio"])
currentRatio.append(tickers.tickers['RF'].info["currentRatio"])
currentRatio.append(tickers.tickers['SPGI'].info["currentRatio"])
currentRatio.append(tickers.tickers['STT'].info["currentRatio"])
currentRatio.append(tickers.tickers['SIVB'].info["currentRatio"])
currentRatio.append(tickers.tickers['SYF'].info["currentRatio"])
currentRatio.append(tickers.tickers['TROW'].info["currentRatio"])
currentRatio.append(tickers.tickers['TRV'].info["currentRatio"])
currentRatio.append(tickers.tickers['TFC'].info["currentRatio"])
currentRatio.append(tickers.tickers['USB'].info["currentRatio"])
currentRatio.append(tickers.tickers['WRB'].info["currentRatio"])
currentRatio.append(tickers.tickers['WFC'].info["currentRatio"])
currentRatio.append(tickers.tickers['WLTW'].info["currentRatio"])
currentRatio.append(tickers.tickers['ZION'].info["currentRatio"])

print("-----------------------------------------  CURRENT RATIO Calculated Successfully   -----------------------------------------\n")
# Out:
# -----------------------------------------------    Calculating CURRENT RATIO  -----------------------------------------------
# -----------------------------------------  CURRENT RATIO Calculated Successfully   -----------------------------------------

# %%
#----------------------------------------------------   QUICK RATIO   ----------------------------------------------------

quickRatio = []
print("\n-----------------------------------------------    Calculating QUICK RATIO  -----------------------------------------------")
quickRatio.append(tickers.tickers['AFL'].info["quickRatio"])
quickRatio.append(tickers.tickers['ALL'].info["quickRatio"])
quickRatio.append(tickers.tickers['AXP'].info["quickRatio"])
quickRatio.append(tickers.tickers['AIG'].info["quickRatio"])
quickRatio.append(tickers.tickers['AMP'].info["quickRatio"])
quickRatio.append(tickers.tickers['AON'].info["quickRatio"])
quickRatio.append(tickers.tickers['AJG'].info["quickRatio"])
quickRatio.append(tickers.tickers['AIZ'].info["quickRatio"])
quickRatio.append(tickers.tickers['BAC'].info["quickRatio"])
quickRatio.append(tickers.tickers['BRK-B'].info["quickRatio"])
quickRatio.append(tickers.tickers['BLK'].info["quickRatio"])
quickRatio.append(tickers.tickers['BK'].info["quickRatio"])
quickRatio.append(tickers.tickers['BRO'].info["quickRatio"])
quickRatio.append(tickers.tickers['COF'].info["quickRatio"])
quickRatio.append(tickers.tickers['CBOE'].info["quickRatio"])
quickRatio.append(tickers.tickers['SCHW'].info["quickRatio"])
quickRatio.append(tickers.tickers['CB'].info["quickRatio"])
quickRatio.append(tickers.tickers['CINF'].info["quickRatio"])
quickRatio.append(tickers.tickers['C'].info["quickRatio"])
quickRatio.append(tickers.tickers['CFG'].info["quickRatio"])
quickRatio.append(tickers.tickers['CME'].info["quickRatio"])
quickRatio.append(tickers.tickers['CMA'].info["quickRatio"])
quickRatio.append(tickers.tickers['DFS'].info["quickRatio"])
quickRatio.append(tickers.tickers['RE'].info["quickRatio"])
quickRatio.append(tickers.tickers['FITB'].info["quickRatio"])
quickRatio.append(tickers.tickers['FRC'].info["quickRatio"])
quickRatio.append(tickers.tickers['BEN'].info["quickRatio"])
quickRatio.append(tickers.tickers['GL'].info["quickRatio"])
quickRatio.append(tickers.tickers['GS'].info["quickRatio"])
quickRatio.append(tickers.tickers['HIG'].info["quickRatio"])
quickRatio.append(tickers.tickers['HBAN'].info["quickRatio"])
quickRatio.append(tickers.tickers['ICE'].info["quickRatio"])
quickRatio.append(tickers.tickers['IVZ'].info["quickRatio"])
quickRatio.append(tickers.tickers['JPM'].info["quickRatio"])
quickRatio.append(tickers.tickers['KEY'].info["quickRatio"])
quickRatio.append(tickers.tickers['LNC'].info["quickRatio"])
quickRatio.append(tickers.tickers['L'].info["quickRatio"])
quickRatio.append(tickers.tickers['MTB'].info["quickRatio"])
quickRatio.append(tickers.tickers['MKTX'].info["quickRatio"])
quickRatio.append(tickers.tickers['MMC'].info["quickRatio"])
quickRatio.append(tickers.tickers['MET'].info["quickRatio"])
quickRatio.append(tickers.tickers['MCO'].info["quickRatio"])
quickRatio.append(tickers.tickers['MS'].info["quickRatio"])
quickRatio.append(tickers.tickers['MSCI'].info["quickRatio"])
quickRatio.append(tickers.tickers['NDAQ'].info["quickRatio"])
quickRatio.append(tickers.tickers['NTRS'].info["quickRatio"])
quickRatio.append(tickers.tickers['PBCT'].info["quickRatio"])
quickRatio.append(tickers.tickers['PNC'].info["quickRatio"])
quickRatio.append(tickers.tickers['PFG'].info["quickRatio"])
quickRatio.append(tickers.tickers['PGR'].info["quickRatio"])
quickRatio.append(tickers.tickers['PRU'].info["quickRatio"])
quickRatio.append(tickers.tickers['RJF'].info["quickRatio"])
quickRatio.append(tickers.tickers['RF'].info["quickRatio"])
quickRatio.append(tickers.tickers['SPGI'].info["quickRatio"])
quickRatio.append(tickers.tickers['STT'].info["quickRatio"])
quickRatio.append(tickers.tickers['SIVB'].info["quickRatio"])
quickRatio.append(tickers.tickers['SYF'].info["quickRatio"])
quickRatio.append(tickers.tickers['TROW'].info["quickRatio"])
quickRatio.append(tickers.tickers['TRV'].info["quickRatio"])
quickRatio.append(tickers.tickers['TFC'].info["quickRatio"])
quickRatio.append(tickers.tickers['USB'].info["quickRatio"])
quickRatio.append(tickers.tickers['WRB'].info["quickRatio"])
quickRatio.append(tickers.tickers['WFC'].info["quickRatio"])
quickRatio.append(tickers.tickers['WLTW'].info["quickRatio"])
quickRatio.append(tickers.tickers['ZION'].info["quickRatio"])

print("-----------------------------------------  QUICK RATIO Calculated Successfully   -----------------------------------------\n")
# Out:
# -----------------------------------------------    Calculating QUICK RATIO  -----------------------------------------------
# -----------------------------------------  QUICK RATIO Calculated Successfully   -----------------------------------------

# %%
#----------------------------------------------------   TRAILING PE RATIO   ----------------------------------------------------
#Berkshire Hathaway Class B shares
trailingPE = []
print("\n-----------------------------------------------    Calculating TRAILING PE RATIO   -----------------------------------------------")
trailingPE.append(tickers.tickers['AFL'].info["trailingPE"])
trailingPE.append(tickers.tickers['ALL'].info["trailingPE"])
trailingPE.append(tickers.tickers['AXP'].info["trailingPE"])
trailingPE.append(tickers.tickers['AIG'].info["forwardPE"])
trailingPE.append(tickers.tickers['AMP'].info["forwardPE"])
trailingPE.append(tickers.tickers['AON'].info["trailingPE"])
trailingPE.append(tickers.tickers['AJG'].info["trailingPE"])
trailingPE.append(tickers.tickers['AIZ'].info["forwardPE"])
trailingPE.append(tickers.tickers['BAC'].info["trailingPE"])
trailingPE.append(tickers.tickers['BRK-B'].info["trailingPE"])
trailingPE.append(tickers.tickers['BLK'].info["trailingPE"])
trailingPE.append(tickers.tickers['BK'].info["trailingPE"])
trailingPE.append(tickers.tickers['BRO'].info["trailingPE"])
trailingPE.append(tickers.tickers['COF'].info["trailingPE"])
trailingPE.append(tickers.tickers['CBOE'].info["trailingPE"])
trailingPE.append(tickers.tickers['SCHW'].info["trailingPE"])
trailingPE.append(tickers.tickers['CB'].info["trailingPE"])
trailingPE.append(tickers.tickers['CINF'].info["trailingPE"])
trailingPE.append(tickers.tickers['C'].info["trailingPE"])
trailingPE.append(tickers.tickers['CFG'].info["trailingPE"])
trailingPE.append(tickers.tickers['CME'].info["trailingPE"])
trailingPE.append(tickers.tickers['CMA'].info["trailingPE"])
trailingPE.append(tickers.tickers['DFS'].info["trailingPE"])
trailingPE.append(tickers.tickers['RE'].info["trailingPE"])
trailingPE.append(tickers.tickers['FITB'].info["trailingPE"])
trailingPE.append(tickers.tickers['FRC'].info["trailingPE"])
trailingPE.append(tickers.tickers['BEN'].info["trailingPE"])
trailingPE.append(tickers.tickers['GL'].info["trailingPE"])
trailingPE.append(tickers.tickers['GS'].info["trailingPE"])
trailingPE.append(tickers.tickers['HIG'].info["trailingPE"])
trailingPE.append(tickers.tickers['HBAN'].info["trailingPE"])
trailingPE.append(tickers.tickers['ICE'].info["trailingPE"])
trailingPE.append(tickers.tickers['IVZ'].info["trailingPE"])
trailingPE.append(tickers.tickers['JPM'].info["trailingPE"])
trailingPE.append(tickers.tickers['KEY'].info["trailingPE"])
trailingPE.append(tickers.tickers['LNC'].info["trailingPE"])
trailingPE.append(tickers.tickers['L'].info["forwardPE"])
trailingPE.append(tickers.tickers['MTB'].info["trailingPE"])
trailingPE.append(tickers.tickers['MKTX'].info["trailingPE"])
trailingPE.append(tickers.tickers['MMC'].info["trailingPE"])
trailingPE.append(tickers.tickers['MET'].info["trailingPE"])
trailingPE.append(tickers.tickers['MCO'].info["trailingPE"])
trailingPE.append(tickers.tickers['MS'].info["trailingPE"])
trailingPE.append(tickers.tickers['MSCI'].info["trailingPE"])
trailingPE.append(tickers.tickers['NDAQ'].info["trailingPE"])
trailingPE.append(tickers.tickers['NTRS'].info["trailingPE"])
trailingPE.append(tickers.tickers['PBCT'].info["trailingPE"])
trailingPE.append(tickers.tickers['PNC'].info["trailingPE"])
trailingPE.append(tickers.tickers['PFG'].info["trailingPE"])
trailingPE.append(tickers.tickers['PGR'].info["trailingPE"])
trailingPE.append(tickers.tickers['PRU'].info["trailingPE"])
trailingPE.append(tickers.tickers['RJF'].info["trailingPE"])
trailingPE.append(tickers.tickers['RF'].info["trailingPE"])
trailingPE.append(tickers.tickers['SPGI'].info["trailingPE"])
trailingPE.append(tickers.tickers['STT'].info["trailingPE"])
trailingPE.append(tickers.tickers['SIVB'].info["trailingPE"])
trailingPE.append(tickers.tickers['SYF'].info["trailingPE"])
trailingPE.append(tickers.tickers['TROW'].info["trailingPE"])
trailingPE.append(tickers.tickers['TRV'].info["trailingPE"])
trailingPE.append(tickers.tickers['TFC'].info["forwardPE"])
trailingPE.append(tickers.tickers['USB'].info["trailingPE"])
trailingPE.append(tickers.tickers['WRB'].info["trailingPE"])
trailingPE.append(tickers.tickers['WFC'].info["trailingPE"])
trailingPE.append(tickers.tickers['WLTW'].info["trailingPE"])
trailingPE.append(tickers.tickers['ZION'].info["trailingPE"])
#dummy7["TrailingPE Ratio"] = trailingPE
print("-----------------------------------------  PEG RATIO Calculated Successfully   -----------------------------------------\n")
# Out:
# -----------------------------------------------    Calculating TRAILING PE RATIO   -----------------------------------------------
# -----------------------------------------  PEG RATIO Calculated Successfully   -----------------------------------------

# %%
#----------------------------------------------------   TRAILING EPS   ----------------------------------------------------

trailingEps = []
print("\n-----------------------------------------------    Calculating TRAILING EPS  -----------------------------------------------")
trailingEps.append(tickers.tickers['AFL'].info["trailingEps"])
trailingEps.append(tickers.tickers['ALL'].info["trailingEps"])
trailingEps.append(tickers.tickers['AXP'].info["trailingEps"])
trailingEps.append(tickers.tickers['AIG'].info["trailingEps"])
trailingEps.append(tickers.tickers['AMP'].info["trailingEps"])
trailingEps.append(tickers.tickers['AON'].info["trailingEps"])
trailingEps.append(tickers.tickers['AJG'].info["trailingEps"])
trailingEps.append(tickers.tickers['AIZ'].info["trailingEps"])
trailingEps.append(tickers.tickers['BAC'].info["trailingEps"])
trailingEps.append(tickers.tickers['BRK-B'].info["trailingEps"])
trailingEps.append(tickers.tickers['BLK'].info["trailingEps"])
trailingEps.append(tickers.tickers['BK'].info["trailingEps"])
trailingEps.append(tickers.tickers['BRO'].info["trailingEps"])
trailingEps.append(tickers.tickers['COF'].info["trailingEps"])
trailingEps.append(tickers.tickers['CBOE'].info["trailingEps"])
trailingEps.append(tickers.tickers['SCHW'].info["trailingEps"])
trailingEps.append(tickers.tickers['CB'].info["trailingEps"])
trailingEps.append(tickers.tickers['CINF'].info["trailingEps"])
trailingEps.append(tickers.tickers['C'].info["trailingEps"])
trailingEps.append(tickers.tickers['CFG'].info["trailingEps"])
trailingEps.append(tickers.tickers['CME'].info["trailingEps"])
trailingEps.append(tickers.tickers['CMA'].info["trailingEps"])
trailingEps.append(tickers.tickers['DFS'].info["trailingEps"])
trailingEps.append(tickers.tickers['RE'].info["trailingEps"])
trailingEps.append(tickers.tickers['FITB'].info["trailingEps"])
trailingEps.append(tickers.tickers['FRC'].info["trailingEps"])
trailingEps.append(tickers.tickers['BEN'].info["trailingEps"])
trailingEps.append(tickers.tickers['GL'].info["trailingEps"])
trailingEps.append(tickers.tickers['GS'].info["trailingEps"])
trailingEps.append(tickers.tickers['HIG'].info["trailingEps"])
trailingEps.append(tickers.tickers['HBAN'].info["trailingEps"])
trailingEps.append(tickers.tickers['ICE'].info["trailingEps"])
trailingEps.append(tickers.tickers['IVZ'].info["trailingEps"])
trailingEps.append(tickers.tickers['JPM'].info["trailingEps"])
trailingEps.append(tickers.tickers['KEY'].info["trailingEps"])
trailingEps.append(tickers.tickers['LNC'].info["trailingEps"])
trailingEps.append(tickers.tickers['L'].info["trailingEps"])
trailingEps.append(tickers.tickers['MTB'].info["trailingEps"])
trailingEps.append(tickers.tickers['MKTX'].info["trailingEps"])
trailingEps.append(tickers.tickers['MMC'].info["trailingEps"])
trailingEps.append(tickers.tickers['MET'].info["trailingEps"])
trailingEps.append(tickers.tickers['MCO'].info["trailingEps"])
trailingEps.append(tickers.tickers['MS'].info["trailingEps"])
trailingEps.append(tickers.tickers['MSCI'].info["trailingEps"])
trailingEps.append(tickers.tickers['NDAQ'].info["trailingEps"])
trailingEps.append(tickers.tickers['NTRS'].info["trailingEps"])
trailingEps.append(tickers.tickers['PBCT'].info["trailingEps"])
trailingEps.append(tickers.tickers['PNC'].info["trailingEps"])
trailingEps.append(tickers.tickers['PFG'].info["trailingEps"])
trailingEps.append(tickers.tickers['PGR'].info["trailingEps"])
trailingEps.append(tickers.tickers['PRU'].info["trailingEps"])
trailingEps.append(tickers.tickers['RJF'].info["trailingEps"])
trailingEps.append(tickers.tickers['RF'].info["trailingEps"])
trailingEps.append(tickers.tickers['SPGI'].info["trailingEps"])
trailingEps.append(tickers.tickers['STT'].info["trailingEps"])
trailingEps.append(tickers.tickers['SIVB'].info["trailingEps"])
trailingEps.append(tickers.tickers['SYF'].info["trailingEps"])
trailingEps.append(tickers.tickers['TROW'].info["trailingEps"])
trailingEps.append(tickers.tickers['TRV'].info["trailingEps"])
trailingEps.append(tickers.tickers['TFC'].info["trailingEps"])
trailingEps.append(tickers.tickers['USB'].info["trailingEps"])
trailingEps.append(tickers.tickers['WRB'].info["trailingEps"])
trailingEps.append(tickers.tickers['WFC'].info["trailingEps"])
trailingEps.append(tickers.tickers['WLTW'].info["trailingEps"])
trailingEps.append(tickers.tickers['ZION'].info["trailingEps"])

print("-----------------------------------------  TRAILING EPS Calculated Successfully   -----------------------------------------\n")
# Out:
# -----------------------------------------------    Calculating TRAILING EPS  -----------------------------------------------
# -----------------------------------------  TRAILING EPS Calculated Successfully   -----------------------------------------

# %%
# Out:
#     Symbol                      Security GICS Sector  \
# 10     AFL                         Aflac  Financials
# 20     ALL                 Allstate Corp  Financials
# 29     AXP              American Express  Financials
# 30     AIG  American International Group  Financials
# 33     AMP          Ameriprise Financial  Financials
# ..     ...                           ...         ...
# 457    USB                  U.S. Bancorp  Financials
# 478    WRB     W. R. Berkley Corporation  Financials
# 486    WFC                   Wells Fargo  Financials
# 495   WLTW          Willis Towers Watson  Financials
# 503   ZION                 Zions Bancorp  Financials
#
#                     GICS Sub-Industry          Headquarters Location  \
# 10            Life & Health Insurance              Columbus, Georgia
# 20      Property & Casualty Insurance  Northfield Township, Illinois
# 29                   Consumer Finance        New York City, New York
# ...

# %%
dummy7["Trailing PE"] = trailingPE
dummy7["Peg Ratio"] = pegRatio
dummy7["Trailing EPS"] = trailingEps
dummy7["Current Ratio"] = currentRatio
dummy7["QUICK Ratio"] = quickRatio
dummy7["Dividend Yield"] = dividendYield
dummy7 = dummy7.drop(columns=['SEC filings','CIK'])
dummy7.to_csv("Financials.csv")
#/Users/shubhammandhare/Desktop/Shubh/Financials.csv

# %%
#################################### WORKS - Time taken to run 6mins+


# dummy = df[df["GICS Sector"]=="Real Estate"]
# symbols = dummy["Symbol"]
# yahoo_financials = yf2(symbols)
# eps = yahoo_financials.get_earnings_per_share()
#dummy['Earnings'] = dummy['Symbol'].map(eps)
#################################### BUT TOO SLOW
# Out:
# ['ARE', 'AMT', 'AVB', 'BXP', 'CBRE', 'CCI', 'DLR', 'DRE', 'EQIX', 'EQR', 'ESS', 'EXR', 'FRT', 'PEAK', 'HST', 'IRM', 'KIM', 'MAA', 'PLD', 'PSA', 'O', 'REG', 'SBAC', 'SPG', 'UDR', 'VTR', 'VNO', 'WELL', 'WY']

# %%
# eps = yahoo_financials.get_earnings_per_share()
#dummy['Earnings'] = dummy['Symbol'].map(eps)
#################################### BUT TOO SLOW

#stocks = ["AAPL", "AMZN", "WFC", "NVDA", "MSFT", "CSCO", "KO","GOOG", "INTC", "NFLX"]


# start_date = "2010-01-01"
# end_date = "2021-10-25"

# close_price = pd.DataFrame()

# for ticker in stocks:
#     close_price[ticker] = yf.download(ticker, start_date, end_date)["Adj Close"]

# close_price.to_csv("AAPL_GOOG")
# len(close_price)

# %%
# infoTech = pd.read_csv("/Users/shubhammandhare/Desktop/Shubh/Stocks Project/Dataset/InformationTechnology.csv")
# fin = pd.read_csv("/Users/shubhammandhare/Desktop/Shubh/Stocks Project/Dataset/Financials.csv")
# healthCare = pd.read_csv("/Users/shubhammandhare/Desktop/Shubh/Stocks Project/Dataset/HealthCare.csv")
# realEstate = pd.read_csv("/Users/shubhammandhare/Desktop/Shubh/Stocks Project/Dataset/RealEstate.csv")

# infoTech = infoTech.rename(columns={'QUICK Ratio':"Quick Ratio"})
# fin = fin.rename(columns={'QUICK Ratio':"Quick Ratio"})
# healthCare = healthCare.rename(columns={'QUICK Ratio':"Quick Ratio"})
# realEstate = realEstate.rename(columns={'QUICK Ratio':"Quick Ratio"})

# infoTech.to_csv("InformationTechnology.csv")
# fin.to_csv("Financials.csv")
# healthCare.to_csv("HealthCare.csv")
# realEstate.to_csv("RealEstate.csv")
# snp_500_stocks = pd.DataFrame()

# snp_500_stocks = snp_500_stocks.append(infoTech)
# snp_500_stocks = snp_500_stocks.append(fin)
# snp_500_stocks = snp_500_stocks.append(healthCare)
# snp_500_stocks = snp_500_stocks.append(realEstate)

# %%
infoTech = pd.read_csv("/Users/shubhammandhare/Desktop/Shubh/Stocks Project/Dataset/InformationTechnology.csv")
fin = pd.read_csv("/Users/shubhammandhare/Desktop/Shubh/Stocks Project/Dataset/Financials.csv")
healthCare = pd.read_csv("/Users/shubhammandhare/Desktop/Shubh/Stocks Project/Dataset/HealthCare.csv")
realEstate = pd.read_csv("/Users/shubhammandhare/Desktop/Shubh/Stocks Project/Dataset/RealEstate.csv")

snp_stocks = pd.DataFrame()

snp_stocks = snp_stocks.append(infoTech)
snp_stocks = snp_stocks.append(fin)
snp_stocks = snp_stocks.append(healthCare)
snp_stocks = snp_stocks.append(realEstate)

# %%
list(snp_stocks.columns)
snp_stocks = snp_stocks.drop(columns=['Unnamed: 0','Unnamed: 0.1'])

# %%
snp_stocks.to_csv("snp500Stocks.csv")
