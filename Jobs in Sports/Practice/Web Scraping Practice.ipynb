# %%
#pip install beautifulsoup4
#pip install lxml
#pip install requests
from bs4 import BeautifulSoup

# with open('file_name.html','r') as html_file:
#     content = file_name.read()

#     soup = BeautifulSoup(content,'lxml')
#     course_tags = soup.find_all('div',class_='card')
#     for course in course_tags:
#       course_name = course.h5.text
#       course_price = course.a.text.split()[-1]

#     pretty_soup = soup.prettify()
#     tags = soup.find('h5')
#     all_tags = soup.find('h5')
#     for tag in all_tags:
#         print(tag.text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14348/3970766352.py in <module>
#       2 #pip install lxml
#       3 from bs4 import BeautifulSoup
# ----> 4 with open('home.html','r') as html_file:
#       5     content = html_file.read()
#       6     print(content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'home.html'

# %%
import requests
url = 'https://www.timesjobs.com/candidate/job-search.html?searchType=Home_Search&from=submit&asKey=OFF&txtKeywords=&cboPresFuncArea=35'
#url = 'https://www.indeed.com/jobs?q=mls+soccer&l=&from=searchOnHP&vjk=f85d4e0073aedfee'
#agent = {"User-Agent":'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'}

print('Put Some Skills that you dont know')
unfamiliar_skill = input('>')
print(f'filtering out: {unfamiliar_skill}')

def find_jobs():
    html_text = requests.get(url).text
    soup = BeautifulSoup(html_text,'lxml')
    jobs = soup.find_all('li',class_ = 'clearfix job-bx wht-shd-bx')

    for job in jobs:
        company_name = job.find('h3',class_ = 'joblist-comp-name').text.replace(' ','')
        skills_required = job.find('span', class_ = 'srp-skills').text.replace(' ','')
        posted_date = job.find('span', class_ = 'sim-posted').span.text
        more_info = job.header.h2.a['href']
        if(unfamiliar_skills not in skills_required):
            #print(f"Company Name: {company_name}")
            #print(f"Skills: {skills_required}")
            #print(f"Posted Date: {posted_date}")
            #print(f'More Info: {more_info}')
            #print(" ")
# Out:
# Company Name:
# bccmarcomindiaprivatelimited
#
#
# Skills:
#
# softwaretesting,graphics,multimedia,security
#
#
# Posted Date: Posted today
# More Info: https://www.timesjobs.com/job-detail/multimedia-designers-bcc-marcom-india-private-limited-chennai-0-to-3-yrs-jobid-Uqqkk0hXQmtzpSvf__PLUS__uAgZw==&source=srp
# Company Name:
# bccmarcomindiaprivatelimited
#
#
# Skills:
#
# off-pageoptimization,on-pageoptimization,searchengineoptimization,webanalytics,xml,linkbuilding,seo
#
#
# Posted Date: Posted today
# More Info: https://www.timesjobs.com/job-detail/seo-analyst-bcc-marcom-india-private-limited-chennai-0-to-3-yrs-jobid-sklv7GDO4mxzpSvf__PLUS__uAgZw==&source=srp
# Company Name:
# bccmarcomindiaprivatelimited
#
#
# Skills:
#
# css,wordpress,javascript,wordpressdeveloper,html
#
#
# Posted Date: Posted today
# More Info: https://www.timesjobs.com/job-detail/web-developers-bcc-marcom-india-private-limited-chennai-0-to-3-yrs-jobid-yIE0TM9cbTdzpSvf__PLUS__uAgZw==&source=srp
# ...
