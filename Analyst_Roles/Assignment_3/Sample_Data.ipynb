# %%
Company Table

# %% [markdown]
# ![Screen%20Shot%202022-12-05%20at%208.55.14%20PM.png](attachment:Screen%20Shot%202022-12-05%20at%208.55.14%20PM.png)

# %%
Job_Post Table

# %% [markdown]
# ![Screen%20Shot%202022-12-05%20at%208.56.44%20PM.png](attachment:Screen%20Shot%202022-12-05%20at%208.56.44%20PM.png)

# %%
Job_Requirements Table

# %% [markdown]
# ![Screen%20Shot%202022-12-05%20at%208.57.46%20PM.png](attachment:Screen%20Shot%202022-12-05%20at%208.57.46%20PM.png)

# %%
Company_Ratings Table

# %% [markdown]
# ![Screen%20Shot%202022-12-05%20at%208.58.07%20PM.png](attachment:Screen%20Shot%202022-12-05%20at%208.58.07%20PM.png)

# %%
Company_Reviews Table

# %% [markdown]
# ![Screen%20Shot%202022-12-05%20at%208.58.27%20PM.png](attachment:Screen%20Shot%202022-12-05%20at%208.58.27%20PM.png)

# %%
Business_Stream Table

# %% [markdown]
# ![Screen%20Shot%202022-12-05%20at%208.58.56%20PM.png](attachment:Screen%20Shot%202022-12-05%20at%208.58.56%20PM.png)

# %%
Company_Image Table

# %% [markdown]
# ![Screen%20Shot%202022-12-05%20at%208.57.12%20PM.png](attachment:Screen%20Shot%202022-12-05%20at%208.57.12%20PM.png)

# %%
Data_Collection_Websites Table

# %% [markdown]
# ![Screen%20Shot%202022-12-05%20at%208.55.41%20PM.png](attachment:Screen%20Shot%202022-12-05%20at%208.55.41%20PM.png)

# %%
Company_Tweet_Hashtags Table

# %% [markdown]
# ![Screen%20Shot%202022-12-05%20at%208.59.38%20PM.png](attachment:Screen%20Shot%202022-12-05%20at%208.59.38%20PM.png)

# %%
Company_Tweets_Info Table

# %% [markdown]
# ![Screen%20Shot%202022-12-05%20at%209.00.37%20PM.png](attachment:Screen%20Shot%202022-12-05%20at%209.00.37%20PM.png)

# %%
Company_Twitter_Profile Table

# %% [markdown]
# ![Screen%20Shot%202022-12-05%20at%209.01.20%20PM.png](attachment:Screen%20Shot%202022-12-05%20at%209.01.20%20PM.png)
